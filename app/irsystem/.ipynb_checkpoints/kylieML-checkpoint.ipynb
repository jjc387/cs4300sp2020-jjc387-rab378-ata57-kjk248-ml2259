# %%
import pandas as pd
import re
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
#data = pd.read_csv('winereviews.csv')
#data.head()
column_headers = ["country", "description","points", "province", "region_1", "variety", "winery"]
data = pd.read_csv('winereviews.csv', usecols=column_headers)

# %%
data.head()
# Out:
#   country                                        description  points  \
# 0      US  This tremendous 100% varietal wine hails from ...      96
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...      96
# 2      US  Mac Watson honors the memory of a wine once ma...      96
# 3      US  This spent 20 months in 30% new French oak, an...      96
# 4  France  This is the top wine from La Bégude, named aft...      95
#
#          province           region_1             variety  \
# 0      California        Napa Valley  Cabernet Sauvignon
# 1  Northern Spain               Toro       Tinta de Toro
# 2      California     Knights Valley     Sauvignon Blanc
# 3          Oregon  Willamette Valley          Pinot Noir
# 4        Provence             Bandol  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
data = data[data.winery.notnull()]
data = data[data.variety.notnull()]
data = data[data.province != "Other"]
data = data[data.province.notnull()]
data = data[data.province != "France Other"]
data = data[data.province != "Spain Other"]
data = data[data.province != "Australia Other"]
data = data[data.country != "US-France"]
data = data[data.points > 87]
data = data.reset_index()

# %%
len(data.country.unique())
# Out:
# 37

# %%
data.shape
# Out:
# (78673, 8)

# %%
reviews = []
for review in data['description']:
    reviews.append([review])
document = []
for review in data['description']:
    document.append(review)
document = ' '.join(document)
document = document.lower()
document = re.sub('[^a-zA-Z]', ' ', document )
re.sub(r'\s+', ' ', document)
document[:100]
# Out:
# 'this tremendous      varietal wine hails from oakville and was aged over three years in oak  juicy r'

# %%
all_sentences = nltk.sent_tokenize(document)
all_words = [nltk.word_tokenize(sent) for sent in all_sentences]

# %%
from nltk.corpus import stopwords
for i in range(len(all_words)):
    all_words[i] = [w for w in all_words[i] if (w not in stopwords.words('english')) and w not in ['wine', 'drink', 'flavors', 'vineyard', 'finish', 'palate', 'drink', 'notes', 'very']]

# %%
from gensim.models import Word2Vec

# %%
word2vec = Word2Vec(all_words, min_count = 2, window = 5, size = 300)

# %%
vocabulary = word2vec.wv.vocab
word2vec.wv.most_similar('peach')
# Out:
# [('aromas', 0.6901301145553589),
#  ('black', 0.6806736588478088),
#  ('tannins', 0.6761652231216431),
#  ('vanilla', 0.6755066514015198),
#  ('oak', 0.6539678573608398),
#  ('cherry', 0.6497132778167725),
#  ('ripe', 0.6496193408966064),
#  ('raspberry', 0.6495509743690491),
#  ('pepper', 0.6444878578186035),
#  ('well', 0.6427257061004639)]

# %%
query = ['dry']

# %%
### new
from nltk.stem import PorterStemmer
from nltk.stem import SnowballStemmer
from gensim.models.phrases import Phrases, Phraser

# %%
reviews = list(data['description'])
reviews = [str(r) for r in reviews]
reviews_full_doc = ' '.join(reviews)
sent_tokens = sent_tokenize(reviews_full_doc)

# %%
#remove stop words, lowercase, and punctuation
punc = '''!()-[]{};:.'"\, <>./?@#$%^&*_~'''

def process_text(text):
    words = word_tokenize(text)
    processed_sentence = []
    for word in words:
        w = str(word)
        lowercase = str.lower(w)
        stemmed = SnowballStemmer('english').stem(lowercase)
        remove_punc = stemmed
        for c in remove_punc:
            if c in punc:
                remove_punc.replace(c, "")
        processed_sentence.append(remove_punc)
    return(processed_sentence)
        
processed_sents = []
for sent in sent_tokens:
    processed = process_text(sent)
    processed_sents.append(processed)

# %%
# add bi grams/phrases
phrases = Phrases(processed_sents)
phrases = Phrases(phrases[processed_sents])
grams = Phraser(phrases)
phrase_sents = []
for sent in processed_sents:
    phrased = grams[sent]
    phrase_sents.append(phrased)
    
allwords = [item for sublist in phrase_sents for item in sublist]

# %%
allwords
# Out:
# ['this',
#  'tremend',
#  '100_%',
#  'variet',
#  'wine',
#  'hail_from',
#  'oakvill',
#  'and',
#  'was',
#  'age',
#  'over',
#  'three_year',
#  'in',
#  'oak',
#  '.',
#  'juici',
#  'red-cherri',
#  'fruit',
#  'and',
#  'a',
#  'compel',
#  'hint',
#  'of',
#  'caramel',
#  'greet',
#  'the',
#  'palat',
#  ',',
#  'frame',
#  'by',
#  'eleg',
#  ',',
#  'fine',
#  'tannin',
#  'and',
#  'a',
#  'subtl',
#  'minti',
#  'tone',
#  'in',
#  'the',
#  'background',
#  '.',
#  'balanc',
#  'and',
#  'reward',
#  'from',
#  'start',
#  'to',
#  'finish',
#  ',',
#  'it',
#  'has',
#  'year',
#  'ahead',
#  'of',
#  'it',
#  'to',
#  'develop',
#  'further',
#  'nuanc',
#  '.',
#  'enjoy',
#  '2022–2030',
#  '.',
#  'ripe',
#  'aroma',
#  'of',
#  'fig',
#  ',',
#  'blackberri',
#  'and',
#  'cassi',
#  'are',
#  'soften',
#  'and',
#  'sweeten',
#  'by',
#  'a',
#  'slather',
#  'of',
#  'oaki',
#  'chocol',
#  'and',
#  'vanilla',
#  '.',
#  'this',
#  'is',
#  'full',
#  ',',
#  'layer',
#  ',',
#  'intens',
#  'and',
#  'cushion',
#  'on',
#  'the',
#  'palat',
#  ',',
#  'with',
#  'rich',
#  'flavor',
#  'of',
#  'chocolati',
#  'black',
#  'fruit',
#  'and',
#  'bake',
#  'spice',
#  '.',
#  'a',
#  'toasti',
#  ',',
#  'everlast',
#  'finish',
#  'is',
#  'headi',
#  'but',
#  'ideal',
#  'balanc',
#  '.',
#  'drink',
#  'through_2023',
#  '.',
#  'mac',
#  'watson',
#  'honor',
#  'the',
#  'memori',
#  'of',
#  'a',
#  'wine',
#  'onc',
#  'made',
#  'by',
#  'his',
#  'mother',
#  'in',
#  'this',
#  'tremend',
#  'delici',
#  ',',
#  'balanc',
#  'and',
#  'complex',
#  'botrytis',
#  'white',
#  '.',
#  'dark',
#  'gold',
#  'in',
#  'color',
#  ',',
#  'it',
#  'layer',
#  'toast_hazelnut',
#  ',',
#  'pear',
#  'compot',
#  'and',
#  'orang_peel',
#  'flavor',
#  ',',
#  'revel',
#  'in',
#  'the',
#  'succul',
#  'of',
#  'it',
#  '122',
#  'g/l',
#  'of',
#  'residu_sugar',
#  '.',
#  'this',
#  'spent_20',
#  'month',
#  'in',
#  '30_%',
#  'new_french',
#  'oak',
#  ',',
#  'and',
#  'incorpor',
#  'fruit',
#  'from',
#  'ponzi',
#  "'s",
#  'aurora',
#  ',',
#  'abetina',
#  'and',
#  'madrona',
#  'vineyard',
#  ',',
#  'among',
#  'other',
#  '.',
#  'aromat',
#  ',',
#  'dens',
#  'and',
#  'toasti',
#  ',',
#  'it',
#  'deft',
#  'blend',
#  'aroma',
#  'and',
#  'flavor',
#  'of',
#  'toast',
#  ',',
#  'cigar_box',
#  ',',
#  'blackberri',
#  ',',
#  'black',
#  'cherri',
#  ',',
#  'coffe',
#  'and',
#  'graphit',
#  '.',
#  'tannin',
#  'are',
#  'polish',
#  'to',
#  'a',
#  'fine',
#  'sheen',
#  ',',
#  'and',
#  'frame',
#  'a',
#  'finish',
#  'load',
#  'with',
#  'dark',
#  'chocol',
#  'and',
#  'espresso',
#  '.',
#  'drink_now',
#  'through',
#  '2032',
#  '.',
#  'this',
#  'is',
#  'the',
#  'top',
#  'wine',
#  'from',
#  'la',
#  'bégude',
#  ',',
#  'name_after',
#  'the',
#  'highest_point',
#  'in',
#  'the',
#  'vineyard',
#  'at',
#  '1200',
#  'feet',
#  '.',
#  'it',
#  'has',
#  'structur',
#  ',',
#  'densiti',
#  'and',
#  'consider',
#  'acid',
#  'that',
#  'is',
#  'still',
#  'calm_down',
#  '.',
#  'with',
#  '18_month',
#  'in',
#  'wood',
#  ',',
#  'the',
#  'wine',
#  'has',
#  'develop',
#  'an',
#  'extra',
#  'rich',
#  'and',
#  'concentr',
#  '.',
#  'produc',
#  'by',
#  'the',
#  'tari',
#  'famili',
#  ',',
#  'former',
#  'of',
#  'château_giscour',
#  'in',
#  'margaux',
#  ',',
#  'it',
#  'is',
#  'a',
#  'wine',
#  'made',
#  'for',
#  'age',
#  '.',
#  'drink',
#  'from',
#  '2020',
#  '.',
#  'deep',
#  ',',
#  'dens',
#  'and',
#  'pure',
#  'from',
#  'the',
#  'open',
#  'bell',
#  ',',
#  'this',
#  'toro',
#  'is',
#  'a',
#  'winner',
#  '.',
#  'aroma',
#  'of',
#  'dark',
#  'ripe',
#  'black',
#  'fruit',
#  'are',
#  'cool',
#  'and',
#  'moder',
#  'oak',
#  '.',
#  'this',
#  'feel',
#  'massiv',
#  'on',
#  'the',
#  'palat',
#  'but',
#  'sensate',
#  'balanc',
#  '.',
#  'flavor',
#  'of',
#  'blackberri',
#  ',',
#  'coffe',
#  ',',
#  'mocha',
#  'and',
#  'toasti',
#  'oak',
#  'finish',
#  'spici',
#  ',',
#  'smooth',
#  'and',
#  'headi',
#  '.',
#  'drink',
#  'this',
#  'exemplari',
#  'toro',
#  'through_2023',
#  '.',
#  'slight',
#  'gritti',
#  'black-fruit',
#  'aroma',
#  'includ',
#  'a',
#  'sweet',
#  'note',
#  'of',
#  'pastri',
#  'along',
#  'with',
#  'a',
#  'hint',
#  'of',
#  'prune',
#  '.',
#  'wall-to-wal',
#  'satur',
#  'ensur',
#  'that',
#  'all',
#  'corner',
#  'of',
#  'one',
#  "'s",
#  'mouth',
#  'are',
#  'cover',
#  '.',
#  'flavor',
#  'of',
#  'blackberri',
#  ',',
#  'mocha',
#  'and',
#  'chocol',
#  'are',
#  'high',
#  'impress',
#  'and',
#  'express',
#  ',',
#  'while',
#  'this',
#  'settl',
#  'nice',
#  'on',
#  'a',
#  'long',
#  'finish',
#  '.',
#  'drink_now',
#  'through_2024',
#  '.',
#  'lush',
#  'cedari',
#  'black-fruit',
#  'aroma',
#  'are',
#  'lux',
#  'and',
#  'offer',
#  'note',
#  'of',
#  'marzipan',
#  'and',
#  'vanilla',
#  '.',
#  'this',
#  'bruiser',
#  'is',
#  'massiv',
#  'and',
#  'tannic',
#  'on',
#  'the',
#  'palat',
#  ',',
#  'but',
#  'still',
#  'lush',
#  'and',
#  'friend',
#  '.',
#  'chocol',
#  'is',
#  'a',
#  'key',
#  'flavor',
#  ',',
#  'while',
#  'bake',
#  'berri',
#  'and',
#  'cassi',
#  'flavor',
#  'are',
#  'hard',
#  'wallflow',
#  '.',
#  'on',
#  'the',
#  'finish',
#  ',',
#  'this',
#  'is',
#  'tannic',
#  'and',
#  'deep',
#  'as',
#  'a',
#  'sea',
#  'trench',
#  '.',
#  'drink',
#  'this',
#  'satur',
#  'black-color',
#  'toro',
#  'through_2023',
#  '.',
#  'this',
#  're-nam',
#  'vineyard',
#  'was',
#  'former',
#  'bottl',
#  'as',
#  'delancellotti',
#  '.',
#  'you_ll',
#  'find',
#  'strike',
#  'miner',
#  'underscor',
#  'chunki',
#  'black',
#  'fruit',
#  '.',
#  'accent',
#  'of',
#  'citrus',
#  'and',
#  'graphit',
#  'comingl',
#  ',',
#  'with',
#  'except',
#  'midpal',
#  'concentr',
#  '.',
#  'this',
#  'is',
#  'a',
#  'wine',
#  'to',
#  'cellar',
#  ',',
#  'though',
#  'it',
#  'is',
#  'alreadi',
#  'quit',
#  'enjoy',
#  '.',
#  'drink_now',
#  'through_2030',
#  '.',
#  'the',
#  'produc',
#  'sourc',
#  'from',
#  'two',
#  'block',
#  'of',
#  'the',
#  'vineyard',
#  'for',
#  'this',
#  'wine—on',
#  'at',
#  'a',
#  'high',
#  'elev',
#  ',',
#  'which',
#  'contribut',
#  'bright',
#  'acid',
#  '.',
#  'crunchi',
#  'cranberri',
#  ',',
#  'pomegran',
#  'and',
#  'orang_peel',
#  'flavor',
#  'surround',
#  'silki',
#  ',',
#  'succul',
#  'layer',
#  'of',
#  'textur',
#  'that',
#  'present',
#  'as',
#  'fleshi',
#  'fruit',
#  '.',
#  'that',
#  'delic',
#  'lush',
#  'flavor',
#  'has',
#  'consider',
#  'length',
#  '.',
#  'eleg',
#  ',',
#  'complex',
#  'and',
#  'structur',
#  'come_togeth',
#  'in',
#  'this',
#  'drop-dead_gorgeous',
#  'winethat',
#  'rank_among',
#  'itali',
#  "'s",
#  'greatest',
#  'white',
#  '.',
#  'it',
#  'open',
#  'with',
#  'sublim',
#  'yellow',
#  'spring_flower',
#  ',',
#  'aromat',
#  'herb',
#  'and',
#  'orchard',
#  'fruit',
#  'scent',
#  '.',
#  'the',
#  'creami',
#  ',',
#  'delici',
#  'palat',
#  'seamless',
#  'combin',
#  'juici',
#  'white',
#  'peach',
#  ',',
#  'ripe',
#  'pear',
#  'and',
#  'citrus',
#  'flavor',
#  'while',
#  'white',
#  'almond',
#  'and',
#  'savori',
#  'miner',
#  'note',
#  'grace',
#  'the',
#  'linger',
#  'finish',
#  '.',
#  'from',
#  '18-year-old',
#  'vine',
#  ',',
#  'this',
#  'suppl',
#  'well-balanc',
#  'effort',
#  'blend',
#  'flavor',
#  'of',
#  'mocha',
#  ',',
#  'cherri',
#  ',',
#  'vanilla',
#  'and',
#  'breakfast_tea',
#  '.',
#  'superbl',
#  'integr',
#  'and',
#  'delici',
#  'even',
#  'at',
#  'this',
#  'earli_stage',
#  ',',
#  'this',
#  'wine',
#  'seem_destin',
#  'for',
#  'a',
#  'long',
#  'and',
#  'savori',
#  'cellar',
#  'life',
#  '.',
#  'drink_now',
#  'through_2028',
#  '.',
#  'a',
#  'standout',
#  'even',
#  'in',
#  'this',
#  'terrif',
#  'lineup',
#  'of',
#  '2015',
#  'releas',
#  'from',
#  'patricia',
#  'green',
#  ',',
#  'the',
#  'weber',
#  'open',
#  'with',
#  'a',
#  'burst',
#  'of',
#  'cola',
#  'and',
#  'tobacco',
#  'scent',
#  'and',
#  'accent',
#  '.',
#  'it',
#  'continu',
#  ',',
#  'subtl',
#  'and',
#  'detail',
#  ',',
#  'with',
#  'flavor',
#  'of',
#  'orang',
#  ',',
#  'vanilla',
#  ',',
#  'tea',
#  'and',
#  'milk_chocol',
#  'discreet',
#  'thread',
#  'through',
#  'ripe',
#  'blackberri',
#  'fruit',
#  '.',
#  'this',
#  'wine',
#  'is',
#  'in',
#  'peak',
#  'condit',
#  '.',
#  'the',
#  'tannin',
#  'and',
#  'the',
#  'secondari',
#  'flavor',
#  'domin',
#  'this',
#  'ripe',
#  'leather-textur',
#  'wine',
#  '.',
#  'the',
#  'fruit',
#  'is',
#  'all',
#  'there',
#  'as',
#  'well',
#  ':',
#  'dri',
#  'berri',
#  'and',
#  'hint',
#  'of',
#  'black-plum',
#  'skin',
#  '.',
#  'it',
#  'is',
#  'a',
#  'major',
#  'wine',
#  'right',
#  'at',
#  'the',
#  'point',
#  'of',
#  'drink',
#  'with',
#  'both',
#  'the',
#  'matur',
#  'flavor',
#  'and',
#  'the',
#  'fruit',
#  'in',
#  'the',
#  'right',
#  'balanc',
#  '.',
#  'with',
#  'it',
#  'sophist',
#  'mix',
#  'of',
#  'miner',
#  ',',
#  'acid',
#  'and',
#  'tart',
#  'fruit',
#  ',',
#  'this',
#  'seduct',
#  'effort',
#  'pleas',
#  'from',
#  'start',
#  'to',
#  'finish',
#  '.',
#  'suppl',
#  'and',
#  'dens',
#  ',',
#  'it',
#  "'s",
#  'got',
#  'strawberri',
#  ',',
#  'blueberri',
#  ',',
#  'plum',
#  'and',
#  'black',
#  'cherri',
#  ',',
#  'a',
#  'touch',
#  'of',
#  'chocol',
#  ',',
#  'and',
#  'that',
#  'under',
#  'streak',
#  'of',
#  'miner',
#  '.',
#  'all',
#  'these',
#  'element',
#  'are',
#  'in',
#  'good',
#  'proport',
#  'and',
#  'finish',
#  'with',
#  'an',
#  'appeal',
#  'silki',
#  'textur',
#  '.',
#  'it',
#  "'s",
#  'delici',
#  'alreadi',
#  ',',
#  'but',
#  'give',
#  'it',
#  'anoth',
#  'decad',
#  'for',
#  'full',
#  'enjoy',
#  '.',
#  'drink_now',
#  'through_2028',
#  '.',
#  'first',
#  'made',
#  'in',
#  '2006',
#  ',',
#  'this',
#  'succul',
#  'luscious',
#  'chardonnay',
#  'is',
#  'all_about',
#  'miner',
#  '.',
#  'it',
#  "'s",
#  'got',
#  'a',
#  'rich',
#  'core',
#  'of',
#  'butterscotch',
#  'and',
#  'the',
#  'seem',
#  'endless',
#  'layer',
#  'of',
#  'subtl',
#  'flavor',
#  'that',
#  'biodynam_farm',
#  'can',
#  'bring',
#  '.',
#  'it',
#  'spend_18',
#  'month',
#  'on',
#  'the',
#  'lee',
#  'prior',
#  'to',
#  'bottl',
#  '.',
#  'drink_now',
#  'through_2028',
#  '.',
#  'this',
#  'blockbust',
#  ',',
#  'powerhous',
#  'of',
#  'a',
#  'wine',
#  'suggest',
#  'blueberri',
#  'pie',
#  'and',
#  'chocol',
#  'as',
#  'it',
#  'open',
#  'in',
#  'the',
#  'glass',
#  '.',
#  'on',
#  'the',
#  'palat',
#  ',',
#  'it',
#  "'s",
#  'smooth',
#  'and',
#  'seduct',
#  'silki',
#  ',',
#  'offer',
#  'complex',
#  'cedar',
#  ',',
#  'peppercorn',
#  'and',
#  'pepperi',
#  'oak',
#  'season',
#  'amidst',
#  'it',
#  'dens',
#  'rich',
#  '.',
#  'it',
#  'finish',
#  'with',
#  'finess',
#  'and',
#  'spice',
#  '.',
#  'nice',
#  'oak',
#  'blackberri',
#  ',',
#  'licoric',
#  ',',
#  'vanilla',
#  'and',
#  'char',
#  'aroma',
#  'are',
#  'smooth',
#  ...]

# %%
mapping = pd.read_csv('descriptor_mapping.csv').set_index('raw descriptor')

# %%
mapping.head()
# Out:
#                     level_3      level_2 level_1
# raw descriptor
# abras              abrasive  high_tannin  tannin
# acacia               acacia      flowery  flower
# acacia_flower        acacia      flowery  flower
# aciddriven      acid_driven    high_acid    acid
# aggress          aggressive    high_acid    acid

# %%
#map corpus words to level 3
def mapped_words(word):
    if word in list(mapping.index):
        mapped = mapping['level_3'][word]
        return mapped
    else:
        return word

processed_sents = []
for sent in phrase_sents:
    processed_sent = []
    for word in sent:
        mapped_word = mapped_words(word)
        processed_sent.append(str(mapped_word))
    processed_sents.append(processed_sent)

# %%
processed_sents
# Out:
# [['this',
#   'tremend',
#   '100_%',
#   'variet',
#   'wine',
#   'hail_from',
#   'oakvill',
#   'and',
#   'was',
#   'age',
#   'over',
#   'three_year',
#   'in',
#   'oak',
#   '.'],
#  ['juicy',
#   'red-cherri',
#   'fruit',
#   'and',
#   'a',
#   'compel',
#   'hint',
#   'of',
#   'caramel',
#   'greet',
#   'the',
#   'palat',
#   ',',
#   'frame',
#   'by',
#   'elegant',
#   ',',
#   'fine',
#   'tannin',
#   'and',
#   'a',
#   'subtl',
#   'mint',
#   'tone',
#   'in',
#   'the',
#   'background',
#   '.'],
#  ['balanc',
#   'and',
#   'reward',
#   'from',
#   'start',
#   'to',
#   'finish',
#   ',',
#   'it',
#   'has',
#   'year',
#   'ahead',
#   'of',
#   'it',
#   'to',
#   'develop',
#   'further',
#   'nuanc',
#   '.'],
#  ['enjoy', '2022–2030', '.'],
#  ['ripe',
#   'aroma',
#   'of',
#   'fig',
#   ',',
#   'blackberry',
#   'and',
#   'cassis',
#   'are',
#   'soften',
#   'and',
#   'sweet',
#   'by',
#   'a',
#   'slather',
#   'of',
#   'oak',
#   'chocolate',
#   'and',
#   'vanilla',
#   '.'],
#  ['this',
#   'is',
#   'full',
#   ',',
#   'layer',
#   ',',
#   'intens',
#   'and',
#   'cushion',
#   'on',
#   'the',
#   'palat',
#   ',',
#   'with',
#   'rich',
#   'flavor',
#   'of',
#   'chocolate',
#   'black',
#   'fruit',
#   'and',
#   'baked',
#   'spice',
#   '.'],
#  ['a',
#   'toast',
#   ',',
#   'everlast',
#   'finish',
#   'is',
#   'heady',
#   'but',
#   'ideal',
#   'balanc',
#   '.'],
#  ['drink', 'through_2023', '.'],
#  ['mac',
#   'watson',
#   'honor',
#   'the',
#   'memori',
#   'of',
#   'a',
#   'wine',
#   'onc',
#   'made',
#   'by',
#   'his',
#   'mother',
#   'in',
#   'this',
#   'tremend',
#   'delici',
#   ',',
#   'balanc',
#   'and',
#   'complex',
#   'botrytis',
#   'white',
#   '.'],
#  ['dark',
#   'gold',
#   'in',
#   'color',
#   ',',
#   'it',
#   'layer',
#   'toasted_hazelnut',
#   ',',
#   'pear',
#   'compote',
#   'and',
#   'orange_peel',
#   'flavor',
#   ',',
#   'revel',
#   'in',
#   'the',
#   'succulent',
#   'of',
#   'it',
#   '122',
#   'g/l',
#   'of',
#   'residual_sugar',
#   '.'],
#  ['this',
#   'spent_20',
#   'month',
#   'in',
#   '30_%',
#   'new_french',
#   'oak',
#   ',',
#   'and',
#   'incorpor',
#   'fruit',
#   'from',
#   'ponzi',
#   "'s",
#   'aurora',
#   ',',
#   'abetina',
#   'and',
#   'madrona',
#   'vineyard',
#   ',',
#   'among',
#   'other',
#   '.'],
#  ['aromat',
#   ',',
#   'dense',
#   'and',
#   'toast',
#   ',',
#   'it',
#   'deft',
#   'blend',
#   'aroma',
#   'and',
#   'flavor',
#   'of',
#   'toast',
#   ',',
#   'cigar_box',
#   ',',
#   'blackberry',
#   ',',
#   'black',
#   'cherry',
#   ',',
#   'coffee',
#   'and',
#   'graphite',
#   '.'],
#  ['tannin',
#   'are',
#   'polished',
#   'to',
#   'a',
#   'fine',
#   'sheen',
#   ',',
#   'and',
#   'frame',
#   'a',
#   'finish',
#   'load',
#   'with',
#   'dark',
#   'chocolate',
#   'and',
#   'coffee',
#   '.'],
#  ['drink_now', 'through', '2032', '.'],
#  ['this',
#   'is',
#   'the',
#   'top',
#   'wine',
#   'from',
#   'la',
#   'bégude',
#   ',',
#   'name_after',
#   'the',
#   'highest_point',
#   'in',
#   'the',
#   'vineyard',
#   'at',
#   '1200',
#   'feet',
#   '.'],
#  ['it',
#   'has',
#   'structur',
#   ',',
#   'dense',
#   'and',
#   'consider',
#   'acid',
#   'that',
#   'is',
#   'still',
#   'calm_down',
#   '.'],
#  ['with',
#   '18_month',
#   'in',
#   'wood',
#   ',',
#   'the',
#   'wine',
#   'has',
#   'develop',
#   'an',
#   'extra',
#   'rich',
#   'and',
#   'concentrated',
#   '.'],
#  ['produc',
#   'by',
#   'the',
#   'tari',
#   'famili',
#   ',',
#   'former',
#   'of',
#   'château_giscour',
#   'in',
#   'margaux',
#   ',',
#   'it',
#   'is',
#   'a',
#   'wine',
#   'made',
#   'for',
#   'age',
#   '.'],
#  ['drink', 'from', '2020', '.'],
#  ['depth',
#   ',',
#   'dense',
#   'and',
#   'pure',
#   'from',
#   'the',
#   'open',
#   'bell',
#   ',',
#   'this',
#   'toro',
#   'is',
#   'a',
#   'winner',
#   '.'],
#  ['aroma',
#   'of',
#   'dark',
#   'ripe',
#   'black',
#   'fruit',
#   'are',
#   'cool',
#   'and',
#   'moder',
#   'oak',
#   '.'],
#  ['this',
#   'feel',
#   'massiv',
#   'on',
#   'the',
#   'palat',
#   'but',
#   'sensate',
#   'balanc',
#   '.'],
#  ['flavor',
#   'of',
#   'blackberry',
#   ',',
#   'coffee',
#   ',',
#   'coffee',
#   'and',
#   'toast',
#   'oak',
#   'finish',
#   'spice',
#   ',',
#   'smooth',
#   'and',
#   'heady',
#   '.'],
#  ['drink', 'this', 'exemplari', 'toro', 'through_2023', '.'],
#  ['slight',
#   'gritty',
#   'black-fruit',
#   'aroma',
#   'includ',
#   'a',
#   'sweet',
#   'note',
#   'of',
#   'pastry',
#   'along',
#   'with',
#   'a',
#   'hint',
#   'of',
#   'prune',
#   '.'],
#  ['wall-to-wal',
#   'satur',
#   'ensur',
#   'that',
#   'all',
#   'corner',
#   'of',
#   'one',
#   "'s",
#   'mouth',
#   'are',
#   'cover',
#   '.'],
#  ['flavor',
#   'of',
#   'blackberry',
#   ',',
#   'coffee',
#   'and',
#   'chocolate',
#   'are',
#   'high',
#   'impress',
#   'and',
#   'express',
#   ',',
#   'while',
#   'this',
#   'settl',
#   'nice',
#   'on',
#   'a',
#   'long',
#   'finish',
#   '.'],
#  ['drink_now', 'through_2024', '.'],
#  ['lush',
#   'cedar',
#   'black-fruit',
#   'aroma',
#   'are',
#   'lux',
#   'and',
#   'offer',
#   'note',
#   'of',
#   'almond',
#   'and',
#   'vanilla',
#   '.'],
#  ['this',
#   'bruiser',
#   'is',
#   'massiv',
#   'and',
#   'tannin',
#   'on',
#   'the',
#   'palat',
#   ',',
#   'but',
#   'still',
#   'lush',
#   'and',
#   'friend',
#   '.'],
#  ['chocolate',
#   'is',
#   'a',
#   'key',
#   'flavor',
#   ',',
#   'while',
#   'baked',
#   'berry',
#   'and',
#   'cassis',
#   'flavor',
#   'are',
#   'hard',
#   'wallflow',
#   '.'],
#  ['on',
#   'the',
#   'finish',
#   ',',
#   'this',
#   'is',
#   'tannin',
#   'and',
#   'depth',
#   'as',
#   'a',
#   'sea',
#   'trench',
#   '.'],
#  ['drink', 'this', 'satur', 'black-color', 'toro', 'through_2023', '.'],
#  ['this',
#   're-nam',
#   'vineyard',
#   'was',
#   'former',
#   'bottl',
#   'as',
#   'delancellotti',
#   '.'],
#  ['you_ll',
#   'find',
#   'strike',
#   'minerality',
#   'underscor',
#   'chunky',
#   'black',
#   'fruit',
#   '.'],
#  ['accent',
#   'of',
#   'citrus',
#   'and',
#   'graphite',
#   'comingl',
#   ',',
#   'with',
#   'except',
#   'midpal',
#   'concentrated',
#   '.'],
#  ['this',
#   'is',
#   'a',
#   'wine',
#   'to',
#   'cellar',
#   ',',
#   'though',
#   'it',
#   'is',
#   'alreadi',
#   'quit',
#   'enjoy',
#   '.'],
#  ['drink_now', 'through_2030', '.'],
#  ['the',
#   'produc',
#   'sourc',
#   'from',
#   'two',
#   'block',
#   'of',
#   'the',
#   'vineyard',
#   'for',
#   'this',
#   'wine—on',
#   'at',
#   'a',
#   'high',
#   'elev',
#   ',',
#   'which',
#   'contribut',
#   'bright',
#   'acid',
#   '.'],
#  ['crunchy',
#   'cranberry',
#   ',',
#   'pomegranate',
#   'and',
#   'orange_peel',
#   'flavor',
#   'surround',
#   'silky',
#   ',',
#   'succulent',
#   'layer',
#   'of',
#   'textur',
#   'that',
#   'present',
#   'as',
#   'fleshy',
#   'fruit',
#   '.'],
#  ['that', 'delic', 'lush', 'flavor', 'has', 'consider', 'length', '.'],
#  ['elegant',
#   ',',
#   'complex',
#   'and',
#   'structur',
#   'come_togeth',
#   'in',
#   'this',
#   'drop-dead_gorgeous',
#   'winethat',
#   'rank_among',
#   'itali',
#   "'s",
#   'greatest',
#   'white',
#   '.'],
#  ['it',
#   'open',
#   'with',
#   'sublim',
#   'yellow',
#   'spring_flower',
#   ',',
#   'aromat',
#   'herb',
#   'and',
#   'orchard',
#   'fruit',
#   'scent',
#   '.'],
#  ['the',
#   'cream',
#   ',',
#   'delici',
#   'palat',
#   'seamless',
#   'combin',
#   'juicy',
#   'white',
#   'peach',
#   ',',
#   'ripe',
#   'pear',
#   'and',
#   'citrus',
#   'flavor',
#   'while',
#   'white',
#   'almond',
#   'and',
#   'savory',
#   'minerality',
#   'note',
#   'grace',
#   'the',
#   'linger',
#   'finish',
#   '.'],
#  ['from',
#   '18-year-old',
#   'vine',
#   ',',
#   'this',
#   'supple',
#   'well-balanc',
#   'effort',
#   'blend',
#   'flavor',
#   'of',
#   'coffee',
#   ',',
#   'cherry',
#   ',',
#   'vanilla',
#   'and',
#   'breakfast_tea',
#   '.'],
#  ['superbl',
#   'integr',
#   'and',
#   'delici',
#   'even',
#   'at',
#   'this',
#   'earli_stage',
#   ',',
#   'this',
#   'wine',
#   'seem_destin',
#   'for',
#   'a',
#   'long',
#   'and',
#   'savory',
#   'cellar',
#   'life',
#   '.'],
#  ['drink_now', 'through_2028', '.'],
#  ['a',
#   'standout',
#   'even',
#   'in',
#   'this',
#   'terrif',
#   'lineup',
#   'of',
#   '2015',
#   'releas',
#   'from',
#   'patricia',
#   'green',
#   ',',
#   'the',
#   'weber',
#   'open',
#   'with',
#   'a',
#   'burst',
#   'of',
#   'cola',
#   'and',
#   'tobacco',
#   'scent',
#   'and',
#   'accent',
#   '.'],
#  ['it',
#   'continu',
#   ',',
#   'subtl',
#   'and',
#   'detail',
#   ',',
#   'with',
#   'flavor',
#   'of',
#   'orange',
#   ',',
#   'vanilla',
#   ',',
#   'tea',
#   'and',
#   'milk_chocolate',
#   'discreet',
#   'thread',
#   'through',
#   'ripe',
#   'blackberry',
#   'fruit',
#   '.'],
#  ['this', 'wine', 'is', 'in', 'peak', 'condit', '.'],
#  ['the',
#   'tannin',
#   'and',
#   'the',
#   'secondari',
#   'flavor',
#   'domin',
#   'this',
#   'ripe',
#   'leather-textur',
#   'wine',
#   '.'],
#  ['the',
#   'fruit',
#   'is',
#   'all',
#   'there',
#   'as',
#   'well',
#   ':',
#   'dry',
#   'berry',
#   'and',
#   'hint',
#   'of',
#   'black-plum',
#   'skin',
#   '.'],
#  ['it',
#   'is',
#   'a',
#   'major',
#   'wine',
#   'right',
#   'at',
#   'the',
#   'point',
#   'of',
#   'drink',
#   'with',
#   'both',
#   'the',
#   'matur',
#   'flavor',
#   'and',
#   'the',
#   'fruit',
#   'in',
#   'the',
#   'right',
#   'balanc',
#   '.'],
#  ['with',
#   'it',
#   'sophist',
#   'mix',
#   'of',
#   'minerality',
#   ',',
#   'acid',
#   'and',
#   'tart',
#   'fruit',
#   ',',
#   'this',
#   'seduct',
#   'effort',
#   'pleas',
#   'from',
#   'start',
#   'to',
#   'finish',
#   '.'],
#  ['supple',
#   'and',
#   'dense',
#   ',',
#   'it',
#   "'s",
#   'got',
#   'strawberry',
#   ',',
#   'blueberry',
#   ',',
#   'plum',
#   'and',
#   'black',
#   'cherry',
#   ',',
#   'a',
#   'touch',
#   'of',
#   'chocolate',
#   ',',
#   'and',
#   'that',
#   'under',
#   'streak',
#   'of',
#   'minerality',
#   '.'],
#  ['all',
#   'these',
#   'element',
#   'are',
#   'in',
#   'good',
#   'proport',
#   'and',
#   'finish',
#   'with',
#   'an',
#   'appeal',
#   'silky',
#   'textur',
#   '.'],
#  ['it',
#   "'s",
#   'delici',
#   'alreadi',
#   ',',
#   'but',
#   'give',
#   'it',
#   'anoth',
#   'decad',
#   'for',
#   'full',
#   'enjoy',
#   '.'],
#  ['drink_now', 'through_2028', '.'],
#  ['first',
#   'made',
#   'in',
#   '2006',
#   ',',
#   'this',
#   'succulent',
#   'luscious',
#   'chardonnay',
#   'is',
#   'all_about',
#   'minerality',
#   '.'],
#  ['it',
#   "'s",
#   'got',
#   'a',
#   'rich',
#   'core',
#   'of',
#   'butterscotch',
#   'and',
#   'the',
#   'seem',
#   'endless',
#   'layer',
#   'of',
#   'subtl',
#   'flavor',
#   'that',
#   'biodynam_farm',
#   'can',
#   'bring',
#   '.'],
#  ['it', 'spend_18', 'month', 'on', 'the', 'lees', 'prior', 'to', 'bottl', '.'],
#  ['drink_now', 'through_2028', '.'],
#  ['this',
#   'blockbust',
#   ',',
#   'powerhous',
#   'of',
#   'a',
#   'wine',
#   'suggest',
#   'blueberry',
#   'pie',
#   'and',
#   'chocolate',
#   'as',
#   'it',
#   'open',
#   'in',
#   'the',
#   'glass',
#   '.'],
#  ['on',
#   'the',
#   'palat',
#   ',',
#   'it',
#   "'s",
#   'smooth',
#   'and',
#   'seduct',
#   'silky',
#   ',',
#   'offer',
#   'complex',
#   'cedar',
#   ',',
#   'pepper',
#   'and',
#   'pepper',
#   'oak',
#   'season',
#   'amidst',
#   'it',
#   'dense',
#   'rich',
#   '.'],
#  ['it', 'finish', 'with', 'finessed', 'and', 'spice', '.'],
#  ['nice',
#   'oak',
#   'blackberry',
#   ',',
#   'licorice',
#   ',',
#   'vanilla',
#   'and',
#   'char',
#   'aroma',
#   'are',
#   'smooth',
#   'and',
#   'sultri',
#   '.'],
#  ['this', 'is', 'an', 'outstand', 'wine', 'from', 'an', 'excel', 'year', '.'],
#  ['forward',
#   'barrel-spic',
#   'and',
#   'coffee',
#   'flavor',
#   'adorn',
#   'core',
#   'blackberry',
#   'and',
#   'raspberry',
#   'fruit',
#   ',',
#   'while',
#   'this',
#   'run',
#   'long',
#   'and',
#   'tast',
#   'vagu',
#   'chocolate',
#   'on',
#   'the',
#   'velvety',
#   'finish',
#   '.'],
#  ['enjoy', 'this', 'top-notch', 'tempranillo', 'through_2030', '.'],
#  ['come',
#   'from',
#   'a',
#   'seven-acr',
#   'vineyard',
#   'name_after',
#   'the',
#   'dovecot',
#   'on',
#   'the',
#   'properti',
#   ',',
#   'this',
#   'is',
#   'a',
#   'magnific',
#   'wine',
#   '.'],
#  ['powerful',
#   'by',
#   'both',
#   'fruit',
#   'tannin',
#   'and',
#   'the',
#   '28_month',
#   'of',
#   'new',
#   'wood',
#   'age',
#   ',',
#   'it',
#   'is',
#   'dark',
#   'rich',
#   'and',
#   'with',
#   'great',
#   'concentrated',
#   '.'],
#  ['as',
#   'a',
#   'sign',
#   'of',
#   'it',
#   'pedigre',
#   ',',
#   'there',
#   'is',
#   'also',
#   'elegant',
#   'here',
#   ',',
#   'a',
#   'restrained',
#   'which',
#   'is',
#   'new',
#   'to',
#   'this',
#   'wine',
#   '.'],
#  ['that', 'make', 'it', 'a', 'wine', 'for', 'long-term_age', '.'],
#  ['drink', 'from_2022', '.'],
#  ['this',
#   'fresh',
#   'and',
#   'live',
#   'medium-bodi',
#   'wine',
#   'is',
#   'beauti_craft',
#   ',',
#   'with',
#   'cherry',
#   'blossom',
#   'aroma',
#   'and',
#   'tangy',
#   'acid',
#   '.'],
#  ['layer',
#   'and',
#   'seduct',
#   ',',
#   'it',
#   'offer',
#   'a',
#   'crisp',
#   'mix',
#   'of',
#   'orange_peel',
#   ',',
#   'cherry',
#   ',',
#   'pomegranate',
#   'and',
#   'baked',
#   'spice',
#   'flavor',
#   'that',
#   'are',
#   'readi',
#   'for',
#   'the',
#   'tabl',
#   'or',
#   'the',
#   'cellar',
#   '.'],
#  ['heitz',
#   'has',
#   'made',
#   'this',
#   'stellar',
#   'rosé',
#   'from',
#   'the',
#   'rare',
#   'grignolino',
#   'grape',
#   'sinc',
#   '1961',
#   '.'],
#  ['rubi',
#   'grapefruit-r',
#   ',',
#   'it',
#   "'s",
#   'sultri',
#   'with',
#   'strawberry',
#   ',',
#   'watermelon',
#   ',',
#   'orange_peel',
#   'and',
#   'salt',
#   'spice',
#   'flavor',
#   ',',
#   'highlight',
#   'with',
#   'vibrant',
#   'flower',
#   'aroma',
#   '.'],
#  ['allur',
#   ',',
#   'complex',
#   'and',
#   'powerful',
#   'aroma',
#   'of',
#   'grilled_meat',
#   ',',
#   'berry',
#   ',',
#   'tea',
#   ',',
#   'smoke',
#   ',',
#   'vanilla',
#   'and',
#   'spice',
#   'cover',
#   'everi',
#   'base',
#   '.'],
#  ['an',
#   'intens',
#   'palat',
#   'is',
#   'concentrated',
#   'but',
#   'still',
#   'elegant',
#   '.'],
#  ['blackberry',
#   ',',
#   'molasses',
#   'and',
#   'coffee',
#   'flavor',
#   'finish',
#   'with',
#   'chocolate',
#   'oak',
#   'note',
#   ',',
#   'fine',
#   'tannin',
#   'and',
#   'overal',
#   'cohes',
#   '.'],
#  ['drink', 'this', 'special', 'rioja', 'from', '2020', 'through_2035', '.'],
#  ['tar',
#   'blackberry',
#   'and',
#   'cheese',
#   'oak',
#   'aroma',
#   'are',
#   'appropri',
#   'for',
#   'a',
#   'wine',
#   'of',
#   'this',
#   'size',
#   'and',
#   'magnitud',
#   '.'],
#  ['in',
#   'the',
#   'mouth',
#   ',',
#   'this',
#   'tinta_de',
#   'toro',
#   'is',
#   'expansive',
#   'and',
#   'grabby',
#   ',',
#   'with',
#   'bullish',
#   'tannin',
#   '.'],
#  ['slight',
#   'salt',
#   'earth',
#   'accent',
#   'come',
#   'with',
#   'core',
#   'blackberry',
#   'flavor',
#   'and',
#   'note',
#   'of',
#   'baked',
#   'spice',
#   'and',
#   'chocolate',
#   ',',
#   'while',
#   'on',
#   'the',
#   'finish',
#   'this',
#   'is',
#   'long',
#   ',',
#   'chocolate',
#   ',',
#   'delici',
#   'and',
#   'not',
#   'too',
#   'hard',
#   'or',
#   'tannin',
#   '.'],
#  ['drink', 'through_2023', '.'],
#  ['the',
#   'apoge',
#   'of',
#   'this',
#   'ambiti',
#   'wineri',
#   "'s",
#   'white',
#   'wine',
#   'effort',
#   ',',
#   'this',
#   'bottl',
#   'of',
#   'just',
#   'two',
#   'oak',
#   'of',
#   'clone',
#   '5',
#   'show',
#   'focus',
#   'almond',
#   ',',
#   'marcona_almond',
#   'and',
#   'white',
#   'peach',
#   'note',
#   'on',
#   'the',
#   'nose',
#   '.'],
#  ['the',
#   'palat',
#   'sizzling',
#   'with',
#   'salt',
#   'and',
#   'a',
#   'lemon',
#   'acid',
#   'that',
#   'cut_through',
#   'it',
#   'brown_butter',
#   'rich',
#   'with',
#   'finessed',
#   '.'],
#  ['the', 'finish', 'is', 'luxurious', 'and', 'long', '.'],
#  ['san',
#   'jose-bas',
#   'produc',
#   'adam',
#   'comartin',
#   'head',
#   '1,100',
#   'feet',
#   'up',
#   'into',
#   'the',
#   'mountain',
#   'to',
#   'sourc',
#   'fruit',
#   'for',
#   'this',
#   'tremend',
#   'wine',
#   ',',
#   'which',
#   'offer',
#   'wild',
#   'cherry',
#   ',',
#   'sage',
#   ',',
#   'and',
#   'eucalyptus',
#   'scent',
#   'on',
#   'the',
#   'nose',
#   '.'],
#  ['ripe',
#   'black',
#   'plum',
#   'and',
#   'strawberry',
#   'fruit',
#   'lead',
#   'the',
#   'palat',
#   ',',
#   'follow_by',
#   'acid-driven',
#   'wave',
#   'of',
#   'juniper',
#   ',',
#   'pine',
#   'and',
#   'bay_leaf',
#   ',',
#   'finish',
#   'with',
#   'a',
#   'menthol-lik',
#   'sensat',
#   '.'],
#  ['yield_were',
#   'down',
#   'in',
#   '2015',
#   ',',
#   'but',
#   'intens',
#   'is',
#   'up',
#   ',',
#   'give',
#   'this',
#   'medium-bodi',
#   ',',
#   'silky',
#   'wine',
#   'the',
#   'potenti',
#   'to',
#   'drink',
#   'well',
#   'through',
#   'at_least',
#   '2025',
#   '.'],
#  ['hickory_smoke',
#   'outlin',
#   'white',
#   'peach',
#   'befor',
#   'end',
#   'in',
#   'a',
#   'long',
#   'flurri',
#   'of',
#   'lime_peel',
#   '.'],
#  ['bergström',
#   'has',
#   'made',
#   'a',
#   'shea',
#   'design',
#   'sinc',
#   '2003',
#   ',',
#   'intent',
#   'on',
#   'showcas',
#   'a',
#   '“',
#   'pretti',
#   '”',
#   'style',
#   'of',
#   'the',
#   'vineyard',
#   '.'],
#  ['here',
#   'are',
#   'love',
#   'aromat',
#   ',',
#   'with',
#   'grape',
#   'jelly',
#   ',',
#   'rose',
#   'and',
#   'plum',
#   'in',
#   'the',
#   'nose',
#   ',',
#   'and',
#   'a',
#   'complex',
#   'run',
#   'of',
#   'red',
#   'fruit',
#   'in',
#   'the',
#   'mouth',
#   '.'],
#  ['streak',
#   'of',
#   'cola',
#   ',',
#   'brown_sugar',
#   'and',
#   'more',
#   'come',
#   'up',
#   'in',
#   'a',
#   'generous',
#   'finish',
#   '.'],
#  ['focus',
#   'and',
#   'dense',
#   ',',
#   'this',
#   'intens',
#   'wine',
#   'captur',
#   'the',
#   'essenc',
#   'of',
#   'ripe',
#   'raspberry',
#   '.'],
#  ['age',
#   'in',
#   '50_%',
#   'new_french',
#   'oak',
#   ',',
#   'it',
#   "'s",
#   'got',
#   'a',
#   'strong',
#   'vein',
#   'of',
#   'coffee',
#   'and',
#   'coffee',
#   '.'],
#  ['the',
#   'flavor',
#   'broaden_out',
#   'and',
#   'penetr',
#   ',',
#   'finish',
#   'with',
#   'highlight',
#   'of',
#   'cedar',
#   ',',
#   'cinnamon',
#   'and',
#   'dark',
#   'chocolate',
#   '.'],
#  ['drink_now',
#   'through',
#   'the',
#   '2020s',
#   ',',
#   'but',
#   'decant',
#   'if_you',
#   'want',
#   'the',
#   'full',
#   'express',
#   '.'],
#  ['cranberry',
#   ',',
#   'baked',
#   'rhubarb',
#   ',',
#   'anise',
#   'and',
#   'slate',
#   'aroma',
#   'show',
#   'on',
#   'the',
#   'nose',
#   'of',
#   'this',
#   'always-excel',
#   'bottl',
#   'from',
#   'the',
#   'franscioni',
#   'famili',
#   '.'],
#  ['the',
#   'palat',
#   'abound',
#   'with',
#   'energi',
#   ',',
#   'drive',
#   'black',
#   'raspberry',
#   'fruit',
#   'accent',
#   'with',
#   'earth',
#   'loamy',
#   ',',
#   'fennel',
#   ',',
#   'oregano',
#   'and',
#   'juniper',
#   'through',
#   'a',
#   'compel',
#   'round',
#   'midpal',
#   '.'],
#  ['this',
#   'standout',
#   'stone',
#   'district',
#   'wine',
#   'bring',
#   'earth',
#   'shake',
#   'aroma',
#   'of',
#   'black-ol',
#   'brine',
#   ',',
#   'olive',
#   ',',
#   'green',
#   'olive',
#   ',',
#   'stargaz',
#   'lili',
#   ',',
#   'orange_peel',
#   'and',
#   'crush',
#   'gravel',
#   '.'],
#  ['the',
#   'smoked_meat',
#   ',',
#   'cured_meat',
#   'and',
#   'blue-fruit',
#   'flavor',
#   "do_n't",
#   'hold',
#   'back',
#   ',',
#   'bring',
#   'a',
#   'love',
#   'sens',
#   'of',
#   'textur',
#   'and',
#   'detail',
#   '.'],
#  ['it',
#   "'s",
#   'an',
#   'intens',
#   'wine',
#   'that',
#   'complet',
#   'demand',
#   'your_attent',
#   '.'],
#  ['this',
#   'bulgarian',
#   'mavrud',
#   'present',
#   'the',
#   'nose',
#   'with',
#   'suggest',
#   'of',
#   'dry',
#   'cherry',
#   ',',
#   'black',
#   'plum',
#   ',',
#   'fresh',
#   'ground',
#   'black',
#   'pepper',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'eucalyptus',
#   '.'],
#  ['in',
#   'the',
#   'mouth',
#   'it',
#   'is',
#   'balanc',
#   'with',
#   'soft',
#   'tannin',
#   'mingl',
#   'with',
#   'dry',
#   'cherry',
#   ',',
#   'cassis',
#   'and',
#   'black',
#   'plum',
#   '.'],
#  ['steel',
#   'and',
#   'perfumed',
#   ',',
#   'this',
#   'wine',
#   'see',
#   'onli',
#   '20_%',
#   'new_french',
#   'oak',
#   ',',
#   'remain',
#   'vibrant',
#   'fresh',
#   '.'],
#  ['baked',
#   'apple',
#   'and',
#   'lemon_pith',
#   'veer_into',
#   'grapefruit',
#   'on',
#   'the',
#   'palat',
#   ',',
#   'with',
#   'spice',
#   'to',
#   'the',
#   'finish',
#   'that',
#   "'s",
#   'both',
#   'brash',
#   'and',
#   'loud',
#   '.'],
#  ['undergrowth',
#   ',',
#   'scorched_earth',
#   ',',
#   'menthol',
#   'and',
#   'plum',
#   'steep',
#   'in',
#   'spirit',
#   'are',
#   'some',
#   'of',
#   'the',
#   'aroma',
#   'that',
#   'unfold',
#   'on',
#   'the',
#   'glass',
#   '.'],
#  ['the',
#   'big',
#   ',',
#   'chewi',
#   'palat_dole',
#   'out',
#   'ripe',
#   'wild',
#   'cherry',
#   ',',
#   'raspberry',
#   'jam',
#   ',',
#   'ground',
#   'pepper',
#   'and',
#   'licorice',
#   'alongsid',
#   'firm',
#   ',',
#   'velvety',
#   'tannin',
#   '.'],
#  ['you_ll',
#   'also_detect',
#   'the',
#   'warm',
#   'of',
#   'alcohol',
#   'on',
#   'the',
#   'finish',
#   '.'],
#  ['the',
#   'aroma',
#   'entic',
#   'with',
#   'note',
#   'of',
#   'wet_rocks',
#   ',',
#   'honeysuckle',
#   ',',
#   'chamomile',
#   'and',
#   'stone',
#   'fruit',
#   '.'],
#  ['the',
#   'palat',
#   'is',
#   'generous',
#   'in',
#   'flavor',
#   'and',
#   'feel',
#   ',',
#   'show',
#   'a',
#   'fine',
#   'sens',
#   'of',
#   'balanc',
#   '.'],
#  ['forest_floor',
#   ',',
#   'till_soil',
#   ',',
#   'matur',
#   'berry',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'new',
#   'leather',
#   'combin',
#   'on',
#   'this',
#   '.'],
#  ['the',
#   'ripe',
#   'palat',
#   'offer',
#   'fleshy',
#   'black',
#   'cherry',
#   ',',
#   'dry',
#   'aromat',
#   'herb',
#   'and',
#   'tobacco',
#   ',',
#   'while',
#   'fine-grain_tannin',
#   'give',
#   'the',
#   'finish',
#   'some',
#   'gripping',
#   '.'],
#  ['drink', '2018–2023', '.'],
#  ['gingeri',
#   'spice',
#   'note',
#   'accent',
#   'fresh',
#   'pear',
#   'and',
#   'melon',
#   'fruit',
#   'in',
#   'this',
#   'medium-',
#   'to',
#   'full-bodi',
#   'wine',
#   '.'],
#  ['it',
#   "'s",
#   'round',
#   'on',
#   'the',
#   'palat',
#   'but',
#   'not',
#   'flabby',
#   ',',
#   'with',
#   'a',
#   'warm',
#   ',',
#   'spice',
#   'finish',
#   '.'],
#  ['drink_now', '.'],
#  ['aroma',
#   'of',
#   'forest_floor',
#   ',',
#   'violet',
#   ',',
#   'red',
#   'berry',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'dark',
#   'baked',
#   'spice',
#   'unfold',
#   'in',
#   'the',
#   'glass',
#   'while',
#   'wild',
#   'cherry',
#   ',',
#   'black',
#   'raspberry',
#   ',',
#   'ground',
#   'pepper',
#   'and',
#   'star_anise',
#   'drive',
#   'the',
#   'palat',
#   '.'],
#  ['frame',
#   'in',
#   'firm',
#   ',',
#   'fine-grain_tannin',
#   ',',
#   'this',
#   'is',
#   'a',
#   'classic',
#   'tuscan',
#   'red',
#   '.'],
#  ['drink', 'through_2020', '.'],
#  ['this',
#   'has',
#   'a',
#   'charm',
#   'nose',
#   'that',
#   'boast',
#   'rose',
#   ',',
#   'violet',
#   'and',
#   'red',
#   'berry',
#   'while',
#   'the',
#   'juicy',
#   ',',
#   'easy-drink',
#   'palat',
#   'offer',
#   'ripe',
#   'wild',
#   'cherry',
#   ',',
#   'mint',
#   ',',
#   'white',
#   'pepper',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'star_anise',
#   '.'],
#  ['there',
#   'is',
#   "n't",
#   'much',
#   'complex',
#   'but',
#   'it',
#   'is',
#   'savory',
#   'and',
#   'balanc',
#   ',',
#   'with',
#   'fresh',
#   'acid',
#   'and',
#   'supple',
#   'tannin',
#   '.'],
#  ['this',
#   'bright',
#   ',',
#   'savory',
#   'wine',
#   'deliv',
#   'aroma',
#   'and',
#   'flavor',
#   'of',
#   'juicy',
#   'wild',
#   'cherry',
#   ',',
#   'black',
#   'raspberry',
#   ',',
#   'violet',
#   ',',
#   'white',
#   'pepper',
#   'and',
#   'coffee',
#   '.'],
#  ['polished', 'tannin', 'provid', 'the', 'framework', '.'],
#  ['enjoy', 'through_2020', '.'],
#  ['earth',
#   'plum',
#   'and',
#   'cherry',
#   'aroma',
#   'score',
#   'point',
#   'for',
#   'be',
#   'clear',
#   'and',
#   'direct',
#   '.'],
#  ['the',
#   'palat',
#   'on',
#   'this',
#   'variet',
#   'mencía',
#   'is',
#   'round',
#   ',',
#   'smooth',
#   'and',
#   'just',
#   'right',
#   '.'],
#  ['light_bodied',
#   'brine',
#   ',',
#   'earth',
#   'plum',
#   'and',
#   'cherry',
#   'flavor',
#   'hold_steadi',
#   'on',
#   'the',
#   'finish',
#   ',',
#   'with',
#   'a',
#   'dash',
#   'of',
#   'salt',
#   '.'],
#  ['this',
#   'come_across',
#   'wide',
#   'and',
#   'expansive',
#   'as',
#   'it',
#   'lazili',
#   'exud',
#   'oily',
#   'aroma',
#   'of',
#   'hazelnut',
#   'and',
#   'toffee',
#   '.'],
#  ['a',
#   'plump',
#   'palat',
#   'is',
#   'not',
#   'over',
#   'cut',
#   'or',
#   'demand',
#   ',',
#   'while',
#   'flavor',
#   'of',
#   'light_bodied',
#   'salt_nut',
#   'and',
#   'buttery_toast',
#   'end',
#   'with',
#   'toffee',
#   'and',
#   'peanut',
#   'flavor',
#   '.'],
#  ['this',
#   'is',
#   'an',
#   'aromat',
#   'brooder',
#   'with',
#   'aroma',
#   'of',
#   'scorched_earth',
#   ',',
#   'plum',
#   ',',
#   'dry',
#   'flower',
#   'and',
#   'green',
#   'herb',
#   '.'],
#  ['it',
#   "'s",
#   'full',
#   'in',
#   'feel',
#   'with',
#   'dense',
#   ',',
#   'dark-fruit',
#   'flavor',
#   ',',
#   'tight_coil',
#   'tannin',
#   'and',
#   'tart',
#   'acids—a',
#   'pleas',
#   'exampl',
#   'of',
#   'the',
#   'varieti',
#   '.'],
#  ['aroma',
#   'of',
#   'dark-skin_berri',
#   ',',
#   'rose',
#   'and',
#   'wild',
#   'herb',
#   'lead',
#   'the',
#   'nose',
#   '.'],
#  ['the',
#   'round',
#   ',',
#   'juicy',
#   'palat_dole',
#   'out',
#   'ripe',
#   'black',
#   'cherry',
#   ',',
#   'fleshy',
#   'raspberry',
#   ',',
#   'white',
#   'pepper',
#   'and',
#   'clove',
#   'while',
#   'polished',
#   'tannin',
#   'provid',
#   'a',
#   'smooth',
#   ',',
#   'velvety',
#   'framework',
#   '.'],
#  ['enjoy', 'through_2019', '.'],
#  ['dark',
#   'in',
#   'color',
#   'and',
#   'in',
#   'flavor',
#   'profil',
#   ',',
#   'this',
#   'medium-bodi',
#   'corna',
#   'boast',
#   'aroma',
#   'and',
#   'flavor',
#   'reminisc',
#   'of',
#   'chocol_fudg',
#   ',',
#   'coffee',
#   'and',
#   'plum',
#   'fruit',
#   ',',
#   'all',
#   'frame',
#   'by',
#   'soft',
#   ',',
#   'dust',
#   'tannin',
#   '.'],
#  ['drink_now–2025', '.'],
#  ['a',
#   'blend',
#   'of',
#   '90_%',
#   'sangioves',
#   'and',
#   '10_%',
#   'canaiolo',
#   ',',
#   'this',
#   'open',
#   'with',
#   'aroma',
#   'of',
#   'violet',
#   ',',
#   'matur',
#   'plum',
#   ',',
#   'coffee',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'forest_floor',
#   '.'],
#  ['the',
#   'firm',
#   'palat',
#   'offer',
#   'dry',
#   'black',
#   'cherry',
#   ',',
#   'ground',
#   'pepper',
#   ',',
#   'toast',
#   'and',
#   'clove',
#   'while',
#   'pack',
#   ',',
#   'fine-grain_tannin',
#   'provid',
#   'support',
#   '.'],
#  ['drink', 'through_2020', '.'],
#  ['earth',
#   ',',
#   'ripe',
#   'berry',
#   ',',
#   'baked',
#   'spice',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'menthol',
#   'meld',
#   'in',
#   'the',
#   'glass',
#   '.'],
#  ['the',
#   'juicy',
#   'palat',
#   'offer',
#   'red',
#   'cherry',
#   ',',
#   'pomegranate',
#   ',',
#   'star_anise',
#   ',',
#   'coffee',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'tobacco',
#   'alongsid_fine-grain',
#   'tannin',
#   '.'],
#  ['blend',
#   'with',
#   '9_%',
#   'malbec',
#   ',',
#   '9_%',
#   'cabernet_franc',
#   'and',
#   '5_%',
#   'petit_verdot',
#   ',',
#   'this',
#   'is',
#   'a',
#   'perenni',
#   'classic',
#   'for',
#   'the',
#   'wineri',
#   ',',
#   'the',
#   'sister',
#   'brand',
#   'of',
#   'cuvaison',
#   '.'],
#  ['juicy',
#   'in',
#   'cherry',
#   'and',
#   'cassis',
#   ',',
#   'it',
#   'sustain',
#   'big',
#   ',',
#   'pillowy',
#   'tannin',
#   'and',
#   'tar',
#   ',',
#   'suggest',
#   'more',
#   'time',
#   'for',
#   'the',
#   'fruit',
#   'to',
#   'match',
#   'up',
#   'with',
#   'the',
#   'structur',
#   '.'],
#  ['drink', 'through_2020', '.'],
#  ['ripe',
#   'dark-skin_berri',
#   ',',
#   'forest_floor',
#   'and',
#   'cooked',
#   'spice',
#   'aroma',
#   'lead',
#   'the',
#   'nose',
#   'along',
#   'with',
#   'a',
#   'whiff',
#   'of',
#   'new',
#   'leather',
#   '.'],
#  ['the',
#   'chewi',
#   'palat',
#   'offer',
#   'fleshy',
#   'black',
#   'cherry',
#   ',',
#   'cinnamon',
#   ',',
#   'vanilla',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'tobacco',
#   'while',
#   'polished',
#   'tannin',
#   'provid',
#   'the',
#   'framework',
#   '.'],
#  ['this',
#   'is',
#   'alreadi_access',
#   'so',
#   'no',
#   'need',
#   'to',
#   'cellar',
#   'it',
#   'for',
#   'year',
#   '.'],
#  ['best', 'through_2021', '.'],
#  ['the',
#   'aroma',
#   'of',
#   'blue',
#   'fruit',
#   ',',
#   'herb',
#   'and',
#   'spice',
#   'are',
#   'initi',
#   'under',
#   'tight',
#   'restrained',
#   '.'],
#  ['the',
#   'flavor',
#   'are',
#   'full',
#   ',',
#   'with',
#   'the',
#   'tannin',
#   'simultan',
#   'firm',
#   'and',
#   'fine',
#   'grain',
#   '.'],
#  ['it', 'show', 'good', 'length', '.'],
#  ['this',
#   'robust',
#   'red',
#   'open',
#   'with',
#   'aroma',
#   'of',
#   'coffee',
#   ',',
#   'plum',
#   'cake',
#   ',',
#   'toast',
#   'and',
#   'dark',
#   'spice',
#   '.'],
#  ['the',
#   'hearty',
#   'palat',
#   'offer',
#   'blackberry',
#   'jam',
#   ',',
#   'licorice',
#   ',',
#   'vanilla',
#   'and',
#   'coffee',
#   'alongsid',
#   'firm',
#   'fine-grain_tannin',
#   '.'],
#  ['a', 'coffee', 'note', 'closed', 'the', 'finish', '.'],
#  ['this',
#   'structur',
#   ',',
#   'complex',
#   'chardonnay',
#   'is',
#   'pack',
#   'with',
#   'minerality',
#   'and',
#   'consider',
#   'weight',
#   '.'],
#  ['the',
#   'tight',
#   'textur',
#   'and',
#   'almost',
#   'tannin',
#   'charact',
#   'will',
#   'soften',
#   'over',
#   'the',
#   'next_few',
#   'month',
#   '.'],
#  ['full',
#   'of',
#   'potenti',
#   ',',
#   'it',
#   "'s",
#   'drinkabl',
#   'now',
#   'but',
#   'will',
#   'be',
#   'so',
#   'much',
#   'better',
#   'from_2017',
#   '.'],
#  ['this',
#   'ripe',
#   ',',
#   'full-bodi',
#   'wine',
#   'has',
#   'ripe',
#   'green',
#   'fruit',
#   'that',
#   'are',
#   'lift',
#   'by',
#   'lime',
#   'and',
#   'made',
#   'rich',
#   'by',
#   'apricot',
#   '.'],
#  ['still',
#   'young',
#   ',',
#   'with',
#   'a',
#   'concentrated',
#   'structur',
#   ',',
#   'it',
#   "'s",
#   'go',
#   'to',
#   'develop',
#   'into',
#   'a',
#   'full',
#   ',',
#   'beauti',
#   'fruit',
#   'wine',
#   '.'],
#  ['the',
#   'name',
#   'of',
#   'the',
#   'wine',
#   'mean',
#   'the',
#   'size',
#   'of',
#   'a',
#   'parcel',
#   'that',
#   'demand',
#   'the',
#   'work',
#   'of',
#   'seven',
#   'men',
#   'for',
#   'a',
#   'day',
#   '.'],
#  ['drink', 'from_2017', '.'],
#  ['with',
#   'it',
#   'light_bodied',
#   'color',
#   'and',
#   'cool',
#   'feel',
#   ',',
#   'this',
#   'well-balanc',
#   'wine',
#   'come',
#   'from',
#   'a',
#   'parcel',
#   'of',
#   '30-year-old_vine',
#   '.'],
#  ['the',
#   'smoke',
#   'tannin',
#   'and',
#   'intens',
#   'acid',
#   'give',
#   'a',
#   'wine',
#   'that',
#   'will',
#   'develop',
#   'well',
#   'and',
#   'slowli',
#   '.'],
#  ['it',
#   "'s",
#   'still',
#   'young',
#   'with',
#   'it',
#   'red-berri',
#   'fruit',
#   'and',
#   'fresh',
#   'aftertast',
#   '.'],
#  ['drink', 'from_2018', '.'],
#  ['there',
#   "'s",
#   'a',
#   'lot',
#   'to',
#   'like',
#   'in',
#   'this',
#   'nice',
#   'price',
#   'white',
#   ',',
#   'a',
#   'blend',
#   'of',
#   'sever',
#   'region',
#   'vineyard',
#   '.'],
#  ['a',
#   'tast',
#   'of',
#   'hazelnut',
#   'expand',
#   'on',
#   'the',
#   'palat',
#   'to',
#   'meet',
#   'cream',
#   'tahitian',
#   'vanilla',
#   '.'],
#  ['approach',
#   'round',
#   ',',
#   'this',
#   'crowd-pleas',
#   'wine',
#   'finish',
#   'in',
#   'measur',
#   ',',
#   'integr',
#   'oak',
#   '.'],
#  ['a',
#   'blend',
#   'of',
#   'cabernet',
#   'from',
#   'grand',
#   'ciel',
#   '(',
#   '31_%',
#   ')',
#   ',',
#   'ciel_du',
#   'cheval',
#   '(',
#   '30_%',
#   ')',
#   ',',
#   'upchurch',
#   '(',
#   '28_%',
#   ')',
#   'and',
#   'klipsun',
#   '(',
#   '11_%',
#   ')',
#   'vineyard',
#   ',',
#   'wood',
#   'spice',
#   'aroma',
#   'start_out',
#   'up_front',
#   '.'],
#  ['the',
#   'cherry',
#   'flavor',
#   'are',
#   'light_bodied',
#   'and',
#   'elegant',
#   ',',
#   'with',
#   'the',
#   'tannin',
#   'bring',
#   'some',
#   'gripping',
#   '.'],
#  ['delici',
#   'while',
#   'also',
#   'young',
#   'and',
#   'textur',
#   ',',
#   'this',
#   'wine',
#   'come',
#   'from',
#   'biodynam_grown',
#   'grape',
#   '.'],
#  ['it',
#   'has',
#   'a',
#   'strong',
#   'sens',
#   'of',
#   'minerality',
#   'as',
#   'well',
#   'as',
#   'intens',
#   'citrus',
#   'and',
#   'green',
#   'fruit',
#   '.'],
#  ['it',
#   "'s",
#   'tight',
#   'at',
#   'the',
#   'moment',
#   'and',
#   'need',
#   'to',
#   'round',
#   'out',
#   ',',
#   'so',
#   'drink',
#   'from_2018',
#   '.'],
#  ['while',
#   'exuberant',
#   'fruit',
#   ',',
#   'almost',
#   'tropical_fruit',
#   'on',
#   'the',
#   'nose',
#   ',',
#   'there',
#   "'s",
#   'a',
#   'minerality',
#   'edgy',
#   'to',
#   'this',
#   'dry',
#   'riesl',
#   'that',
#   'render',
#   'it',
#   'especi',
#   'refreshing',
#   '.'],
#  ['it',
#   "'s",
#   'vibrant',
#   'and',
#   'light_bodied',
#   'foot',
#   ',',
#   'brighten',
#   'by',
#   'a',
#   'linger',
#   'honey',
#   'note',
#   'on',
#   'the',
#   'finish',
#   '.'],
#  ['cabernet',
#   'make',
#   'up',
#   'just',
#   'over',
#   'half',
#   'of',
#   'this',
#   'blend',
#   '.'],
#  ['aroma',
#   'of',
#   'black',
#   'cherry',
#   ',',
#   'herb',
#   'and',
#   'minerality',
#   'are',
#   'follow_by',
#   'plush-feel',
#   'dark-fruit',
#   'flavor',
#   'and',
#   'back_by',
#   'firm',
#   'tannin',
#   '.'],
#  ['drink_now', '.'],
#  ['this',
#   'savory',
#   'blend',
#   'of',
#   '40_%',
#   'merlot',
#   ',',
#   '30_%',
#   'cabernet_sauvignon',
#   ',',
#   '25_%',
#   'cabernet_franc',
#   'and',
#   '5_%',
#   'syrah',
#   'open',
#   'with',
#   'aroma',
#   'of',
#   'roast',
#   'coffee',
#   ',',
#   'leather',
#   ',',
#   'tobacco',
#   'and',
#   'dark',
#   'woody_berry',
#   '.'],
#  ['the',
#   'chewi',
#   'palat',
#   'offer',
#   'juicy',
#   'plum',
#   ',',
#   'cassis',
#   'and',
#   'clove',
#   'alongsid',
#   'polished',
#   'tannin',
#   '.'],
#  ['drink', 'through_2019', '.'],
#  ['concentrated',
#   ',',
#   'ripe',
#   'blackberry',
#   'and',
#   'cassis',
#   'aroma',
#   'come',
#   'with',
#   'pepper',
#   'spice',
#   'and',
#   'cedar',
#   'oak',
#   'note',
#   '.'],
#  ['this',
#   'is',
#   'big',
#   'and',
#   'generous',
#   'on',
#   'the',
#   'palat',
#   ',',
#   'with',
#   'roast',
#   ',',
#   'well-oak',
#   'blackberry',
#   'flavor',
#   '.'],
#  ['a', 'touch', 'of', 'hot', 'lend', 'sizzling', 'to', 'the', 'finish', '.'],
#  ['drink', 'through_2020', '.'],
#  ['moorooduc',
#   "'s",
#   'estat',
#   'pinot_noir',
#   'is',
#   'a',
#   'solid',
#   'valu',
#   'among',
#   'the',
#   'boutiqu',
#   'offer',
#   'from',
#   'the',
#   'mornington',
#   'peninsula',
#   '.'],
#  ['there',
#   "'s",
#   'a',
#   'supple',
#   'cushion',
#   'of',
#   'flesh',
#   'wrap_around',
#   'a',
#   'firm',
#   'backbon',
#   'of',
#   'acid',
#   ',',
#   'while',
#   'the',
#   'flavor',
#   'run',
#   'from',
#   'black',
#   'cherry',
#   'and',
#   'mint',
#   'through',
#   'earthy',
#   'note',
#   'of',
#   'brown_sugar',
#   'and',
#   'roast_parsnip',
#   '.'],
#  ['drink_now', 'through_2020', '.'],
#  ['smoke',
#   'aroma',
#   'of',
#   'fresh-cut',
#   'wood',
#   'blend',
#   'with',
#   'berry',
#   'and',
#   'cassis',
#   'form',
#   'a',
#   'welcom',
#   ',',
#   'generous',
#   'flower',
#   '.'],
#  ['this', 'feel', 'live', 'on', 'the', 'palat', ',', 'albeit', 'tartar', '.'],
#  ['oak',
#   'plum',
#   ',',
#   'cassis',
#   'and',
#   'vanilla',
#   'flavor',
#   'finish',
#   'full',
#   'and',
#   'agreeabl',
#   '.'],
#  ['drink', 'through_2019', '.'],
#  ["l'homm",
#   'mort',
#   'is',
#   'a',
#   'northern',
#   'extens',
#   'of',
#   'the',
#   'fourchaum_premier',
#   'cru',
#   'vineyard',
#   ',',
#   'so',
#   'call',
#   'becaus',
#   'this',
#   'was',
#   'where',
#   'a',
#   'local',
#   'lord',
#   'dispens',
#   'justic',
#   'by',
#   'death',
#   '.'],
#  ['it', 'often', 'produc', 'cooler', 'wine', 'such', 'as', 'this', '.'],
#  ['it',
#   'is',
#   'tight',
#   ',',
#   'with',
#   'toast',
#   'hint',
#   'and',
#   'with',
#   'a',
#   'strong',
#   'tangy',
#   'charact',
#   '.'],
#  ['it',
#   'doe',
#   'need',
#   'to',
#   'develop',
#   'and',
#   'should',
#   "n't",
#   'be_drunk',
#   'befor_2018',
#   '.'],
#  ['this', 'is', 'a', 'super-rip', ',', 'still', 'veri', 'young', 'wine', '.'],
#  ['it',
#   "'s",
#   'show',
#   'all',
#   'it',
#   'concentrated',
#   'fruit',
#   ',',
#   'wood',
#   'age',
#   'flavor',
#   'and',
#   'dense',
#   'textur',
#   'as',
#   'well',
#   'as',
#   'the',
#   'firm',
#   'tannin',
#   'that',
#   'will',
#   'allow',
#   'it',
#   'to',
#   'age',
#   '.'],
#  ['with',
#   'it',
#   'combin',
#   'of',
#   'black',
#   'plum',
#   'skin',
#   ',',
#   'blackberry',
#   'and',
#   'dark',
#   'concentrated',
#   ',',
#   'leav',
#   'the',
#   'wine',
#   'until_2018',
#   '.'],
#  ['fresh',
#   'boysenberry',
#   'and',
#   'a',
#   'blueberry',
#   'sorbet',
#   'charact',
#   'mix',
#   'with',
#   'note',
#   'of',
#   'mint',
#   'tarragon',
#   ',',
#   'dill',
#   'and',
#   'hot',
#   'gravel',
#   'on',
#   'the',
#   'nose',
#   'of',
#   'this',
#   'wine',
#   ',',
#   'from',
#   'an',
#   'area',
#   'between',
#   'gilroy',
#   'and',
#   'morgan_hill',
#   '.'],
#  ['pepper',
#   'are',
#   'promin',
#   'on',
#   'the',
#   'relat',
#   'light_bodied',
#   'palat',
#   ',',
#   'along',
#   'with',
#   'tobacco',
#   ',',
#   'coffee',
#   'and',
#   'boysenberry',
#   '.'],
#  ['the',
#   'steel',
#   'charact',
#   'of',
#   'a',
#   'young',
#   'chabli',
#   'is',
#   'veri',
#   'appar',
#   'in',
#   'this',
#   'wine',
#   '.'],
#  ['it',
#   'is',
#   'crisp',
#   ',',
#   'lemon',
#   'flavor',
#   'and',
#   'with',
#   'a',
#   'minerality',
#   'edgy',
#   '.'],
#  ['the',
#   'wine',
#   'has',
#   'a',
#   'juicy',
#   'fresh',
#   ',',
#   'still',
#   'young',
#   'at',
#   'heart',
#   'and',
#   'need',
#   'to',
#   'age',
#   '.'],
#  ['drink', 'from_2018', '.'],
#  ['from',
#   'the',
#   'produc',
#   "'s",
#   'monument',
#   'atlas_peak',
#   'vineyard',
#   ',',
#   'this',
#   'is',
#   'a',
#   'tight',
#   ',',
#   'solid',
#   'construct',
#   'mountain',
#   'cab',
#   ',',
#   'blend',
#   'with',
#   'a',
#   'hand',
#   'of',
#   'petit_verdot',
#   '.'],
#  ['tobacco',
#   ',',
#   'black',
#   'tea',
#   'and',
#   'a',
#   'sliver',
#   'of',
#   'coconut',
#   'intermingl',
#   'around',
#   'a',
#   'medium-bodi',
#   'whole',
#   'that',
#   'will_benefit',
#   'from',
#   'cellar',
#   ',',
#   'through_2021',
#   '.'],
#  ['big',
#   ',',
#   'full_bodied',
#   ',',
#   'dark',
#   'and',
#   'chewi',
#   ',',
#   'this',
#   'build_upon',
#   'substanti',
#   'black-cherri',
#   'fruit',
#   'and',
#   'support',
#   'acid',
#   '.'],
#  ['still',
#   'knit_togeth',
#   ',',
#   'it',
#   'show',
#   'highlight',
#   'of',
#   'cedar',
#   'and',
#   'tobacco',
#   ',',
#   'along',
#   'with',
#   'thick',
#   'tannin',
#   '.'],
#  ['give',
#   'this',
#   'a',
#   'coupl',
#   'more',
#   'year',
#   'of',
#   'bottl',
#   'age',
#   ',',
#   'and',
#   'drink',
#   'after_2018',
#   '.'],
#  ['a',
#   'juicy',
#   'of',
#   'cherry',
#   'and',
#   'vanilla',
#   'spark',
#   'the',
#   'open',
#   'of',
#   'this',
#   'wine',
#   ',',
#   'a',
#   'celebr',
#   'of',
#   'the',
#   'vintag',
#   ',',
#   'appel',
#   'and',
#   'in',
#   'this',
#   'case',
#   ',',
#   'fruit-forward',
#   'of',
#   'the',
#   'varieti',
#   '.'],
#  ['with',
#   'a',
#   'backbon',
#   'of',
#   'oak',
#   'and',
#   'cedar',
#   ',',
#   'it',
#   'has',
#   'smooth',
#   'tannin',
#   'and',
#   'medium_bodied',
#   ',',
#   'finish',
#   'in',
#   'coffee',
#   'chocolate',
#   '.'],
#  ['drink_now', 'through_2022', '.'],
#  ['sweet',
#   'tannin',
#   'highlight',
#   'a',
#   'depth',
#   'of',
#   'chocolate',
#   'and',
#   'blackberry',
#   'in',
#   'this',
#   '100_%',
#   'variet',
#   'wine',
#   'made',
#   'in',
#   'small_amount',
#   '.'],
#  ['soft',
#   'and',
#   'juicy',
#   ',',
#   'it',
#   'craft',
#   'a',
#   'balanc',
#   'of',
#   'rich',
#   'and',
#   'dense',
#   'around',
#   'elegant',
#   'spice',
#   'clove',
#   'and',
#   'cinnamon',
#   '.'],
#  ['this',
#   'wine',
#   'draw',
#   'from',
#   'a',
#   'hand',
#   'of',
#   'tremend',
#   'vineyard_site',
#   ',',
#   'includ',
#   'the',
#   'produc',
#   "'s",
#   'estat',
#   ',',
#   'platt',
#   'and',
#   'clari',
#   'ranch',
#   ',',
#   'all',
#   'cool-clim',
#   'and',
#   'windswept',
#   '.'],
#  ['it',
#   "'s",
#   'a',
#   'tight',
#   ',',
#   'light_bodied',
#   'and',
#   'minim',
#   'messed-with',
#   'wine',
#   ',',
#   'bright',
#   'in',
#   'cherry',
#   ',',
#   'pomegranate',
#   'and',
#   'rose',
#   '.'],
#  ['this',
#   'offer',
#   'aroma',
#   'of',
#   'red',
#   'rose',
#   ',',
#   'wild_berry',
#   ',',
#   'dark',
#   'cooked',
#   'spice',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'sun',
#   'baked',
#   'earth',
#   '.'],
#  ['the',
#   'ripe',
#   'palat',
#   'offer',
#   'black',
#   'cherry',
#   'marin',
#   'in',
#   'spirit',
#   ',',
#   'licorice',
#   ',',
#   'game',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'chocolate',
#   'alongsid',
#   'velvety',
#   'tannin',
#   '.'],
#  ['the', 'warm', 'of', 'alcohol', 'closed', 'the', 'finish', '.'],
#  ['drink', '2018–2029', '.'],
#  ['massiv',
#   'fruit',
#   ',',
#   'this',
#   'is',
#   'an',
#   'apple/pear',
#   'bonanza',
#   ',',
#   'fleshy',
#   'and',
#   'almost',
#   'lascivi',
#   'delici',
#   '.'],
#  ['the',
#   'huge',
#   'fruit',
#   'flavor',
#   'convey',
#   'an',
#   'impress',
#   'of',
#   'sweet',
#   ',',
#   'though',
#   'this',
#   'is',
#   'not',
#   'identifi',
#   'as',
#   'off',
#   'dry',
#   '.'],
#  ['it', 'has', 'tremend', 'dense', 'and', 'length', '.'],
#  ['it',
#   'is',
#   'the',
#   'ripe',
#   'dark',
#   'alicant',
#   'bouschet',
#   'that',
#   'domin',
#   'this',
#   'firm',
#   'structur',
#   'wine',
#   '.'],
#  ['it',
#   'is',
#   'pack',
#   'with',
#   'tannin',
#   'along',
#   'with',
#   'a',
#   'huge',
#   'dense',
#   'textur',
#   'and',
#   'concentrated',
#   'juicy',
#   'berry',
#   'flavor',
#   '.'],
#  ['it', 'is', 'veri', 'firm', ',', 'still', 'young', '.'],
#  ['wait_until', '2017', '.'],
#  ['an',
#   'elegant',
#   'blend',
#   'from',
#   'differ',
#   'estat_vineyard',
#   ',',
#   'this',
#   'wide_avail',
#   'cuvé',
#   'bring',
#   'sturdy',
#   'tannin',
#   'and',
#   'red',
#   'currant',
#   'fruit',
#   ',',
#   'highlight',
#   'with',
#   'pretti',
#   'baked',
#   'spice',
#   '.'],
#  ['it',
#   'would_be',
#   'an',
#   'ideal_match',
#   'for',
#   'roast_duck',
#   'with',
#   'an',
#   'orange',
#   'sauc',
#   '.'],
#  ['this',
#   'wine',
#   'is',
#   'bone-dri',
#   ',',
#   'although',
#   'with',
#   'some',
#   'age',
#   'the',
#   'shock',
#   'of',
#   'the',
#   'acid',
#   'has_been',
#   'round',
#   'out',
#   'by',
#   'a',
#   'hint',
#   'of',
#   'toast',
#   '.'],
#  ['it',
#   "'s",
#   'linear',
#   ',',
#   'fresh',
#   'and',
#   'intens',
#   'crisp',
#   ',',
#   'with',
#   'citrus',
#   'and',
#   'almond',
#   'tone',
#   '.'],
#  ['drink', 'this', 'wine', 'from', 'a', 'good', 'vintag', 'now', '.'],
#  ['given',
#   'four_month',
#   'in',
#   'concret_egg',
#   ',',
#   'this',
#   'is',
#   'an',
#   'exot',
#   'crisp',
#   'and',
#   'textur',
#   'white',
#   ',',
#   'lean',
#   'and',
#   'high',
#   'in',
#   'acid',
#   'with',
#   'plenti',
#   'of',
#   'mouthcoat',
#   'bodi',
#   'to',
#   'find',
#   'it',
#   'balanc',
#   '.'],
#  ['lemon',
#   ',',
#   'grapefruit',
#   'and',
#   'tangerine',
#   'are',
#   'the',
#   'highlight',
#   ',',
#   'finish',
#   'in',
#   'refreshing',
#   'layer',
#   'of',
#   'white',
#   'peach',
#   '.'],
#  ['this', 'wine', 'over-deliv', 'in', 'qualiti', 'for', 'the', 'price', '.'],
#  ['it',
#   "'s",
#   'made',
#   'from',
#   'most',
#   'cabernet_sauvignon',
#   ',',
#   'with',
#   'hand',
#   'of',
#   'merlot',
#   ',',
#   'malbec',
#   ',',
#   'petit_verdot',
#   'and',
#   'cabernet_franc',
#   'blend',
#   'in',
#   'to',
#   'good',
#   'effect',
#   '.'],
#  ['the',
#   'whole',
#   'combin',
#   'into',
#   'layer',
#   'of',
#   'chocolate',
#   'and',
#   'graham_cracker',
#   ',',
#   'dappl',
#   'in',
#   'vanilla',
#   'and',
#   'jam',
#   '.'],
#  ['thick',
#   'tannin',
#   'suggest',
#   'a',
#   'swirl',
#   'or_two',
#   'of',
#   'the',
#   'glass',
#   '.'],
#  ['the', 'finish', 'is', 'all', 'tobacco', '.'],
#  ['undergrowth',
#   ',',
#   'smoke',
#   ',',
#   'coffee',
#   'and',
#   'dark',
#   'fruit',
#   'aroma',
#   'lead',
#   'the',
#   'nose',
#   'and',
#   'carri',
#   'over',
#   'to',
#   'the',
#   'ripe',
#   'palat',
#   'along',
#   'with',
#   'dry',
#   'black',
#   'cherry',
#   ',',
#   'licorice',
#   'and',
#   'clove',
#   '.'],
#  ['firm', ',', 'velvety', 'tannin', 'provid', 'the', 'framework', '.'],
#  ['drink_2018–2028', '.'],
#  ['generous',
#   'black-cherri',
#   'fruit',
#   'anchor',
#   'this',
#   'barrel-ag',
#   'wine',
#   'that',
#   'remain',
#   'tart',
#   'acid',
#   ',',
#   'with',
#   'pretti',
#   'accent',
#   'of',
#   'toast',
#   'and',
#   'coffee',
#   '.'],
#  ['focus',
#   ',',
#   'young',
#   'and',
#   'fresh',
#   ',',
#   'it',
#   'should',
#   'drink',
#   'optim',
#   '2018–2028',
#   '.'],
#  ['dark',
#   'red',
#   'violet',
#   'in',
#   'color',
#   ',',
#   'this',
#   'wine',
#   'has',
#   'aroma',
#   'of',
#   'cherry',
#   ',',
#   'lavender',
#   'and',
#   'rose',
#   '.'],
#  ['it',
#   'is',
#   'a',
#   'well-balanc',
#   'wine',
#   'with',
#   'flavor',
#   'of',
#   'black',
#   'cherry',
#   ',',
#   'raspberry',
#   ',',
#   'turkish_delight',
#   'and',
#   'herb',
#   'de_provenc',
#   '.'],
#  ['silky',
#   'tannin',
#   'coat',
#   'the',
#   'palat',
#   'into',
#   'the',
#   'last',
#   'finish',
#   ',',
#   'which',
#   'is',
#   'punctuat_by',
#   'a',
#   'note',
#   'of',
#   'bright',
#   'cherry',
#   '.'],
#  ['berry',
#   ',',
#   'baked',
#   'spice',
#   ',',
#   'dry',
#   'iri',
#   ',',
#   'mint',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'vanilla',
#   'come_togeth',
#   'on',
#   'this',
#   'structur',
#   'wine',
#   '.'],
#  ['on',
#   'the',
#   'palat',
#   ',',
#   'note',
#   'of',
#   'white',
#   'pepper',
#   ',',
#   'sage',
#   ',',
#   'anise',
#   ',',
#   'orange_peel',
#   'and',
#   'yellow',
#   'peach',
#   'accent',
#   'the',
#   'red',
#   'cherry',
#   'core',
#   'while',
#   'a',
#   'balsamic',
#   'note',
#   'closed',
#   'the',
#   'finish',
#   '.'],
#  ['firm', ',', 'refined', 'tannin', 'provid', 'the', 'backbon', '.'],
#  ['this',
#   'hearty',
#   'red',
#   'open',
#   'with',
#   'aroma',
#   'of',
#   'forest_floor',
#   ',',
#   'leather',
#   ',',
#   'licorice',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'menthol',
#   '.'],
#  ['the',
#   'firm',
#   ',',
#   'chewi',
#   'palat',
#   'offer',
#   'ripe',
#   'wild',
#   'cherry',
#   ',',
#   'raspberry',
#   'jam',
#   ',',
#   'anise',
#   'and',
#   'tobacco',
#   '.'],
#  ['brood', 'tannin', 'support', 'the', 'dark', 'flavor', '.'],
#  ['drink_2019–2029', '.'],
#  ['entic',
#   'aroma',
#   'of',
#   'woody_berry',
#   ',',
#   'crush',
#   'rose',
#   ',',
#   'mint',
#   'and',
#   'menthol',
#   'lead',
#   'the',
#   'nose',
#   'on',
#   'thisfull-bodi',
#   'red',
#   '.'],
#  ['mint',
#   'carri',
#   'over',
#   'to',
#   'the',
#   'palat',
#   'along',
#   'with',
#   'wild',
#   'cherry',
#   ',',
#   'red',
#   'raspberry',
#   ',',
#   'kitchen',
#   'spice',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'toast',
#   '.'],
#  ['assertive',
#   'tannin',
#   'and',
#   'bright',
#   'acid',
#   'hold',
#   'it',
#   'all',
#   'togeth',
#   '.'],
#  ['aroma',
#   'of',
#   'french_oak',
#   ',',
#   'coconut',
#   ',',
#   'vanilla',
#   'and',
#   'spice',
#   'plum',
#   'lead',
#   'the',
#   'nose',
#   'on',
#   'this',
#   'powerful',
#   'structur',
#   'wine',
#   '.'],
#  ['the',
#   'oak',
#   'sensat',
#   'carri',
#   'over',
#   'to',
#   'the',
#   'warm',
#   'palat',
#   'along',
#   'with',
#   'cherry',
#   'marin',
#   'in',
#   'spirit',
#   ',',
#   'licorice',
#   'and',
#   'menthol',
#   '.'],
#  ['brace',
#   ',',
#   'close-grain',
#   'tannin',
#   'provid',
#   'the',
#   'framework',
#   'and',
#   'need_time',
#   'to',
#   'unwind',
#   '.'],
#  ['best', 'after_2020', '.'],
#  ['this',
#   'delici',
#   ',',
#   'refreshing',
#   'wine',
#   'is',
#   'textur',
#   ',',
#   'tight',
#   'and',
#   'minerality',
#   ',',
#   'with',
#   'fruit',
#   'acid',
#   '.'],
#  ['tangy',
#   'and',
#   'crisp',
#   ',',
#   'it',
#   'has',
#   'a',
#   'tight',
#   'structur',
#   ',',
#   'touch',
#   'of',
#   'toast',
#   'along',
#   'with',
#   'apple',
#   'and',
#   'citrus',
#   'flavor',
#   '.'],
#  ['the',
#   'wine',
#   'is',
#   'still',
#   'young',
#   'and',
#   'veri',
#   'tight',
#   ',',
#   'so',
#   'should',
#   'not',
#   'be_drunk',
#   'befor',
#   '2017',
#   '.'],
#  ['from',
#   'a',
#   'multipl',
#   'of',
#   'vineyard',
#   ',',
#   'this',
#   'wine',
#   'work',
#   'and',
#   'is',
#   'a',
#   'tremend',
#   'valu',
#   'for',
#   'the',
#   'price',
#   '.'],
#  ['it',
#   'mix',
#   'hot',
#   'mulled-cid',
#   'spice',
#   ',',
#   'cinnamon',
#   ',',
#   'clove',
#   'and',
#   'pine',
#   ',',
#   'convey',
#   'surpris',
#   'depth',
#   '.'],
#  ['plum',
#   ',',
#   'dark',
#   'cherry',
#   'and',
#   'more',
#   'clove',
#   'lead',
#   'to',
#   'a',
#   'powerful',
#   ',',
#   'leather',
#   'finish',
#   '.'],
#  ['the',
#   'first',
#   'pinot_noir',
#   'releas',
#   'from',
#   'this',
#   'produc',
#   ',',
#   'this',
#   'is',
#   'a',
#   'velvety-smooth',
#   ',',
#   'exot',
#   'and',
#   'charm',
#   'wine',
#   ',',
#   'light_bodied',
#   'on',
#   'the',
#   'palat',
#   'despit',
#   'a',
#   'concentrated',
#   'of',
#   'ripe',
#   ',',
#   'rich',
#   'fruit',
#   '.'],
#  ['kirsch',
#   ',',
#   'cherry',
#   ',',
#   'raspberry',
#   'and',
#   'cinnamon',
#   'combin',
#   'to',
#   'make',
#   'the',
#   'wine',
#   'invit',
#   'lush',
#   'and',
#   'plush',
#   '.'],
#  ['a',
#   'red',
#   'meritag',
#   'driven_by',
#   '73_%',
#   'cabernet_sauvignon',
#   ',',
#   'this',
#   'structur',
#   ',',
#   'full-bodi',
#   'wine',
#   'also',
#   'blend',
#   'in',
#   '19_%',
#   'merlot',
#   ',',
#   '3_%',
#   'petit_verdot',
#   'and',
#   '3_%',
#   'malbec',
#   '.'],
#  ['blackberry',
#   'and',
#   'chocolate',
#   'accent',
#   'chalk',
#   'tannin',
#   ',',
#   'with',
#   'full_bodied',
#   'hit',
#   'of',
#   'black',
#   'licorice',
#   ',',
#   'cassis',
#   ',',
#   'pencil',
#   'and',
#   'black',
#   'tea',
#   '.'],
#  ['drink_now', 'through_2020', '.'],
#  ['bright',
#   ',',
#   'light_bodied',
#   'oak',
#   'shade',
#   'dress_up',
#   'this',
#   'medium-bodi',
#   'wine',
#   ',',
#   'complement',
#   'the',
#   'red',
#   'cherry',
#   'and',
#   'strawberry',
#   'flavor',
#   '.'],
#  ['it',
#   "'s",
#   'fresh',
#   ',',
#   'fruit',
#   'and',
#   'not',
#   'veri',
#   'tannic—easi',
#   'to',
#   'drink',
#   'and',
#   'enjoy',
#   '.'],
#  ['the',
#   'local',
#   'baga_grape',
#   ',',
#   'better_known',
#   'for',
#   'produc',
#   'structur',
#   'red',
#   'wine',
#   ',',
#   'also',
#   'lend_itself',
#   'to',
#   'fruit',
#   'sparkling',
#   'rosé',
#   '.'],
#  ['bright',
#   'acid',
#   'give',
#   'this',
#   'crisp',
#   'wine',
#   'it',
#   'tangy',
#   ',',
#   'red',
#   'currant',
#   'charact',
#   '.'],
#  ['drink_now', '.'],
#  ['aroma',
#   'of',
#   'white',
#   'spring_flower',
#   ',',
#   'orchard',
#   'fruit',
#   'and',
#   'citrus',
#   'spill',
#   'out',
#   'of',
#   'the',
#   'glass',
#   '.'],
#  ['the',
#   'fun',
#   'live',
#   'palat',
#   'deliv',
#   'ripe',
#   'yellow',
#   'peach',
#   'and',
#   'green',
#   'apple',
#   'alongsid',
#   'a',
#   'foamy',
#   'mousse',
#   '.'],
#  ['a',
#   'smoke',
#   'scent',
#   'and',
#   'earth',
#   ',',
#   'crisp-appl',
#   'flavor',
#   'make',
#   'this',
#   'medium-bodi',
#   'wine',
#   'a',
#   'chang',
#   'of',
#   'pace',
#   'from',
#   'the',
#   'averag',
#   'butterbal',
#   'chardonnay',
#   '.'],
#  ['it', 'has', 'welcom', 'acid', 'and', 'a', 'nice', 'smooth', 'textur', '.'],
#  ['this',
#   'family-own',
#   'estat',
#   'has',
#   'produc',
#   'an',
#   'immedi_attract',
#   'entry-level',
#   'wine',
#   '.'],
#  ['light_bodied',
#   'spice',
#   'with',
#   'wood',
#   ',',
#   'it',
#   'blend',
#   'touriga_franca',
#   ',',
#   'tinta_roriz',
#   'and',
#   'tinta',
#   'barroca',
#   'to',
#   'show',
#   'black',
#   'fruit',
#   ',',
#   'ripe',
#   'tannin',
#   'and',
#   'bright',
#   'acid',
#   '.'],
#  ['drink_now', '.'],
#  ['this',
#   'is',
#   'a',
#   'smooth',
#   ',',
#   'soft',
#   'wine',
#   'that',
#   'is',
#   'full',
#   'of',
#   'black',
#   'fruit',
#   'and',
#   'ripe',
#   'tannin',
#   '.'],
#  ['the',
#   'merlot',
#   'round',
#   'out',
#   'the',
#   'rougher',
#   'edgy',
#   'of',
#   'the',
#   'malbec',
#   'to',
#   'give',
#   'a',
#   'rich',
#   'juicy',
#   'wine',
#   'that',
#   'will',
#   'develop',
#   'quick',
#   '.'],
#  ['it',
#   'is',
#   'all',
#   'fruit',
#   ',',
#   'generous',
#   'and',
#   'readi',
#   'to',
#   'drink',
#   'from_2017',
#   '.'],
#  ['this',
#   'is',
#   'an',
#   'easygo',
#   'wine',
#   'that',
#   "'s",
#   'neither',
#   'too',
#   'oak',
#   'nor',
#   'too',
#   'crisp',
#   ',',
#   'with',
#   'a',
#   'decent',
#   'blend',
#   'of',
#   'ripe',
#   'pear',
#   'and',
#   'baked',
#   'spice',
#   'flavor',
#   'pair',
#   'with',
#   'soft',
#   ',',
#   'smooth',
#   'textur',
#   '.'],
#  ['blend',
#   'with',
#   'small_amount',
#   'of',
#   'merlot',
#   ',',
#   'cabernet_franc',
#   ',',
#   'petit_verdot',
#   'and',
#   'malbec',
#   ',',
#   'this',
#   'is',
#   'an',
#   'austere',
#   ',',
#   'unfussi',
# ...
#  ['drink', 'from', '2020', '.'],
#  ['the',
#   'aroma',
#   'pop',
#   ',',
#   'with',
#   'note',
#   'of',
#   'orange_peel',
#   ',',
#   'ember',
#   ',',
#   'cured_meat',
#   ',',
#   'black',
#   'olive',
#   'and',
#   'wet_rocks',
#   ',',
#   'with',
#   'purple',
#   'fruit',
#   'lurk',
#   'in',
#   'the',
#   'background',
#   '.'],
#  ['the',
#   'palat',
#   'is',
#   'surpris',
#   'fruit',
#   'forward',
#   ',',
#   'with',
#   'plum',
#   'and',
#   'savory',
#   'flavor',
#   'that',
#   'coat',
#   'the',
#   'palat',
#   'from',
#   'end',
#   'to',
#   'end',
#   '.'],
#  ['the', 'finish', 'glide', 'for', 'a', 'full', '30', 'second', '.'],
#  ['this',
#   'is',
#   'a',
#   'wine',
#   'that',
#   'is',
#   'begin',
#   'to',
#   'show',
#   'some',
#   'fine',
#   'matur',
#   '.'],
#  ['there',
#   'are',
#   'ripe',
#   'fruit',
#   'still',
#   'veri',
#   'present',
#   ',',
#   'but',
#   'they',
#   'are',
#   'match',
#   'by',
#   'the',
#   'secondari',
#   'flavor',
#   ',',
#   'spice',
#   'and',
#   'warm',
#   'tannin',
#   'along',
#   'with',
#   'the',
#   'classic',
#   'herb',
#   'charact',
#   'of',
#   'mourvèdr',
#   '.'],
#  ['the',
#   'wine',
#   'is',
#   'produc',
#   'from',
#   'organ_grown',
#   'grape',
#   ',',
#   'give',
#   'puriti',
#   'as',
#   'well',
#   'as',
#   'some',
#   'serious',
#   'structur',
#   'in',
#   'the',
#   'background',
#   '.'],
#  ['drink', 'from_2018', '.'],
#  ['spice',
#   'yet',
#   'sweet',
#   'aroma',
#   'of',
#   'sarsaparilla',
#   'root',
#   ',',
#   'saddle_leather',
#   'and',
#   'earth',
#   'berry',
#   'fruit',
#   'preced',
#   'a',
#   'rich',
#   'dense',
#   'palat',
#   '.'],
#  ['this',
#   'tast',
#   'of',
#   'dark',
#   'cherry',
#   'and',
#   'berry',
#   'fruit',
#   ',',
#   'with',
#   'an',
#   'herb',
#   'shade',
#   'ad',
#   'complex',
#   '.'],
#  ['chocolate',
#   'oak',
#   'take',
#   'hold',
#   'on',
#   'a',
#   'solid',
#   'long',
#   'finish',
#   '.'],
#  ['drink', 'through_2024', '.'],
#  ['this', 'is', 'one', 'of', 'the', 'classic', 'among', 'provenc_rosé', '.'],
#  ['produc',
#   'from',
#   'organ_grown',
#   'grape',
#   'and',
#   'come',
#   'from',
#   'an',
#   'impress',
#   'red-win',
#   'produc',
#   'estat',
#   'east',
#   'of',
#   'aix-en-prov',
#   ',',
#   'the',
#   'wine',
#   'is',
#   'structur',
#   'and',
#   'ageworthi',
#   'with',
#   'it',
#   'blend',
#   'that',
#   'includ',
#   'cabernet_sauvignon',
#   '.'],
#  ['rich',
#   'and',
#   'full',
#   'of',
#   'red',
#   'fruit',
#   ',',
#   'the',
#   'wine',
#   'should_be',
#   'drunk',
#   'from',
#   'late_2017',
#   '.'],
#  ['ripe',
#   'pure',
#   'black-fruit',
#   'aroma',
#   'are',
#   'touch',
#   'up',
#   'by',
#   'note',
#   'of',
#   'malti',
#   'chocolate',
#   'and',
#   'coffee',
#   '.'],
#  ['this',
#   'is',
#   'proport',
#   'big',
#   ',',
#   'with',
#   'cheek-grab',
#   'tannin',
#   ',',
#   'but',
#   'it',
#   "'s",
#   'not',
#   'over',
#   'hard',
#   'or',
#   'unbalanced—',
#   'just',
#   'the',
#   'opposit',
#   '.'],
#  ['flavor',
#   'of',
#   'coffee',
#   ',',
#   'coffee',
#   ',',
#   'hazelnut',
#   'and',
#   'ripe',
#   'berry',
#   'fruit',
#   'finish',
#   'flush',
#   ',',
#   'dense',
#   'and',
#   'firm',
#   ',',
#   'with',
#   'toast',
#   'note',
#   'and',
#   'powerful',
#   'but',
#   'control',
#   'residu',
#   'tannin',
#   '.'],
#  ['drink', 'through_2030', '.'],
#  ['this',
#   'single-vineyard',
#   'estat',
#   'wine',
#   'is',
#   'made',
#   'by',
#   'nil',
#   'veng',
#   'and',
#   'tom',
#   'rinaldi',
#   ',',
#   'who',
#   'have',
#   'somehow_manag',
#   'to',
#   'captur',
#   'quiet',
#   'elegant',
#   'and',
#   'powerful',
#   'fruit',
#   'at',
#   'the',
#   'same_time',
#   '.'],
#  ['red-fruit',
#   'driven',
#   ',',
#   'it',
#   "'s",
#   'round',
#   'and',
#   'rich',
#   ',',
#   'with',
#   'moder',
#   'tannin',
#   'and',
#   'cassis',
#   ',',
#   'clove',
#   'and',
#   'black',
#   'pepper',
#   'highlight',
#   '.'],
#  ['this',
#   'is',
#   'an',
#   'impress',
#   'rich',
#   ',',
#   'still',
#   'veri',
#   'young',
#   'wine',
#   '.'],
#  ['domin',
#   'by',
#   'bandol',
#   "'s",
#   'own',
#   'mourvèdr',
#   'grape',
#   ',',
#   'it',
#   'is',
#   'dense',
#   'and',
#   'concentrated',
#   '.'],
#  ['spice',
#   'and',
#   'dark',
#   'red',
#   'fruit',
#   'are',
#   'shot_through',
#   'with',
#   'a',
#   'wonder',
#   'herb',
#   'charact',
#   'that',
#   'conjur',
#   'the',
#   'southern',
#   'warm',
#   '.'],
#  ['the',
#   'wine',
#   'is',
#   'still',
#   'just',
#   'set',
#   'out',
#   'and',
#   'will',
#   'not',
#   'be',
#   'readi',
#   'to',
#   'drink',
#   'befor_2019',
#   '.'],
#  ['open-grain',
#   'oak',
#   'aroma',
#   'are',
#   'out',
#   'front',
#   ',',
#   'follow_by',
#   'sweet',
#   'scent',
#   'of',
#   'almond',
#   ',',
#   'prune',
#   'and',
#   'chocolate',
#   '.'],
#  ['a',
#   'full',
#   ',',
#   'tannin',
#   'palat',
#   'is',
#   'depth',
#   'and',
#   'dense',
#   ',',
#   'while',
#   'toast',
#   'blacken',
#   'flavor',
#   'of',
#   'cassis',
#   'and',
#   'blackberry',
#   'finish',
#   'with',
#   'note',
#   'of',
#   'coffee',
#   ',',
#   'chocolate',
#   'and',
#   'pepper',
#   '.'],
#  ['this',
#   'is',
#   'a',
#   'bit',
#   'rough',
#   'and',
#   'tannin',
#   ',',
#   'so',
#   'cellar',
#   'will',
#   'help',
#   'it',
#   'calm_down',
#   '.'],
#  ['drink', 'through_2023', '.'],
#  ['this',
#   'is',
#   'a',
#   'serious',
#   'wine',
#   'with',
#   'a',
#   'light_bodied',
#   'bright',
#   'side',
#   '.'],
#  ['it',
#   'wood',
#   'age',
#   'add',
#   'spice',
#   'to',
#   'the',
#   'ripe',
#   'red',
#   'fruit',
#   'and',
#   'bring_out',
#   'the',
#   'concentrated',
#   'and',
#   'intens',
#   '.'],
#  ['it',
#   'is',
#   ',',
#   'in',
#   'it',
#   'way',
#   ',',
#   'an',
#   'unexpect',
#   'side',
#   'of',
#   'provenc_rosé',
#   ',',
#   'emphas',
#   'rich',
#   'and',
#   'complex',
#   '.'],
#  ['but',
#   'it',
#   'all',
#   'come_togeth',
#   ':',
#   'a',
#   'fine',
#   'wine',
#   'that',
#   ',',
#   'after',
#   'a',
#   'year',
#   'of',
#   'age',
#   ',',
#   'is',
#   'readi',
#   'to',
#   'drink',
#   '.'],
#  ['from',
#   'old_vine',
#   'in',
#   'a',
#   'tree-enclos',
#   'vineyard',
#   'on',
#   'the',
#   'third',
#   'terrac',
#   'abov',
#   'the',
#   'river',
#   'lot',
#   ',',
#   'this',
#   'wine',
#   'form',
#   'part',
#   'of',
#   'a',
#   'rang',
#   'of',
#   'wine',
#   'featur',
#   'the',
#   'soil',
#   'and',
#   'terrac',
#   'of',
#   'the',
#   'cahor',
#   'vineyard',
#   '.'],
#  ['name',
#   'in',
#   'homag',
#   'to',
#   'marguerit',
#   'de',
#   'massaut',
#   ',',
#   'a',
#   '16th-centuri',
#   'owner',
#   'of',
#   'the',
#   'estat',
#   ',',
#   'the',
#   'wine',
#   'is',
#   'age',
#   'in',
#   'new',
#   'wood',
#   'that',
#   'give',
#   'it',
#   'a',
#   'mint',
#   'charact',
#   '.'],
#  ['that',
#   'is',
#   'balanc',
#   'by',
#   'the',
#   'rich',
#   'black-plum',
#   'and',
#   'truffle',
#   'flavor',
#   'and',
#   'the',
#   'intens',
#   'acid',
#   '.'],
#  ['the', 'wine', 'need', 'to', 'age', ',', 'so', 'drink', 'from', '2021', '.'],
#  ['polished',
#   'in',
#   'everi_way',
#   ',',
#   'this',
#   'bring',
#   'an',
#   'entic',
#   'potpourri',
#   'of',
#   'almond',
#   ',',
#   'apple',
#   'and',
#   'white',
#   'pepper',
#   '.'],
#  ['wild',
#   'yeast',
#   'ferment',
#   'in',
#   'oak',
#   '(',
#   '30_%',
#   'new',
#   ')',
#   'marri',
#   'complex',
#   'compon',
#   'in',
#   'perfect',
#   'precis',
#   'balanc',
#   '.'],
#  ['as',
#   'with',
#   'all',
#   'the',
#   'ponzi',
#   '2014',
#   'chardonnay',
#   ',',
#   'the',
#   'acid',
#   'are',
#   'bright',
#   'but',
#   'not',
#   'bite',
#   ',',
#   'and',
#   'the',
#   'wine',
#   'are',
#   'built',
#   'for',
#   'both',
#   'near-term',
#   'enjoy',
#   'and',
#   'medium-term_age',
#   '.'],
#  ['scent',
#   'of',
#   'woody_berry',
#   ',',
#   'rose',
#   ',',
#   'grill',
#   'herb',
#   ',',
#   'anise',
#   'and',
#   'a',
#   'balsamic',
#   'note',
#   'emerg',
#   'on',
#   'this',
#   'firm',
#   'structur',
#   'wine',
#   '.'],
#  ['on',
#   'the',
#   'robust',
#   'palat',
#   ',',
#   'white',
#   'pepper',
#   ',',
#   'licorice',
#   ',',
#   'sage',
#   'and',
#   'a',
#   'hint',
#   'of',
#   'toast',
#   'weav_through',
#   'the',
#   'black',
#   'cherry',
#   'core',
#   '.'],
#  ['you_ll',
#   'also_detect',
#   'the',
#   'warm',
#   'of',
#   'alcohol',
#   'on',
#   'the',
#   'closed',
#   '.'],
#  ['drink_2018–2028', '.'],
#  ['juicy',
#   ',',
#   'sun-kiss',
#   'grapefruit',
#   'and',
#   'apple',
#   'blossom',
#   'explod',
#   'from',
#   'this',
#   'buoyant',
#   'fresh',
#   ',',
#   'off-dri_kabinett',
#   '.'],
#  ['invigor',
#   'acid',
#   'lend',
#   'backbon',
#   'and',
#   'a',
#   'steel',
#   'focus',
#   'that',
#   'reson',
#   'long',
#   'on',
#   'the',
#   'finish',
#   '.'],
#  ['it',
#   "'s",
#   'beauti',
#   'now',
#   ',',
#   'but',
#   'should_hold',
#   'nice',
#   ',',
#   'and',
#   'perhap',
#   'improv',
#   ',',
#   'through_2020',
#   '.'],
#  ['dense',
#   ',',
#   'rich',
#   'red',
#   'fruit',
#   'beli',
#   'an',
#   'elegant',
#   'wine',
#   'that',
#   'find',
#   'balanc',
#   'despit',
#   'the',
#   'concentrated',
#   'of',
#   'vanilla',
#   'and',
#   'berry',
#   '.'],
#  ['soft',
#   ',',
#   'approach',
#   'and',
#   'integr',
#   'tannin',
#   'and',
#   'oak',
#   'let',
#   'the',
#   'whole',
#   'exist',
#   'as',
#   'one',
#   ',',
#   'instead',
#   'of',
#   'separ',
#   'part',
#   '.'],
#  ['this',
#   'show',
#   'off',
#   'the',
#   'appel',
#   "'s",
#   'mountain',
#   'fruit',
#   'and',
#   'rocky',
#   'minerality',
#   '.'],
#  ['light_bodied',
#   'lees',
#   'aroma',
#   'of',
#   'vanilla',
#   'cookie',
#   'are',
#   'offset_by',
#   'crisp',
#   'minerality',
#   'apple',
#   'and',
#   'stone-fruit',
#   'scent',
#   '.'],
#  ['this',
#   'is',
#   'pure',
#   'and',
#   'lift',
#   'by',
#   'fine',
#   'acid',
#   ',',
#   'while',
#   'flavor',
#   'of',
#   'apple',
#   ',',
#   'pineapple',
#   'and',
#   'lemon-lim',
#   'end',
#   'fresh',
#   ',',
#   'with',
#   'a',
#   'distant',
#   'note',
#   'of',
#   'citrus_pith',
#   '.'],
#  ['drink', 'immedi', '.'],
#  ['from',
#   'the',
#   'loval',
#   'valley_section',
#   'of',
#   'the',
#   'napa_valley',
#   'quit',
#   'near',
#   'sonoma',
#   ',',
#   'this',
#   'love',
#   'wine',
#   'is',
#   'awash',
#   'in',
#   'tropical_fruit',
#   'mango',
#   ',',
#   'with',
#   'lilt',
#   'of',
#   'pear',
#   'and',
#   'vanilla',
#   '.'],
#  ['cream',
#   ',',
#   'it',
#   "'s",
#   'made',
#   'in',
#   'a',
#   'fuller-bodi',
#   'style',
#   'but',
#   'never',
#   'get',
#   'ridicul',
#   ',',
#   'instead',
#   'offer',
#   'balanc',
#   'and',
#   'elegant',
#   ',',
#   'finish',
#   'with',
#   'a',
#   'squeez',
#   'of',
#   'grapefruit',
#   '.'],
#  ['the',
#   'top',
#   'wine',
#   'in',
#   'the',
#   'rocim',
#   'rang',
#   'is',
#   'produc',
#   'from',
#   'select',
#   'alicant',
#   'bouschet',
#   'grape',
#   '.'],
#  ['it',
#   'is',
#   'huge',
#   'and',
#   'powerful',
#   ',',
#   'perhap',
#   'too_much',
#   'in',
#   'it',
#   'concentrated',
#   ',',
#   'rich',
#   'and',
#   'dense',
#   '.'],
#  ['dark',
#   'and',
#   'brood',
#   ',',
#   'it',
#   'is',
#   'super',
#   'everyth',
#   'and',
#   'certain',
#   'need',
#   'to',
#   'calm_down',
#   '.'],
#  ['drink', 'from_2019', '.'],
#  ['there',
#   "'s",
#   'a',
#   'cantaloupe-lik',
#   'ripe',
#   'on',
#   'the',
#   'nose',
#   'of',
#   'this',
#   'blend',
#   'of',
#   '37_%',
#   'grenach_blanc',
#   ',',
#   '33_%',
#   'viognier',
#   'and',
#   '30_%',
#   'roussann',
#   ',',
#   'but',
#   'not_overdon',
#   ',',
#   'layer',
#   'with',
#   'sear',
#   'white',
#   'peach',
#   ',',
#   'caramel',
#   'pear',
#   ',',
#   'poach',
#   'apple',
#   'and',
#   'almond',
#   'aroma',
#   '.'],
#  ['the',
#   'palat',
#   'is',
#   'more',
#   'restrained',
#   'and',
#   'quit',
#   'grippy',
#   ',',
#   'with',
#   'flavor',
#   'of',
#   'green-appl',
#   'skin',
#   ',',
#   'pear',
#   'and',
#   'a',
#   'touch',
#   'of',
#   'honey',
#   '.'],
#  ['this',
#   'lush',
#   'offer',
#   'open',
#   'with',
#   'appeal',
#   'aroma',
#   'of',
#   'rose',
#   'and',
#   'fresh',
#   'strawberry',
#   ',',
#   'then',
#   'glide_into',
#   'a',
#   'smooth-as-silk',
#   'midpal',
#   '.'],
#  ['the',
#   'berry/cherri',
#   'fruit',
#   'is',
#   'nice',
#   'adorn',
#   'with',
#   'toast',
#   'oak',
#   'flavor',
#   ',',
#   'and',
#   'it',
#   "'s",
#   'as',
#   'satiny',
#   'as',
#   'new',
#   'sheet',
#   '.'],
#  ['you_ll',
#   'find',
#   'it',
#   'hard',
#   'to',
#   'keep',
#   'from',
#   'gulp',
#   'this',
#   'by',
#   'the',
#   'glass',
#   '.'],
#  ['a',
#   'pretti',
#   'salmon-pink',
#   'in',
#   'color',
#   ',',
#   'and',
#   'a',
#   'lovabl',
#   'quaffer',
#   ',',
#   'this',
#   'wine',
#   'is',
#   'dry',
#   ',',
#   'crisp',
#   'and',
#   'bright',
#   'refreshing',
#   'in',
#   'succulent',
#   'wave',
#   'of',
#   'grapefruit',
#   'and',
#   'tangerine',
#   ',',
#   'remark',
#   'light_bodied',
#   'in',
#   'alcohol',
#   'but',
#   'not',
#   'shi',
#   'in',
#   'flavor',
#   '.'],
#  ['enjoy',
#   'it',
#   'on',
#   'it',
#   'own',
#   'or',
#   'with',
#   'a',
#   'rang',
#   'of',
#   'foods—it',
#   'light_bodied',
#   'beget',
#   'versatil',
#   '.'],
#  ['aroma',
#   'of',
#   'slight',
#   'stew',
#   'fruit',
#   ',',
#   'steep',
#   'berry',
#   ',',
#   'spice',
#   'and',
#   'menthol',
#   'unfold',
#   'in',
#   'the',
#   'glass',
#   '.'],
#  ['the',
#   'firm',
#   'palat',
#   'deliv',
#   'juicy',
#   'cherry',
#   ',',
#   'crush',
#   'raspberry',
#   ',',
#   'licorice',
#   ',',
#   'ground',
#   'pepper',
#   'and',
#   'a',
#   'mint',
#   'note',
#   'while',
#   'brace',
#   'tannin',
#   'and',
#   'racy',
#   'acid',
#   'provid',
#   'the',
#   'backbon',
#   '.'],
#  ['this',
#   'need',
#   'a',
#   'few_more',
#   'year',
#   'to',
#   'calm_down',
#   'and',
#   'will',
#   'continu',
#   'to',
#   'age',
#   'well',
#   'for',
#   'a',
#   'decad',
#   'or',
#   'more',
#   '.'],
#  ['drink_2018–2026', '.'],
#  ['pretti',
#   'aroma',
#   'of',
#   'blue_flower',
#   ',',
#   'rose',
#   ',',
#   'wild_berry',
#   'and',
#   'graphite',
#   'lead',
#   'the',
#   'way',
#   '.'],
#  ['the',
#   'firm',
#   'palat',
#   'deliv',
#   'matur',
#   'black',
#   'cherry',
#   ',',
#   'raspberry',
#   ',',
#   'star_anise',
#   ',',
#   'black',
#   'pepper',
#   'and',
#   'chop_sage',
#   'alongsid',
#   'bright',
#   'acid',
#   'and',
#   'tight',
#   'tannin',
#   'that',
#   'need',
#   'to',
#   'unwind',
#   '.'],
#  ['drink_2018–2026', '.'],
#  ['bittersweet',
#   'at_first',
#   ',',
#   'with',
#   'sizabl',
#   'tannin',
#   ',',
#   'this',
#   'cab',
#   'also',
#   'contain',
#   '13.8',
#   '%',
#   'petit_verdot',
#   '.'],
#  ['red',
#   'and',
#   'black',
#   'berry',
#   'give',
#   'it',
#   'a',
#   'juicy',
#   'palat',
#   'atop',
#   'dust',
#   ',',
#   'chalk',
#   'tannin',
#   'and',
#   'a',
#   'rich',
#   'of',
#   'leather',
#   'and',
#   'clove',
#   'on',
#   'the',
#   'finish',
#   '.'],
#  ['aroma',
#   'of',
#   'perfumed',
#   'berry',
#   ',',
#   'mint',
#   ',',
#   'baked',
#   'spice',
#   'and',
#   'a',
#   'whiff',
#   'of',
#   'oak',
#   'emerg',
#   'on',
#   'this',
#   'structur',
#   'wine',
#   '.'],
#  ['the',
#   'firm',
#   'palat',
#   'offer',
#   'wild',
#   'red',
#   'cherry',
#   ',',
#   'crush',
#   'raspberry',
#   ',',
#   'mint',
#   ',',
#   'sage',
#   'and',
#   'a',
#   'touch',
#   'of',
#   'oak-driven',
#   'spice',
#   'alongsid_brace',
#   'tannin',
#   'and',
#   'nervous',
#   'acid',
#   '.'],
#  ['give', 'it', 'time', 'to', 'soften', 'and', 'fulli', 'develop', '.'],
#  ['drink', '2019–2031', '.'],
#  ['aroma',
#   'and',
#   'flavor',
#   'of',
#   'sandalwood',
#   'and',
#   'grenadin',
#   'layer',
#   'around',
#   'this',
#   'velvety',
#   ',',
#   'seduct',
#   'wine',
#   '.'],
#  ['it',
#   'offer',
#   'black',
#   'tea',
#   ',',
#   'truffle',
#   'and',
#   'forest_floor',
#   ',',
#   'the',
#   'bodi',
#   'sinewy',
#   'and',
#   'complex',
#   '.'],
#  ['savory',
#   'in',
#   'cinnamon',
#   'and',
#   'clove',
#   'on',
#   'the',
#   'finish',
#   ',',
#   'it',
#   'need',
#   'more',
#   'time',
#   'to',
#   'open',
#   ';',
#   'decant',
#   'or',
#   'cellar',
#   'through_2021',
#   '.'],
#  ['a',
#   'classic',
#   'northern_rhône',
#   'valley',
#   'blend',
#   'of',
#   'syrah',
#   'with',
#   'a',
#   'touch',
#   'of',
#   'viognier',
#   ',',
#   'this',
#   'massiv',
#   'wine',
#   'is',
#   'made',
#   'from',
#   'grape',
#   'grown',
#   'on',
#   'granit_soil',
#   ',',
#   'which',
#   'leav',
#   'it',
#   'mark',
#   'in',
#   'dense',
#   'minerality',
#   'and',
#   'great',
#   'powerful',
#   '.'],
#  ['it',
#   'is',
#   'a',
#   'wine',
#   'for',
#   'lover',
#   'of',
#   'the',
#   'big',
#   'stuff',
#   ',',
#   'concentrated',
#   'and',
#   'need',
#   'to',
#   'age',
#   '.'],
#  ['drink', 'from_2018', '.'],
#  ['this',
#   'is',
#   'a',
#   'rich',
#   ',',
#   'full-bodi',
#   'wine',
#   'that',
#   'is',
#   'readi',
#   'to',
#   'drink_now',
#   '.'],
#  ['it',
#   'still',
#   'has',
#   'a',
#   'dry',
#   'core',
#   'of',
#   'tannin',
#   ',',
#   'although',
#   'they',
#   'are',
#   'overwhelm',
#   'by',
#   'the',
#   'rich',
#   ',',
#   'juicy',
#   'black',
#   'fruit',
#   'and',
#   'generous',
#   'textur',
#   '.'],
#  ['it',
#   "'s",
#   'a',
#   'concentrated',
#   'wine',
#   ',',
#   'high',
#   'in',
#   'alcohol',
#   ',',
#   'although',
#   'that',
#   'is',
#   'realli',
#   'balanc',
#   'by',
#   'the',
#   'fresh',
#   'aftertast',
#   '.'],
#  ['warm',
#   'vanilla',
#   'note',
#   'are',
#   'laid_across',
#   'ripe',
#   'nectarine',
#   ',',
#   'apple',
#   'and',
#   'a',
#   'twist',
#   'of',
#   'lemon_peel',
#   'on',
#   'this',
#   'single-vineyard',
#   'studi',
#   'by',
#   'the',
#   'los',
#   'gatos-bas',
#   'wineri',
#   '.'],
#  ['pencil_lead',
#   'kick_off',
#   'the',
#   'palat',
#   ',',
#   'which',
#   'then',
#   'open',
#   'into',
#   'poach',
#   'apple',
#   'and',
#   'lemon',
#   ',',
#   'laid_across',
#   'a',
#   'sizzling',
#   'acid',
#   'that',
#   'last',
#   'long',
#   '.'],
#  ...]

# %%
#embeddings:

# %%
model = Word2Vec(processed_sents, size=300, min_count=1, iter=15)

# %%
print(model)
# Out:
# Word2Vec(vocab=39919, size=300, alpha=0.025)

# %%
print(model)
# Out:
# Word2Vec(vocab=39919, size=300, alpha=0.025)

# %%
model.wv.most_similar(positive='peach', topn=10)
# Out:
# [('peach_nectar', 0.6587433815002441),
#  ('pear', 0.6312757134437561),
#  ('lemon_curd', 0.6200466156005859),
#  ('nectarine', 0.6192095279693604),
#  ('honeydew', 0.618532121181488),
#  ('mango', 0.6031101942062378),
#  ('guava', 0.6021448373794556),
#  ('papaya', 0.6000341176986694),
#  ('grapefruit', 0.5924464464187622),
#  ('melon', 0.5872974395751953)]

# %%
#update review data to only show meaningful words
reviews = list(data['description'])
mapped_reviews = []
def mapping_wine_words(word):
    if word in list(mapping.index):
        mapped = mapping['level_3'][word]
        return mapped
for review in reviews:
    processed = process_text(review)
    phrased = grams[processed]
    mapped = [mapping_wine_words(word) for word in phrased]
    remove_none = [str(d) for d in mapped if d is not None]
    mapped_rev = ' '.join(remove_none)
    mapped_reviews.append(mapped_rev)

# %%
mapped_reviews
# Out:
# ['oak juicy fruit caramel elegant mint',
#  'ripe fig blackberry cassis sweet oak chocolate vanilla rich chocolate fruit baked spice toast heady',
#  'complex white dark gold toasted_hazelnut pear compote orange_peel succulent residual_sugar',
#  'oak fruit dense toast toast cigar_box blackberry cherry coffee graphite polished dark chocolate coffee',
#  'dense wood rich concentrated',
#  'depth dense dark ripe fruit oak blackberry coffee coffee toast oak spice smooth heady',
#  'gritty sweet pastry prune blackberry coffee chocolate',
#  'lush cedar almond vanilla tannin lush chocolate baked berry cassis hard tannin depth',
#  'minerality chunky fruit citrus graphite concentrated',
#  'bright crunchy cranberry pomegranate orange_peel silky succulent fleshy fruit lush length',
#  'elegant complex white yellow spring_flower herb fruit cream juicy white peach ripe pear citrus white almond savory minerality',
#  'supple coffee cherry vanilla savory',
#  'green cola tobacco orange vanilla tea milk_chocolate ripe blackberry fruit',
#  'ripe fruit dry berry fruit',
#  'minerality tart fruit supple dense strawberry blueberry plum cherry chocolate minerality silky',
#  'succulent minerality rich butterscotch lees',
#  'blueberry pie chocolate smooth silky complex cedar pepper pepper oak dense rich finessed spice',
#  'oak blackberry licorice vanilla smooth coffee blackberry raspberry fruit chocolate velvety',
#  'powerful fruit wood dark rich concentrated elegant restrained',
#  'fresh cherry tangy crisp orange_peel cherry pomegranate baked spice',
#  'strawberry watermelon orange_peel salt spice vibrant flower',
#  'complex powerful grilled_meat berry tea smoke vanilla spice concentrated elegant blackberry molasses coffee chocolate oak',
#  'tar blackberry cheese oak expansive grabby bullish salt earth blackberry baked spice chocolate chocolate hard tannin',
#  'white oak almond white peach sizzling salt lemon brown_butter rich finessed luxurious',
#  'fruit cherry sage eucalyptus ripe plum strawberry fruit juniper pine bay_leaf',
#  'silky hickory_smoke white peach lime_peel',
#  'jelly rose plum complex fruit cola brown_sugar',
#  'dense ripe raspberry oak coffee coffee cedar cinnamon dark chocolate',
#  'cranberry baked rhubarb anise slate raspberry fruit earth loamy fennel oregano juniper round',
#  'stone earth brine olive green olive orange_peel gravel smoked_meat cured_meat',
#  'dry cherry plum fresh pepper eucalyptus soft dry cherry cassis plum',
#  'steel perfumed oak vibrant fresh baked apple lemon_pith grapefruit spice',
#  'undergrowth scorched_earth menthol plum chewi ripe cherry raspberry jam pepper licorice firm velvety warm',
#  'wet_rocks honeysuckle chamomile stone fruit',
#  'forest_floor berry leather ripe fleshy cherry dry herb tobacco gripping',
#  'spice fresh pear melon fruit round flabby warm spice',
#  'forest_floor violet berry dark baked spice cherry raspberry pepper star_anise firm',
#  'rose violet berry juicy ripe cherry mint white pepper star_anise complex savory fresh supple',
#  'bright savory juicy cherry raspberry violet white pepper coffee polished',
#  'earth plum cherry round smooth light_bodied brine earth plum cherry salt',
#  'expansive oily hazelnut toffee plump light_bodied buttery_toast toffee peanut',
#  'scorched_earth plum dry flower green herb dense tart',
#  'rose herb round juicy ripe cherry fleshy raspberry white pepper clove polished smooth velvety',
#  'dark coffee plum fruit soft dust',
#  'violet plum coffee forest_floor firm dry cherry pepper toast clove',
#  'earth ripe berry baked spice menthol juicy cherry pomegranate star_anise coffee tobacco',
#  'juicy cherry cassis pillowy tar fruit',
#  'ripe forest_floor cooked spice leather chewi fleshy cherry cinnamon vanilla tobacco polished',
#  'blue fruit herb spice tight restrained firm grain length',
#  'robust coffee plum cake toast dark spice hearty blackberry jam licorice vanilla coffee firm coffee closed',
#  'complex minerality weight tight tannin',
#  'ripe ripe green fruit lime rich apricot concentrated fruit',
#  'light_bodied smoke fruit fresh',
#  'white hazelnut cream vanilla round oak',
#  'wood spice cherry light_bodied elegant gripping',
#  'minerality citrus green fruit tight round',
#  'exuberant fruit tropical_fruit minerality edgy dry refreshing vibrant light_bodied honey',
#  'cherry herb minerality firm',
#  'savory coffee leather tobacco dark woody_berry chewi juicy plum cassis clove polished',
#  'concentrated ripe blackberry cassis pepper spice cedar oak blackberry hot sizzling',
#  'supple firm cherry mint earthy brown_sugar',
#  'smoke wood berry cassis flower oak plum cassis vanilla',
#  'tight toast tangy',
#  'concentrated fruit wood dense firm plum blackberry dark concentrated',
#  'fresh boysenberry blueberry sorbet mint tarragon dill hot gravel pepper light_bodied tobacco coffee boysenberry',
#  'steel crisp lemon minerality edgy juicy fresh',
#  'tight tobacco tea coconut',
#  'full_bodied dark chewi fruit cedar tobacco thick',
#  'juicy cherry vanilla oak cedar smooth medium_bodied coffee chocolate',
#  'sweet depth chocolate blackberry soft juicy rich dense elegant spice clove cinnamon',
#  'tight light_bodied bright cherry pomegranate rose',
#  'rose wild_berry dark cooked spice baked earth ripe cherry licorice game chocolate velvety warm closed',
#  'fruit fleshy fruit sweet dry dense length',
#  'ripe dark firm dense concentrated juicy berry firm',
#  'elegant sturdy currant fruit baked spice orange',
#  'round toast linear fresh crisp citrus almond',
#  'crisp white lean lemon grapefruit tangerine refreshing white peach',
#  'chocolate graham_cracker vanilla jam thick tobacco',
#  'undergrowth smoke coffee dark fruit ripe dry cherry licorice clove firm velvety',
#  'fruit tart toast coffee fresh',
#  'dark violet cherry lavender rose cherry raspberry herb silky bright cherry',
#  'berry baked spice dry mint vanilla white pepper sage anise orange_peel yellow peach cherry balsamic closed firm refined',
#  'hearty forest_floor leather licorice menthol firm chewi ripe cherry raspberry jam anise tobacco dark',
#  'woody_berry rose mint menthol mint cherry raspberry spice toast assertive bright',
#  'french_oak coconut vanilla spice plum powerful oak warm cherry licorice menthol',
#  'refreshing tight minerality fruit tangy crisp tight toast apple citrus tight',
#  'hot spice cinnamon clove pine depth plum dark cherry clove powerful leather',
#  'light_bodied concentrated ripe rich fruit kirsch cherry raspberry cinnamon lush plush',
#  'blackberry chocolate chalk full_bodied licorice cassis tea',
#  'bright light_bodied oak cherry strawberry fresh fruit',
#  'fruit sparkling bright crisp tangy currant',
#  'white spring_flower fruit citrus ripe yellow peach green apple foamy mousse',
#  'smoke earth smooth',
#  'light_bodied spice wood fruit ripe bright',
#  'smooth soft fruit ripe round edgy rich juicy fruit',
#  'oak crisp ripe pear baked spice soft smooth',
#  'austere modest crisp currant cranberry cedar dry herb',
#  'spice stalky bright berry fruit crisp light_bodied minerality',
#  'light_bodied refreshing bright perfumed herb citrus',
#  'juicy kiwi lime sour apple candy ripe oily honeydew',
#  'bramble herb bright ripe tar toffee rich cola',
#  'undergrowth berry toast low_complexity lean sour cherry green sage pepper astringent',
#  'leather tobacco pepper rustic edgy fruit mellow',
#  'sticky sweet oily candy honeydew kiwi sweet juniper pine gold honey soft oil thick',
#  'ripe lean overripe apple melon orange_peel fruit',
#  'wood smoke grilled_meat assertive oak dry herb medium_bodied soft',
#  'earth flower low_complexity fruit',
#  'dry earth savory fruit walnut almond',
#  'oak medium_bodied overripe honeysuckle lime lemon_peel',
#  'soft ripe light_bodied fruit',
#  'rubber citrus fruit round dry citrus',
#  'tannin oak hard ripe smoke oak currant concentrated powerful',
#  'savory apple pear lemon bramble earth tangerine bright sweet',
#  'tart gooseberry lime flower pith plum currant citrus_peel light_bodied astringent fresh herb saline closed',
#  'prune raisin plum gritty chunky grabby blackberry burnt coffee dark chocolate plump rubber closed',
#  'cherry cassis horsey hot sweet hard cherry cassis baked plum chunky',
#  'pale fruit crisp soft',
#  'soft fruit light fruit earth edgy',
#  'fruit ripe berry fruit soft smooth',
#  'robust oak cherry oak toast reductive smooth concentrated powerful ripe',
#  'full_bodied fruit round spice tart cherry',
#  'elegant sparkling sparkling watermelon dry orange_blossom yeast citrus_peel fresh strawberry tart raspberry yeast melon salt gripping',
#  'citrus elegant honey pear caramel lengthy complex mellow',
#  'tangy nervy refreshing fresh tangy fruit cranberry concentrated',
#  'restrained powerful modest fruit tart fruit lean elegant oak',
#  'vanilla coconut rich milk_chocolate strawberry jam sweet smooth',
#  'thick chocolate leather pepper concentrated smooth round robust blackberry vanilla',
#  'strawberry currant spice fresh grabby fruit baked spice cocoa dry cassis chocolate',
#  'pineapple fruit saline apple peach herb minerality firm',
#  'juicy ripe fruit succulent crisp apple pear nectarine minerality bright',
#  'light_bodied chalk slate minerality pear kiwi honeydew fruit pith grapefruit apple warm yellow pear saline warm',
#  'meaty smoke fruit robust dry firm tannin grilled_meat',
#  'crisp elegant lemon_peel apple pear light_bodied oak',
#  'dark pepper syrupy earth dry',
#  'dark olallieberry blackberry plum concentrated purple_flower licorice earth eucalyptus fresh pomegranate juicy',
#  'sour cherry cranberry sandalwood savory herb oregano dry herb juicy',
#  'heavy fruit concentrated thick velvety concentrated',
#  'cherry plum vanilla oak elegant plum cherry toast oak vanilla toast crisp hard',
#  'fruit currant raspberry strawberry flower lavender rosemary berry peach_pit soft spice closed',
#  'light_bodied ripe strawberry raspberry citrus',
#  'citrus light_bodied complex white refreshing bite oak steel oak shine tropical_fruit',
#  'zesty cherry cola cinnamon spice pepper light_bodied grippy vibrant iron',
#  'steel racy pungent rich juicy fruit apple tangerine oak powerful',
#  'clean sharp zesty fruit ripe green apple fresh tingly sour stone fruit grippy',
#  'strawberry rich fruit warm hard ripe soft',
#  'exuberant fruit spice robust dark berry dust brown_sugar pepper ripe concentrated smooth elegant powerful',
#  'white_flower stone fruit lees juicy elegant citrus pith',
#  'vibrant flower depth blackberry dry fresh baked berry pastry cooked blackberry vanilla juicy strawberry pepper rosemary spice',
#  'white sweet bone_dry sugar citrus orange_blossom peach syrupy brisk honeysuckle pine bitter',
#  'light_bodied tart cherry fruit chocolate bright light_bodied',
#  'orange lemon_peel vanilla white_flower citrus lush tropical_fruit fruit',
#  'dust lees apple vanilla sturdy fresh modest elegant lime apple tarragon dry apple citrus easy',
#  'bright citrus tropical_fruit fruit white fresh elegant',
#  'peach pear lemon white complex fruit soft',
#  'light_bodied herb horsey blueberry plum cardamom ripe hot flabby soft chunky plum blackberry licorice mint chewi syrupy',
#  'fruit dry wood berry fruit juicy fresh',
#  'shine bright spice tart strawberry raspberry cherry american_oak oak gripping',
#  'leather plum compost rubber juicy herb plum currant earth tomato light_bodied leafy',
#  'berry cassis spice jam hollow blackberry blueberry fleshy soft',
#  'dry oregano thyme cherry green pepper blackberry tomato',
#  'fruit dense chunky cherry coffee oak toast elegant',
#  'dense tar asphalt rubber boysenberry flat tannin blackberry prune raisin toast bitter chocolate weight oak ripe',
#  'smoke meaty ripe plum tart blackberry overripe restrained savory tarragon anise',
#  'peach lemon juicy honey minerality apple pear cider ripe light_bodied',
#  'tight spice berry fruit light_bodied oak milk_chocolate smooth',
#  'plum coffee tobacco cedar low_complexity blackberry currant clove licorice',
#  'wild_berry violet spice savory cherry clove pepper',
#  'firm dry fruit fresh currant berry perfumed',
#  'light_bodied yellow green crisp green apple rich pear butter fig rich ripe',
#  'rhubarb cola pencil_shaving earth sassafras dry berry soil minerality dark fruit',
#  'dark lemon graphite licorice blackberry horsey baked chunky heavy fruit resin oak spice salt wood tannin',
#  'leather cherry plum ripe cherry cedar cinnamon soft',
#  'light_bodied fresh fruit cranberry cherry tangy fruit cinnamon firm',
#  'oak meaty savory super_ripe cherry fruit',
#  'cherry raspberry fresh dense wild_berry plum brown_sugar warm heady fruit bright',
#  'sleek toast oak vanilla blue_flower plum round sweet cherry raspberry licorice mint assertive',
#  'robust baked plum coffee menthol spice hearty fruit chocolate licorice dry herb hot closed',
#  'juicy soft blackberry cherry oak weight strawberry dry herb closed',
#  'latex tire_rubber spice cured_meat berry fruit grabby herb muscular plum licorice pepper',
#  'lemon oak refreshing fennel brine powerful',
#  'oak cherry extracted rich depth fruit complex licorice tar',
#  'earth menthol eucalyptus tomato light_bodied powerful weight cherry plum dark savory',
#  'kumquat wet_rocks concentrated light_bodied shine',
#  'dark mint inky blackberry rubber grabby toast berry fruit chocolate oak hot mint coffee',
#  'raspberry cherry herb wood_spice fruit fresh elegant light_bodied chalk',
#  'lush powerful gingerbread cherry thick heavy coffee plum cherry earth complex pencil_lead',
#  'hearty earth nutmeg iron hot stone loamy cherry extracted lush ripe cassis cherry fruit elegant chalk round cocoa',
#  'apple nectarine lees brine round bitter melon peach lees pith grapefruit_peel',
#  'raisin baked overripe heavy berry prune fresh raisin',
#  'crisp minerality oak firm juicy modest blackberry cassis oak coffee closed',
#  'bright fruit minerality fresh fruit firm',
#  'rich weight wood smoke edgy',
#  'smoke toast wood fruit juicy fruit firm',
#  'tannin wood juicy fruit bright smoke fruit dark toast',
#  'smoke burnt toast currant fruit bright fruit',
#  'cream butter bright lemon apple sweet luxurious viscous',
#  'brick dry round cherry watermelon',
#  'zesty minerality unoaked citrus refreshing pear quince crisp',
#  'smoke violet perfumed elegant fresh green apple pear tart concentrated tight',
#  'rocks slate lemon tangerine zippy fresh brisk stone',
#  'fig spice perfumed rustic potpourri dust raisin fig elegant crisp spice',
#  'ripe soft fruit soft rich smooth round',
#  'leather firm fruit',
#  'pear white_flower sweet spice',
#  'plum herb dark blue fruit chalk dry',
#  'dry cherry vanilla dry tobacco blackberry dry cranberry cherry rich tart astringent',
#  'potpourri brisk concentrated light_bodied elegant perfumed',
#  'light_bodied wood herb fruit sweet rich fruit gripping',
#  'smoke toast fresh crisp citrus foamy grapefruit orange pepper caramel foamy pepper bitter',
#  'ripe spice wood powerful fruit dark bitter chocolate cherry rich concentrated',
#  'blue_flower ripe berry baked spice mint elegant juicy cherry raspberry cinnamon licorice minerality firm ripe finessed',
#  'earth dark complex ripe blackberry cherry compote',
#  'raspberry blue_flower graphite firm ripe cherry pepper licorice sage tight',
#  'chalk rich fruit steel minerality perfumed crisp fresh dense complex',
#  'rich fruit minerality tangy apple grapefruit steel tight',
#  'cherry toffee tobacco tar violet full_bodied powerful fruit spice bright',
#  'dry rose leather truffle berry ripe cherry raspberry cinnamon white pepper chewi',
#  'rich ripe elegant tropical_fruit fruit juicy warm round',
#  'ripe fruit tight',
#  'lush wild_berry wet_rocks sweet grain bright berry fruit',
#  'light_bodied heavy leather purple fruit blueberry tobacco licorice pepper game restrained juicy thick',
#  'round rich flower fruit steel',
#  'juicy oak dense cherry plum lavender sage thick rocky minerality',
#  'ripe fresh violet rose perfumed berry spice depth juicy cherry raspberry clove pepper chewi',
#  'ripe oil rich honey fruit dry edgy botrytis orange light_bodied ginger',
#  'white pepper exuberant buoyant fruit wild_berry bramble soft',
#  'high_alcohol oak herb berry grain bramble tart strawberry cherry fruit',
#  'hot blackberry pie cinnamon allspice cola nut cherry dark plum fruit plum candy blackberry syrupy fresh watery',
#  'herb dark berry fruit spice leather powerful complex concentrated',
#  'light_bodied complex coffee vanilla pencil_lead cherry blueberry herb polished plush elegant',
#  'saddle_leather cedar spice cardamom soft juicy tingly weight',
#  'depth tannin ripe fig plum fruit saline iron',
#  'fruit mass cherry cassis smoke oak length dry',
#  'balsamic menthol mint fennel ripe berry leather violet cherry raspberry baked spice licorice fresh',
#  'ripe minerality rich white fruit fresh fruit citrus complex',
#  'flower rich dry ripe perfumed round opulent steel minerality',
#  'chalk minerality ripe tropical_fruit fruit rich dry ripe sweet',
#  'rich dense dark opulent fruit firm silky',
#  'violet spice perfumed berry juicy ripe cherry raspberry fresh pepper coffee anise fresh firm polished',
#  'smoke toast currant fruit fresh firm juicy fruit',
#  'rich crisp fruit tight chalk steel ripe apple grapefruit bright fruit',
#  'tight herbacious crisp minerality fresh fruit juicy bright',
#  'round velvety smooth blackberry fruit fresh rich soft',
#  'crisp fruit bright lime grapefruit fresh juicy',
#  'ripe apple brioche smooth',
#  'toast oak tart raspberry fruit clean oak light_bodied fruit',
#  'pink cinnamon berry bubble_gum sour cherry plum fruit',
#  'bright orange juicy dill herb vanilla apple fresh lime juicy',
#  'white cream tropical_fruit ripe melon pear fruit spice',
#  'plum bright cherry fruit savory tobacco spice sweet pepper caramel',
#  'bright berry fruit light_bodied sage baked spice',
#  'dust oak burnt toast cherry fruit chalk',
#  'brown lean light_bodied strawberry flower oak cardamom spice fig',
#  'spice concentrated sweet tea',
#  'plum oak coffee pepper balsamic barnyard dark cherry oak coffee toast vanilla aggressive wood astringent',
#  'white heady flower jasmine vibrant sweet fresh fruit grapefruit peach nectarine',
#  'iron pepper light_bodied racy boysenberry sanguine',
#  'plum cherry coffee ripe',
#  'brilliant purple tannin syrupy blackberry baked spice clove oak',
#  'dust cherry dark plum ripe plump clean weight berry fruit spice oak smooth fresh',
#  'fresh fruit sparkling crisp apple apricot ripe light_bodied cream mousse fruit tight',
#  'chalk earth pepper clove spice complex cedar tea green pepper',
#  'blackberry pepper meaty boysenberry iron licorice',
#  'low_complexity closed cherry coffee prune oak tire_rubber aggressive dry',
#  'crisp ripe yellow fruit warm rich fruit almond refreshing',
#  'honeydew ripe nectarine lemongrass peach bubblegum flint',
#  'bright rustic fresh raspberry stone tart cherry berry ripe raspberry tart',
#  'light_bodied butterscotch baked pear fresh jasmine apple pear round',
#  'raisin cinnamon spice soft extracted modest baked fruit fig chocolate herb chocolate rich',
#  'fruit dark firm juicy cherry',
#  'fruit rich wood rich fruit complex minerality tight nervy citrus fruit apricot',
#  'ripe orange apricot oak',
#  'rosemary leather rich savory juicy dark plum tobacco coffee',
#  'dry sparkling dry complex lemon orange yeast vanilla cream toast sparkling',
#  'low_alcohol brisk silky raspberry cola butter cinnamon toast',
#  'depth apple fruit flint cream',
#  'rich cream apple bitter orange herb complex',
#  'ripe smooth cream ripe peach vanilla concentrated rich',
#  'rich raspberry cranberry persimmon crisp dry',
#  'depth flower chamomile fruit graphite juicy honeydew white peach ripe pear citrus minerality fresh',
#  'stone fruit tomato fresh cut_grass green melon depth cream white peach ripe cataloupe firm closed flint minerality',
#  'powerful dense fruit dark fruit',
#  'mint wood ripe polished rich fruit blackberry dry',
#  'fruit astringent',
#  'depth rich cherry blueberry complex mushroom toast dry tannin',
#  'cream fruit wood apricot ripe apple melon spice toast rich warm',
#  'tannin dense complex dark fruit licorice bitter',
#  'ripe smooth rich toast apricot fruit tight minerality',
#  'soft clean blueberry fruit',
#  'firm closed tannin fruit dry firm fruit leather dark',
#  'violet truffle ripe fruit rich dark heavy complex',
#  'fruit racy rich pear orange_peel snappy spice',
#  'blackberry jam milk_chocolate cassis toast butter oak sweet dry thick',
#  'ripe rich smoke fruit honey ripe apricot peach',
#  'elegant peach pink dry low_alcohol peach lime vanilla crisp',
#  'savory cataloupe tomato vibrant juicy green melon pineapple citrus minerality fresh clean crisp',
#  'savory weight oak apple pear nutmeg flint cream fresh',
#  'light_bodied silky rich raspberry cherry spice cola smoke oak tart earth',
#  'dense brick tar bramble blackberry fruit powerful smoke meat',
#  'stone earth brine olive green olive orange_peel gravel smoked_meat cured_meat',
#  'white sparkling wax apricot pear crisp minerality stone dry refreshing viscous complex',
#  'complex dry violet plum cooked spice smooth blackberry jam tobacco ripe cherry nutmeg licorice velvety elegant',
#  'fruit white steel crisp white peach brine stone heady honeysuckle ginger vanilla',
#  'plum tangy cranberry pine juniper pencil_shaving mulberry marjoram indian_spice',
#  'silky hickory_smoke white peach lime_peel',
#  'fruit cola clean earth minerality',
#  'ripe fruit spice oak forest_floor opulent baked spice earth cherry fruit complex',
#  'powerful fruit concentrated rose sage strawberry velvety weight',
#  'fruit coffee smoke fruit wood fruit bright raspberry plum cherry light_bodied cola ripe apple sweet spice',
#  'full_bodied orange dark cherry pungent earth savory meaty pepper clove tea',
#  'elegant savory vibrant white yellow stone fruit wet_rocks thyme vibrant yellow peach tangy tangerine lemon_drop pineapple graphite closed elegant depth',
#  'white white_flower yellow stone fruit white peach pear ginger lemon_drop fresh cream minerality',
#  'fruit tropical_fruit edgy coconut firm sage cedar tobacco pepper savory fruit',
#  'currant cherry dry milk_chocolate',
#  'crisp robust raspberry blackberry coffee full_bodied dense licorice clove lengthy',
#  'flower cream crisp length stone green apple rich complex',
#  'chunky cranberry blackberry cherry fruit dense fruit wet_rocks minerality',
#  'full_bodied fruit firm minerality powerful elegant',
#  'pop orange_peel cured_meat olive wet_rocks purple fruit fruit plum savory',
#  'ripe fruit spice warm herb',
#  'spice sweet root saddle_leather earth berry fruit rich dense dark cherry berry fruit herb complex chocolate oak',
#  'rich fruit',
#  'ripe chocolate coffee hard coffee coffee hazelnut ripe berry fruit dense firm toast powerful',
#  'elegant powerful fruit round rich cassis clove pepper',
#  'rich dense concentrated spice dark fruit herb warm',
#  'oak sweet almond prune chocolate tannin depth dense toast cassis blackberry coffee chocolate pepper rough tannin',
#  'light_bodied bright wood spice ripe fruit concentrated rich complex',
#  'soil wood mint rich truffle',
#  'polished potpourri almond apple white pepper yeast oak complex bright bite',
#  'woody_berry rose herb anise balsamic firm robust white pepper licorice sage toast cherry warm closed',
#  'juicy grapefruit apple buoyant fresh steel',
#  'dense rich fruit elegant concentrated vanilla berry soft oak fruit rocky minerality',
#  'light_bodied lees vanilla cookie crisp minerality apple apple pineapple fresh citrus_pith',
#  'tropical_fruit mango pear vanilla cream elegant grapefruit',
#  'powerful concentrated rich dense dark',
#  'ripe white peach caramel pear apple almond restrained grippy pear honey',
#  'lush rose fresh strawberry fruit toast oak satiny hard',
#  'quaffer dry crisp bright refreshing succulent grapefruit tangerine light_bodied light_bodied',
#  'fruit berry spice menthol firm juicy cherry raspberry licorice pepper mint racy',
#  'blue_flower rose wild_berry graphite firm cherry raspberry star_anise pepper bright tight',
#  'bittersweet berry juicy dust chalk rich leather clove',
#  'perfumed berry mint baked spice oak firm cherry raspberry mint sage spice',
#  'sandalwood velvety tea truffle forest_floor sinewy complex savory cinnamon clove',
#  'dense minerality powerful concentrated',
#  'rich dry rich juicy fruit concentrated fresh',
#  'warm vanilla ripe nectarine apple lemon_peel pencil_lead apple lemon sizzling',
#  'lemon light_bodied tropical_fruit white weight elegant hard white peach',
#  'herb green perfumed fruit peach fresh pear herb fresh brisk citrus apple silky supple',
#  'rose wild_berry cinnamon balsamic juicy cherry white pepper anise mint spice polished firm refined',
#  'caramel white peach salt lemon pear apple white_flower orange grapefruit_pith buttery_toast saline herb',
#  'cherry kirsch coffee tobacco fruit tar coffee',
#  'cream mousse dry white citrus fruit tangy tight minerality',
#  'rich currant fresh leather',
#  'light_bodied honeysuckle moist_earth tart raspberry cherry minerality crisp',
#  'restrained plum dark plum mint eucalyptus pepper fruit soft mint bright opulent tart apple crisp',
#  'cream pineapple apple custard lemon iodine lemon salt apple tangy ripe fruit savory saline',
#  'lush strawberry cream fruit closed',
#  'rose berry mint menthol oak linear cherry strawberry white pepper licorice tight bright',
#  'ripe berry earth leather blackberry chocolate raisin prune light_bodied toast dense',
#  'cedar cherry olive wet_earth green olive fresh plum pop ripe cherry tangy green olive tart',
#  'lemon_curd soft apple pear ripe stone fruit tangy bone_dry grippy chalk',
#  'melon white peach citrus',
#  'velvety fresh earth oak leafy fruit depth depth game',
#  'fruit firm raspberry plum perfumed fresh',
#  'fresh cranberry raspberry fruit clean light_bodied',
#  'berry rose clove bright supple smooth juicy cherry strawberry white pepper fresh minerality savory',
#  'plum blackberry ripe rich fruit savory edgy bramble dry herb crisp cranberry fresh',
#  'fresh green pear watery herb edgy fresh green refreshing',
#  'pepper spice lees fresh white asparagus luminous fresh',
#  'pear juicy warm earth tropical_fruit lemon pineapple fresh',
#  'fresh pear fruit crisp clean fresh fruit fresh',
#  'pale elegant restrained velvety finessed rhubarb cinnamon cardamom cocoa',
#  'firm fruit raspberry fruit perfumed fresh',
#  'spring_flower beeswax fruit elegant linear juicy lemon nectarine hazelnut saline firm closed crisp clean',
#  'earth white flower dust fruit dry herb flower dry peach candy nectarine zest',
#  'tart juicy fresh tangy citrus green apple fruit lees wet_rocks refreshing white',
#  'light_bodied yellow stone fruit citrus herb bright cream peach green apple nectarine minerality juicy',
#  'apple pear vibrant fresh sweet simple refreshing steel minerality',
#  'herb mint rich dry tannin cherry wild_berry rosemary rich meat mushroom',
#  'concentrated oak dark cherry ripe dry blackberry dark chocolate full_bodied dark fruit',
#  'blackberry jam oak pepper sturdy',
#  'depth blackberry cedar firm restrained oak smoke pencil_lead lengthy',
#  'plum herb tobacco fresh plum berry cherry',
#  'ripe rich berry ripe blackberry plum fleshy rich soft supple silky tannin',
#  'fruit vanilla tobacco orange_peel earth fresh hollow pepper oak cherry plum toast snappy',
#  'steel american_oak powerful elegant tannin grippy toast oak cherry rich cinnamon chocolate',
#  'grippy leather tobacco gravel concentrated dense currant cassis leather',
#  'depth blackberry boysenberry ripe concentrated',
#  'spice oak velvety smooth ripe cranberry cedar nutmeg',
#  'cream honeysuckle light_bodied butter citrus_peel vanilla apple cinnamon firm clean light_bodied',
#  'juicy blackberry blackcurrant cocoa cola pepper dense depth dark tar pencil_shaving dry blueberry asphalt umami tight',
#  'ripe leather menthol robust concentrated cherry raspberry jam cinnamon licorice warm hot firm ripe',
#  'fresh dill green herb plum',
#  'fruit raspberry blackberry light_bodied tangy mellow dark chocolate',
#  'apple lime minerality fresh round plump peach citrus stone tropical_fruit lychee mango',
#  'perfumed rich ripe fruit smooth dark cherry juicy',
#  'undergrowth earth truffle star_anise menthol ripe dry cherry blackberry jam licorice coffee assertive',
#  'coffee undergrowth leather dark spice fruit oak firm dry cherry coffee vanilla star_anise dust',
#  'lemon_custard pineapple white vanilla lemon_meringue pie',
#  'scorched_earth coffee dry cherry blackberry coffee vanilla game',
#  'herb forest_floor scorched_earth cured_meat menthol ripe juicy cherry fleshy raspberry cinnamon tobacco candy firm',
#  'rose perfumed berry meditteranean_herbs soft bright cherry raspberry tobacco coffee supple',
#  'peach baked orange apple honeysuckle racy sizzling cut_grass lemongrass',
#  'rosemary bay_leaf clove full_bodied dry',
#  'tannin cherry leather',
#  'thick dense dust fruit cedar tar tobacco blackberry currant powerful gripping',
#  'steel refreshing orange lime',
#  'funky brine tropical_fruit oak mellow opulent butter',
#  'tropical_fruit guava mango restrained french_oak vanilla honeysuckle low_complexity lengthy',
#  'pepper dry cherry plum violet plum blackberry tart cherry smooth',
#  'wild_berry thyme dry cherry white pepper sage anise tight',
#  'caramel oak rich round medium_bodied lemon apple',
#  'low_complexity exuberant toast oak gripping cedar sage cassis cherry powerful soft',
#  'french_oak brawny meat leather blackberry tar velvety oak',
#  'light_bodied spice fresh plum medium_bodied',
#  'round ripe baked plum vanilla anise leather juicy cherry blackberry coffee dry sage baked spice licorice polished',
#  'forest_floor plum menthol spice elegant cherry pepper licorice firm',
#  'scorched_earth undergrowth blue_flower woody_berry elegant raspberry cherry brown spice leather tight refined',
#  'dry cherry vanilla dry tobacco blackberry dry cranberry cherry rich tart astringent',
#  'light_bodied cherry pepper spice light_bodied lush ripe berry nutmeg game',
#  'potpourri brisk concentrated light_bodied elegant perfumed',
#  'light_bodied wood herb fruit sweet rich fruit gripping',
#  'smoke toast fresh crisp citrus foamy grapefruit orange pepper caramel foamy pepper bitter',
#  'raspberry currant oak maple crisp plum raspberry',
#  'light_bodied apple herb tropical_fruit fruit medium_bodied lean tart concentrated',
#  'mint rich currant fruit fresh juicy',
#  'butter full_bodied full_bodied ripe fruit toast oak dry rich savory smoke fruit',
#  'heavy oak smoke ripe cherry boysenberry rich full_bodied toast oak firm sweet oak',
#  'hot coffee vanilla herb cherry blackberry sweet viscous dry',
#  'pear peach minerality almond medium_bodied',
#  'earth leather wild_berry funky game robust sage tobacco licorice depth fleshy cherry raspy',
#  'oak vanilla toast dense dark prune coffee anise oak astringent dry',
#  'perfumed toast smoke fruit fruit wood',
#  'round purple fruit fresh soil dust ripe cherry tart plum earth',
#  'apple spice low_complexity',
#  'apricot white_flower orange_peel fresh baked full_bodied dry sweet fruit',
#  'bright crisp white apricot nectarine white peach minerality juicy fruit zesty clean refreshing',
#  'cheese funky complicated brine stone fruit butter oxidized brine apricot',
#  'earth leafy forest_floor dry currant low_complexity juicy blackberry raspberry clove smooth',
#  'lime minerality stone fruit dry residual_sugar phenolic cream',
#  'berry spice oak vanilla cream oak sharp plum boysenberry tart vanilla snappy sharp',
#  'smooth nut vanilla dry orange lemon salt peanut crisp metal angular salt oily',
#  'crisp mint herb berry plum bright tannin blackberry chocolate earth plump',
#  'oak dry coconut coffee vanilla hard',
#  'berry cherry fruit clean tannin plum blackberry crisp firm',
#  'concentrated plum scorched_earth dense prune baked cherry nutmeg clove velvety fruit',
#  'cured_meat fruit toast oak ripe sage vanilla oak spice fleshy plum fruit rich',
#  'oak vanilla plum coffee coconut tight dry fruit coffee clove hot closed',
#  'crisp refreshing currant light_bodied caramel fruit',
#  'resin balsamic overripe dry apricot candy nectarine zest closed',
#  'robust viscous petrol oak tart',
#  'barnyard soy sweet cherry cooked fruit funky',
#  'berry soft fruit smooth',
#  'rose lychee powerful flower fruit soft sweet',
#  'fruit crisp bright fruit tangy citrus ripe cream',
#  'pale brick elegant cherry',
#  'dry cranberry currant cake tannin tart',
#  'spice reedy dry herb fruit tight baked plum berry fruit cocoa',
#  'soft green apple orange_peel underripe banana zippy prickly pith citrus zest bitter',
#  'american_oak round pencil_shaving cherry leather tobacco firm',
#  'concentrated orange_blossom bubblegum minerality sweet dry syrupy apple pear lemon_curd',
#  'green wood herb cherry ripe chalk fruit astringent bitter',
#  'fruit grippy hearty full_bodied cherry plum',
#  'crisp fruit bright lemon fruit minerality',
#  'jam blueberry oak dense flat baked berry herb plum sweet green syrupy',
#  'ripe tropical_fruit honeydew banana nectarine sweet apple bubblegum',
#  'modest lemon white lemon pith yeast citrus tangy',
#  'lime concrete green apple rind lime tangy ripe apple pear stone',
#  'fruit bright soft fruit',
#  'smoke brawny pepper cherry ripe grippy powerful coffee dust',
#  'spice wood firm tight granite blackberry fruit',
#  'low_complexity dry fruit medium_bodied cherry blackberry',
#  'funky sour blackberry charcoal dry meat blueberry sour plum savory meat',
#  'grass herb apricot spice fruit',
#  'dull rustic earth anise soft cherry fruit light_bodied',
#  'bright fruit juicy plum',
#  'pale light_bodied bright fruit zesty orange_peel crisp strawberry',
#  'light_bodied fresh fruit cranberry cherry tangy fruit cinnamon firm',
#  'leather cherry plum ripe cherry cedar cinnamon soft',
#  'cherry raspberry full_bodied tannin',
#  'blue_flower undergrowth coffee concentrated pepper clove tight fruit rich',
#  'spice juicy fruit sweet berry ripe',
#  'sweet honey rich apricot fruit fresh fruit minerality fruit',
#  'apple pear dust pollen saffron savory spice dry concentrated tangerine lime dust earth',
#  'sparkling honeysuckle candy citrus firm ripe yellow apple nectarine zest candy ginger toast walnut crisp',
#  'full_bodied apple pear pineapple fruit',
#  'dry cherry purple_flower vanilla blackberry jam purple_flower sour cherry coffee sanguine grippy',
#  'toast coffee currant cedar dry cherry coffee sage leather astringent',
#  'firm plum fruit cherry',
#  'oak cherry coffee anise smooth sandalwood butterscotch',
#  'firm light_bodied raspberry citrus stone',
#  'warm pie pepper green bell_pepper plum cherry strawberry wood bitter',
#  'perfumed dark chocolate dense powerful dark',
#  'boysenberry dry violet pepper fresh rich purple fruit licorice tobacco',
#  'blackberry ripe plum blue_flower anise pepper fleshy cherry assertive polished',
#  'blue fruit allspice earth game spice blueberry blackberry pepper licorice tobacco',
#  'earth berry licorice light_bodied oak fresh juicy plum raspberry loamy earth heavy',
#  'cherry leather silky cocoa',
#  'dry strawberry wild_berry clove cinnamon cocoa powerful fruit dry cherry dry herb dark chocolate hot',
#  'blackberry cassis herb spice ripe berry cassis chocolate oak chocolate cream oak full_bodied',
#  'spice crisp blue plum licorice dark chocolate light_bodied game cured_meat leafy',
#  'cinnamon cherry potpourri gingerbread raspberry juicy dark chocolate purple_flower pepper cardamom gripping',
#  'fruit herb tart cranberry tight bitter pineapple elegant aggressive herbacious fruit',
#  'blue light_bodied fresh watery flower fresh herb lees stone fruit crisp citrus orange peach nectarine lemon minerality',
#  'fruit toast oak coffee licorice blackberry extracted anise clove tobacco dust',
#  'dry light_bodied oak plum berry bright juicy fresh racy cherry plum clean',
#  'minerality citrus dust round gripping nectarine lime green banana',
#  'bite apple anise powerful finessed depth complex',
#  'concentrated minerality perfumed melon orange fruit',
#  'powerful dark fruit rich juicy dry concentrated dense wood ripe fruit',
#  'spice plum berry fruit fresh cinnamon clove complex tea savory toast oak',
#  'plum dust clove blackberry chocolate vanilla',
#  'plum cedar coffee supple concentrated dark roasted_meat savory pie',
#  'pea wood cigar_box camphor fruit cedar blueberry cherry milk_chocolate',
#  'complex wet_rocks orange_peel herb dry tart stone fruit',
#  'cider nectarine yellow fruit flower yeast grapefruit',
#  'firm berry fruit juicy dark fresh powerful dense minerality',
#  'voluptuous rich toast lemon crisp yellow apple brilliant minerality vanilla firm round',
#  'rich herb mint fruit powerful ripe',
#  'length elegant pungent grass tight lime apple fruit mustard green white pepper',
#  'effervescent cherry mint licorice slate blackberry pepper powerful',
#  'warm depth rich fruit apple peach lees light_bodied oak cream',
#  'rich ripe yellow fruit pepper concentrated light_bodied toast',
#  'soft toast refreshing herb',
#  'dry orange_peel mango honey stone savory herb tight lemon yellow_flower yeast toast racy round',
#  'honeysuckle jasmine linear vanilla caramel lemon_custard lush rich minerality butter',
#  'straw lemon_curd apricot fresh apricot pear spice crisp clean spice',
#  'rose violet baked spice juicy cherry vanilla licorice cinnamon firm',
#  'plush vanilla honeysuckle apricot viscous',
#  'berry blue lilac baked spice meditteranean_herbs white pepper sage tobacco bright cherry aggressive bright',
#  'ripe rich smoke fruit oak ripe fruit rich dense spice toast fruit',
#  'firm depth fruit weight concentrated plum juicy currant dry complex',
#  'minerality fruit complex fruit steel',
#  'zesty fresh rich oak smoke caramel pear vanilla oak apple white peach nectarine lime_peel',
#  'depth cassis berry racy tight full_bodied berry pepper baked spice chocolate toast pepper juicy',
#  'concentrated concrete oak flower light_bodied toast length',
#  'oil ripe caramel toast depth gold crisp green apple melon complex minerality supple',
#  'complex herb cherry fresh fruit mint clove anise vibrant full_bodied',
#  'herb plump fruit dill sage cherry blueberry sleek',
#  'sweet firm stone soft angular peach',
#  'closed edgy soft ripe ripe fruit',
#  'wood rich dark fruit wood fruit firm complex',
#  'cinnamon cherry ripe cranberry light_bodied tobacco leather rustic soft cranberry cherry spice thyme bay_leaf cinnamon',
#  'hazelnut truffle juicy round concentrated',
#  'white peach apricot steel minerality elegant light_bodied sweet bramble herbacious',
#  'wild_berry sage cherry raspberry fruit concentrated',
#  'heady honeysuckle white stone fruit dill hay vegetal tomato tangy juicy grapefruit white peach honeydew saline depth',
#  'wood wood toast spice yellow fruit ripe rich',
#  'soft stone melon fresh clean soft stone dry fresh apple',
#  'rich smoke wood perfumed fruit wood',
#  'ripe apple soft pepper spice rich lemon fresh soft cheese',
#  'white ripe green pear fresh bright lemon',
#  'tart yellow fruit cucumber green lemon steel oak minerality rich gripping',
#  'fruit cake spice concentrated ripe cherry raspberry nutmeg carob depth',
#  'complex rich cherry berry dry herb lavender',
#  'dry heady jasmine citrus yellow stone fruit vibrant apricot tangerine_peel herb fresh',
#  'crisp elegant white white peach grapefruit',
#  'cherry light_bodied coffee tobacco',
#  'oak restrained steel oak rich apple pear compote rich lemon fresh',
#  'rose baked spice juicy fleshy cherry raspberry pepper bright supple',
#  'spice oak velvety smooth ripe cranberry cedar nutmeg',
#  'baked root sandalwood spice berry fruit grabby oak herb plum raspberry dry firm',
#  'berry cinnamon light_bodied wood spice tannin oak plum berry fruit savory dry snappy',
#  'depth ripe fruit light_bodied spice firm bite rosemary fruit concentrated oak',
#  'apple pear vibrant fresh sweet simple refreshing steel minerality',
#  'herb mint rich dry tannin cherry wild_berry rosemary rich meat mushroom',
#  'concentrated oak dark cherry ripe dry blackberry dark chocolate full_bodied dark fruit',
#  'cherry pie spice buoyant robust fruit oak white pepper',
#  'fruit strawberry cherry citrus tea elegant feminine sturdy',
#  'full_bodied rich fruit dense dust tannin',
#  'robust currant dark cherry chocolate dust sage cedar luxurious smooth complex',
#  'bright oak lemon_custard flower citrus green apple lemongrass ginger rich',
#  'nervy light_bodied clean crisp pear nectarine mandarin pith tight sharp citrus round',
#  'white flower almond fruit almond herbs elegant peach apricot almond tangerine',
#  'ripe fruit rich dry fruit',
#  'iron cranberry cola cherry pepper vibrant',
#  'complex chocolate cherry cherry plum fruit oak spice lemon',
#  'dark concentrated fruit smooth rich round opulent',
#  'pungent earth fruit strawberry orange_peel tea savory rich smoke vanilla',
#  'pepper cinnamon blueberry plum tart cherry fruit spice fresh restrained fresh rich',
#  'cranberry herb licorice dry cherry tight firm',
#  'shine plum raspberry blackberry soft dark chocolate clove',
#  'baked cherry vanilla pastry loamy dry mint forest_floor tannin raspberry fruit round thyme oregano pepper saline',
#  'depth dark berry vanilla gritty spice tobacco hard blackberry cassis oak spice molasses savory oak chocolate blackberry fruit',
#  'juicy cherry fruit tar elderberry edgy licorice fruit fresh vibrant elegant refreshing',
#  'earth elderberry dry oak leafy smooth elegant powerful shine depth',
#  'rich cherry candy strawberry spice lavish purple fruit flower pepper spice vanilla warm tar',
#  'crisp peach apricot white gravel steel gripping gritty velvety smooth',
#  'fruit bright spice cherry concentrated length light green herb round',
#  'bright firm berry savory rich steak ripe fruit firm grippy',
#  'nut cashew honey walnut vanilla oak smoke',
#  'minerality rocky powerful spice plum cola clove pepper',
#  'oak leafy tart strawberry supple vanilla smooth mellow depth fresh',
#  'robust rich dark cherry currant oak full_bodied',
#  'complex raspberry sage spice raspberry syrupy dark chocolate blackberry light_bodied grippy plush fruit',
#  'high_alcohol warm burnt earth cherry rubber herb chewi boysenberry cassis herb spice smooth',
#  'fruit spice dense licorice wood complex',
#  'high_alcohol dry tannin ripe blackberry dark chocolate pepper',
#  'bright fruit spice fruit crisp ripe',
#  'rich brisk currant cassis minerality oak elegant',
#  'ripe concentrated depth fruit rich peach pear spice wood',
#  'jasmine honeysuckle fruit round juicy green apple citrus yellow peach minerality',
#  'fresh raspberry cherry jam fruit complex mushroom',
#  'spice honeycomb lanolin minerality dry concentrated complex spice stone fruit tangerine',
#  'dainty stone fruit flower tea minerality juicy orange mango peach',
#  'lavish ripe peach honeysuckle juicy nectar lime',
#  'zesty lime peach plum cherry medium_sweet juicy stone fruit refreshing',
#  'smoke brisk flower lush ripe peach nectarine',
#  'smooth rich concentrated fruit apricot smoke minerality gold apple hazelnut honey crisp crisp complex',
#  'thick spice pear butter mint complex rich',
#  'fruit dust smooth complex juicy fruit dense minerality',
#  'rich lees french_oak oak fruit ripe racy tropical_fruit peach pear depth',
#  'dense spice wood smoke bacon weight berry fruit',
#  'dry lean angular lemon lime wet_rocks tropical_fruit fruit',
#  'rich currant thick soft cherry violet grilled_meat pepper meaty dry',
#  'dark dense tannin earth spice dry cherry rhubarb pomegranate fruit',
#  'ripe juicy peach nectarine semisweet soft sweet minerality',
#  'fresh herbacious elegant rich round sweet peach zingy citrus spice',
#  'semisweet ripe yellow cherry quince crisp tart tangerine bright elegant fresh herb',
#  'smoke stone fruit apple racy powerful sweet yellow cherry quince minerality brisk citrus',
#  'smoke candle_wax savory ripe stone fruit lemon concentrated ripe juicy tangerine sweet lime zest',
#  'complex concentrated ripe peach nectarine smoke spice zippy bright tart tangerine minerality',
#  'sweet honey apricot pear lemon vanilla rich crisp',
#  'concentrated cataloupe yellow peach elderberry tomato fruit juicy fresh minerality crisp depth',
#  'ripe fruit fruit dark fruit',
#  'complex fruit concentrated spice leather rich dense dust',
#  'white toast juicy citrus pear apple spice',
#  'rich blackberry chocolate chalk juicy cigar medium_bodied round soft cherry pomegranate',
#  'fruit beet cherry purple rich velvety',
#  'stewed_prune coconut coffee herb firm dark cherry coffee anise tobacco bright',
#  'wood powerful dense fruit concentrated wood fruit',
#  'closed firm ripe sour cherry dark cooked spice tobacco herbs fresh austere refined',
#  'vanilla berry dark chocolate jam mint',
#  'pungent wood earth orange_blossom pear crisp light_bodied honey lemon complex',
#  'berry undergrowth herb spice dry cherry anise coffee toast herb assertive brisk',
#  'berry sage cinnamon menthol juicy sour cherry raspberry licorice tobacco low_complexity ripe fresh',
#  'woody_berry herb oak firm dry cherry baked spice coffee firm closed star_anise fruit rich',
#  'firm plum undergrowth baked earth vanilla spice chewi ripe cherry raspberry jam vanilla coffee white pepper mint polished',
#  'tropical_fruit fruit lees dust minerality lemon tangy lemon lime gooseberry fresh clean stone citrus',
#  'clove graphite iron cherry complex iron raspberry minerality',
#  'juicy blackberry ripe plum dry fruit full_bodied light_bodied smoke perfumed',
#  'fresh fruit white hot dry yellow green fruit refreshing',
#  'residual_sugar lush fruit sweet dry peach pear light_bodied spice fruit',
#  'flower dry fresh apricot cream light_bodied fresh',
#  'rich spice toast dense perfumed',
#  'toast spice ripe yellow fruit zingy lemon_peel minerality',
#  'tangerine lime green herb grapefruit lemon crisp clean',
#  'soft dense currant cherry powerful juicy exuberant fruit oak smoke',
#  'fruit scorched_earth spice blue_flower vibrant savory juicy cherry plum pepper anise racy soft polished',
#  'ripe tannin chewi firm blue plum cherry tobacco toast compost earth',
#  'dark french_oak coffee clove blackberry extracted licorice vanilla sweet baked spice baked plum',
#  'bright raspberry fruit toast oak fresh',
#  'fruit chewi ripe full_bodied powerful citrus',
#  'full_bodied peach banana pineapple fresh',
#  'baked plum earth truffle leather game cured_meat ripe dense fleshy cherry anise coffee mint velvety candy',
#  'violet rose dark berry cured_meat firm extracted rich cherry chocolate tobacco sweet spice grippy',
#  'french_oak coconut coffee menthol dense extracted raspberry jam vanilla toast oak kirsch warm leather wood concentrated',
#  'crisp elegant cherry rose silky scorched_earth dry complex flower',
#  'light_bodied fruit citrus rich chalk soil fresh crisp fruit',
#  'cherry plum earth gritty weight berry cherry bitter chocolate coffee',
#  'herbacious green herb tight citrus gooseberry light_bodied fresh',
#  'lean savory tea herb juicy bramble berry grippy',
#  'complex fruit spice savory plum fresh plum fruit tart bacon',
#  'fruit bright wood firm currant fruit',
#  'coconut cream pie fig honey vanilla cream baked fruit lush',
#  'crisp apple citrus minerality bright grapefruit',
#  'plum spice incense cherry white pepper leather licorice coffee balsamic astringent',
#  'flashy sweet oak ripe fruit rich ripe raspberry cherry firm vanilla',
#  'pungent lychee grapefruit pepper ginger clove dry rich herb spice fresh',
#  'fresh citrus green apple crisp steel',
#  'sparkling sandalwood licorice currant tart cranberry bitter herb',
#  'pungent juicy grapefruit chocolate strawberry fruit light_bodied light_bodied',
#  'light_bodied orange juicy passion_fruit sugar grapefruit_peel pear cider complex',
#  'white heady dry fruit fresh peach buttery_toast fresh stone fruit fig astringent',
#  'coconut oak extracted coffee coffee mint spice fruit rich oak dry wood',
#  'light_bodied bright refreshing pear lime_peel guava citrus_peel light_bodied papaya apple juicy rich crisp',
#  'round spice light_bodied fruit',
#  'rich toast apricot peach fruit round',
#  'crisp ripe fruit fresh herbacious fruit',
#  'closed rich fruit bitter_almond fruit',
#  'oak plum fruit tobacco cedar clove pepper steak',
#  'white currant fresh apricot fruit bright toast rich',
#  'cherry fruit steel stone firm tannin tart crisp fruit',
#  'flower peach lemon dust clove light_bodied oak bright',
#  'silky cherry strawberry dense refined oak violet rose rich powerful finessed',
#  'fruit dry edgy fruit',
# ...
#  'weight fruit ripe berry fruit fresh powerful dry dense',
#  'brine bell_pepper vegetal round celery bell_pepper lime tangerine grass brine',
#  'rich pineapple apple',
#  'toast weed undergrowth tobacco plum anise coffee fruit rich astringent',
#  'violet rose wild_berry bright lean berry pepper saline dry sage astringent',
#  'oak vanilla cocoa wood_spice cranberry herb raspberry elegant herb cherry tart',
#  'warm robust undergrowth spice plum sage leather balsamic tight dry berry fig menthol licorice hot coffee closed',
#  'tire_rubber leather dry fruit mushroom silky tart fruit',
#  'fresh juicy bright smoke fresh currant',
#  'fruit crisp herbacious rich wood light_bodied fruit',
#  'ripe exuberant fruit',
#  'dry juicy fruit sweet plum ripe',
#  'ripe rich opulent round dark rich dry',
#  'perfumed lavender juicy cassis rough chewi',
#  'blackberry dry cherry pepper coffee anise assertive astringent dry fruit hot',
#  'cherry boysenberry full_bodied rich ripe fruit firm',
#  'fruit rich sweet cherry berry plum fresh full_bodied',
#  'coffee chocolate herb plum oak soft elegant',
#  'dark fruit wood burnt toast chocolate dry fresh fruit',
#  'blueberry vanilla herb full_bodied',
#  'grass gooseberry crisp bright vibrant fresh mellow lush',
#  'oak fresh plum cherry velvety ripe firm soft',
#  'oak steel peach pear minerality round light_bodied oily',
#  'chewi coconut smoke game dense concentrated coffee',
#  'raspberry cherry flower pepper dark coffee light_bodied fruit oak',
#  'oak dill vanilla plum green herb fruit plump vibrant oak',
#  'bright fresh green apple lime lemon melon tangy refreshing medium_bodied crisp refreshing',
#  'low_complexity cherry dry rose anise complex dark fruit pepper spice',
#  'tobacco juicy plum oak vanilla dry ripe',
#  'yellow plum pear brawny full_bodied rich butter ripe citrus apple',
#  'concentrated tangerine peach smoke spice',
#  'chewi robust tar leather cranberry herb oak restrained',
#  'light_bodied depth dry bright berry currant fruit',
#  'dry heady jasmine citrus yellow stone fruit vibrant apricot tangerine_peel herb fresh',
#  'crisp elegant white white peach grapefruit',
#  'cherry light_bodied coffee tobacco',
#  'oak restrained steel oak rich apple pear compote rich lemon fresh',
#  'rose baked spice juicy fleshy cherry raspberry pepper bright supple',
#  'wood wood toast spice yellow fruit ripe rich',
#  'soft stone melon fresh clean soft stone dry fresh apple',
#  'rich smoke wood perfumed fruit wood',
#  'ripe apple soft pepper spice rich lemon fresh soft cheese',
#  'white ripe green pear fresh bright lemon',
#  'heady honeysuckle white stone fruit dill hay vegetal tomato tangy juicy grapefruit white peach honeydew saline depth',
#  'tart yellow fruit cucumber green lemon steel oak minerality rich gripping',
#  'sanguine jam rich plush fruit beef_jerky cedar cranberry crisp edgy leather pepper',
#  'residual_sugar peach pear lemon voluptuous spice flower jasmine dry',
#  'cherry rocks meditteranean_herbs vibrant tangy succulent nectarine cherry strawberry minerality',
#  'firm chewi dark earth umami roasted_meat asphalt mushroom length ripe tannin',
#  'chocolate blackberry hearty oak cigar coffee brawny',
#  'earth complex juicy blackberry bitter tea concentrated oak',
#  'opulent blackberry jam grapey dry fruit concentrated tart tannin rich mellow',
#  'dense depth wood smoke blackberry berry clove dark chocolate full_bodied gripping rich',
#  'spice fruit hard dry',
#  'pepper clove leather cigar succulent fruit smoke',
#  'fruit spice chewi cherry ripe cinnamon cardamom light_bodied astringent',
#  'spice herb plum cassis olive fresh dense leafy berry plum olive herb spice',
#  'smoke oak savory plum berry abrasive lemon_peel toast cassis chocolate toast',
#  'dry purple_flower dark cardamom spice blackberry roast_beef soy pepper chewi dark pencil_lead blueberry asphalt',
#  'gravel asphalt complex bright cherry strawberry fruit rocky minerality spice pepper',
#  'tannin fresh berry cherry firm',
#  'dust slate saffron zesty lime honey light_bodied concentrated marmalade',
#  'mint dry cherry oak bright ripe fruit dense fresh complex',
#  'smoke oak tight gripping fruit leather chocolate tobacco lengthy powerful',
#  'lees burnt banana toast lime dry apple elegant',
#  'fresh strawberry complex mushroom yeast sparkling mousse heavy',
#  'oak spice rich concentrated complex velvety',
#  'funky foamy nectarine yeast bread',
#  'crisp thyme blackberry tar medium_bodied juicy cassis',
#  'dry cherry strawberry anise lush velvety ripe berry cherry concentrated pomegranate bramble',
#  'brilliant fresh tight zingy citrus apple toast bright tangy',
#  'honey crisp fruit concentrated light_bodied ripe light_bodied',
#  'ripe clean perfumed zesty rich green fruit apple green plum refreshing',
#  'spice earth lengthy concentrated cardamom pine fruit dark bramble crisp spice',
#  'smooth licorice coffee tobacco dry herb fruit leather violet',
#  'cherry raspberry dry violet graphite full_bodied blueberry cherry espresso soft round elegant',
#  'fruit dry tannin concentrated firm',
#  'ripe fruit fresh crisp minerality steel fresh lemon lime',
#  'sage dark cranberry butter cherry fresh marjoram wet_rocks thyme bay_leaf anise rich cranberry fruit tannin gripping dark fruit depth',
#  'forest_floor herb leather berry ripe chewi cherry sage licorice toasted_nut tight',
#  'pale pink_color lime_peel wet_rocks bright citrus',
#  'dust apple minerality crisp round stone apple quince',
#  'tight wood brine citrus dry stone fruit racy dry apricot tart nectarine almond',
#  'scorched_earth game truffle plum ripe dry blackberry cherry anise almond firm',
#  'chocolate spice powerful',
#  'cherry rose spice round savory juicy fleshy cherry raspberry star_anise coffee polished',
#  'rose violet berry menthol cooked spice linear cherry orange_peel clove white pepper licorice tobacco firm',
#  'fruit herb firm savory soy_sauce plum ripe cherry warm earth plum berry',
#  'dry dry plum clove scorched_earth balsamic concentrated dry cherry raisin licorice pepper firm',
#  'luminous fresh berry violet herbs baked spice vibrant linear cherry strawberry white pepper star_anise racy polished',
#  'violet perfumed berry baked spice sleek savory ripe cherry raspberry cinnamon clove star_anise firm polished',
#  'berry herbs blue_flower menthol elegant juicy ripe cherry raspberry licorice vanilla round',
#  'dark tobacco violet soy pepper plum wood pepper dry violet lavender thyme rosemary elderberry',
#  'concentrated concrete oak flower light_bodied toast length',
#  'oil ripe caramel toast depth gold crisp green apple melon complex minerality supple',
#  'zesty fresh rich oak smoke caramel pear vanilla oak apple white peach nectarine lime_peel',
#  'depth cassis berry racy tight full_bodied berry pepper baked spice chocolate toast pepper juicy',
#  'rose blue_flower incense truffle pepper coffee licorice depth bright fruit polished smooth silky fresh',
#  'fruit tangy rich juicy light_bodied spice green fruit zesty bitter orange fruit',
#  'sweet oak vanilla plum violet coffee oak ripe cherry leather baked spice tight closed',
#  'undergrowth tobacco leather truffle blackberry toast fig cherry carob bitter cocoa white pepper dry',
#  'smooth cherry allspice elegant fruit',
#  'butter toast nut minerality apple butter cinnamon vanilla',
#  'elegant sparkling rose berry yeast fresh baked depth tart apple strawberry sage marjoram brisk elegant mousse',
#  'fresh refined fruit wild_berry forest_floor pine rose bright strawberry cherry vanilla cinnamon smooth supple bright',
#  'light_bodied austere plum blackberry weight fruit',
#  'dark dense powerful concentrated firm fruit',
#  'crisp grapefruit tight tangy steel fruit austere',
#  'sugar juicy sweet rich fruit ripe grapefruit peach apricot length',
#  'grilled_meat pepper jam blackberry coffee bitter powerful',
#  'light_bodied toast tobacco blueberry pie cedar fresh blueberry cigar',
#  'oak tight dense cherry chocolate licorice baked spice silky full_bodied',
#  'heavy coffee dark cherry coffee',
#  'berry cherry minerality',
#  'mint hot gravel fruit light_bodied complex herb spice blackberry fruit',
#  'reedy berry eucalyptus tight tannin dry leafy herb fruit licorice coffee dry snappy earth spice olive mint',
#  'vibrant slate peach apricot citrus dry depth rich fruit',
#  'strawberry cake dry purple_flower cigar_box elegant purple fruit leather pepper tart',
#  'ripe lush complex plum cassis gripping snappy',
#  'elegant pear ginger lemon herb',
#  'flint smoke nectarine citrus ginger white pepper balsamic depth complex',
#  'plum asphalt oak toast spice forest_floor cherry coffee licorice minerality',
#  'ripe spice rich fruit depth minerality',
#  'plush oak depth berry cassis chocolate coffee wood spice rich berry fruit oak',
#  'flower perfumed lavender pepper white pepper thyme tart plum savory dry purple_flower thyme rosemary pepper medium_bodied dense',
#  'baked pear fruit honeysuckle apple fresh',
#  'ripe fruit brilliant fruit dense',
#  'fruit asphalt pepper rosemary lavender plum light_bodied tar juicy purple fruit',
#  'feral game rosemary dry fennel rose forest_floor blackberry light_bodied firm rosemary lavender game',
#  'light_bodied gold bright jasmine succulent steel minerality powerful',
#  'wood rich spice fruit ripe raspberry fruit lemon',
#  'light_bodied crisp tight elegant fruit spice tangy minerality fruit',
#  'rich dark fruit tannin',
#  'dry ripe fruit berry lemon juicy full_bodied rich',
#  'perfumed ripe yellow fruit currant citrus',
#  'rich oil lavish opulent plump blueberry soft spice cherry dark chocolate caramel powerful',
#  'oak viscous green apple melon peach honeysuckle grapefruit_peel voluptuous weight ripe',
#  'oak perfumed tart boysenberry rich caramel oak cola plum gravel bay_leaf meaty depth',
#  'fresh herb lemon olive citrus fresh apple fruit',
#  'earth dust loamy rich grippy chewi oak dark chocolate clove tobacco blueberry blackberry',
#  'meaty smoke pepper dense blue fruit powerful coffee chocolate',
#  'rich pastry raspberry tart tangy gripping length',
#  'powerful toffee weight nut salt caramel dry apricot buttery_toast umami racy',
#  'cola cocoa graphite tobacco blackberry fruit light_bodied elegant',
#  'rich almond peach apple pear fruit light_bodied bright wet_rocks gravel',
#  'stone',
#  'shine violet blueberry light_bodied pepper elegant clove',
#  'ripe fruit raisin tire_rubber toast french_oak dark tight gripping oak cassis blackberry firm closed',
#  'edgy cherry plum mulberry pepper spice sage rich full_bodied tangy plum eucalyptus fresh',
#  'butter rich smoke honeysuckle almond apple cream marshmallow pear citrus',
#  'grapefruit green tea cola sleek berry',
#  'ocean feral robust fruit tart cranberry orange_peel',
#  'hearty spice cherry cardamom spice sanguine meaty dry cherry indian_spice olive gripping',
#  'undergrowth fruit toast coffee oak coffee coconut vanilla coffee dry cherry prune clove raspy fruit rich dry',
#  'ripe fruit heavy toast fruit weight dark juicy',
#  'herb earth fruit dense dust ripe sweet plum wood rich spice',
#  'weight fruit ripe berry fruit fresh powerful dry dense',
#  'ripe smooth rich raspberry fresh fruit juicy',
#  'depth blueberry prune dry purple bacon purple fruit juicy sharp licorice edgy',
#  'brine bell_pepper vegetal round celery bell_pepper lime tangerine grass brine',
#  'rich pineapple apple',
#  'tropical_fruit citrus bell_pepper zesty lemon tangerine brine citrus juicy crisp',
#  'minerality white oak vanilla brioche viscous vibrant fruit ripe apple apricot',
#  'cherry plum rubber raisin depth light_bodied herb flower plum cherry oak resin elegant',
#  'fresh fruit polished raspberry plum chocolate blackberry rich firm fruit',
#  'wildflower lemon_peel dry citrus white grapefruit bitter_almond white fresh',
#  'dense earth meaty light_bodied tannin forest_floor plum baked',
#  'vibrant elegant cherry raspberry alpine_herbs supple bright',
#  'foamy sparkling sparkling apple ripe pear low_complexity apple white flower guava tropical_fruit',
#  'ripe fruit spice undergrowth dry herb dry cherry plum clove sage',
#  'spice tight pear fruit white pepper watery cracker',
#  'dense earth berry fruit latex crisp fresh hot light_bodied herb leather currant wild_berry oak',
#  'coffee tobacco cedar fruit elegant currant dry cherry clove anise silky',
#  'concentrated berry fruit soft fresh fruit',
#  'sawdust oak spice currant toast oak coffee menthol pepper dry cherry grippy astringent',
#  'fresh strawberry fruit spice tart lemon',
#  'crisp dry tannin cranberry ripe cherry dry currant savory dry herb clove',
#  'dense concentrated prune tobacco leather syrupy blackberry extracted fig sweet spice velvety complex',
#  'firm spice plum violet spice juicy ripe cherry licorice clove tight refined',
#  'fruit cherry hard candy light_bodied herb stemmy fruit',
#  'concentrated fruit powerful juicy fruit',
#  'dark raspberry fruit graphite dark earth rocks earth juniper sour',
#  'white citrus flower soft lemon_curd orange white fruit rich high_alcohol',
#  'berry undergrowth leather fennel herb firm vibrant ripe cherry raspberry licorice coffee balsamic',
#  'smooth smoke edgy purple plum berry fruit silky length',
#  'fruit ripe currant berry spice wood fresh juicy',
#  'ripe fruit spice tannin cherry raspberry sweet chocolate',
#  'resin oak stalky berry cherry raspberry grabby clampy oak berry baked plum oak raisin licorice',
#  'fruit blue_flower round dry cherry blackberry jam licorice tobacco chewi',
#  'dark blackberry pepper juniper berry smooth plum blackberry white peach elderberry violet eucalyptus fresh cherry juicy',
#  'strawberry dense powerful tight oak spice',
#  'fresh apple pear fresh herb citrus_peel honey steel',
#  'raisin white pepper ripe fruit flower spice anise full_bodied hearty complex firm',
#  'dark strawberry plum caramel smoked_meat blackberry blueberry smoked_meat vanilla coffee vanilla silky orange_peel',
#  'blue_flower plum licorice clove coffee menthol brawny warm full_bodied juicy cherry coffee pepper anise hot',
#  'concentrated wood light oak ripe yellow fruit crisp tangy spice bright',
#  'rich concentrated almond hazelnut light_bodied lengthy lemon_peel apple',
#  'flower cherry pomegranate fresh pepper pomegranate strawberry mace anise smooth bright',
#  'soft ripe nectarine citrus edgy pith orange bitter dry apple',
#  'fruit minerality fruit gripping powerful dense herb',
#  'dark cherry flower cherry matchstick petrol cherry pomegranate bell_pepper light_bodied flower chewi orange_peel cranberry',
#  'dark berry coffee toast cooked spice cherry coffee dry herb',
#  'vanilla soft spice fruit mellow sweet',
#  'rose bright berry anise sour cherry tobacco clove herbs brisk',
#  'brawny plum coffee menthol dense chewi cherry licorice coffee warm',
#  'rose berry coffee herb toast crunchy cherry raspberry star_anise white pepper tight assertive closed coffee',
#  'earth leather game earth berry dry cherry coffee coffee licorice tobacco fresh',
#  'dark berry blue_flower spice firm ripe cherry white pepper cocoa star_anise balsamic',
#  'cherry plum butter oak leather firm ripe loamy berry cassis light_bodied raisin round',
#  'wild_berry dark spice menthol low_complexity dark cherry licorice dry herb firm ripe',
#  'oak toast brown_sugar coffee fruit dark berry cola clove cinnamon cream lush weight dry fruit vanilla coffee',
#  'fresh toast light_bodied cranberry cherry fruit tart oak',
#  'clean crisp bright steel wood fresh fruit apple melon ginger racy',
#  'yellow apple chamomile flower ripe acacia bitter_almond',
#  'smoke toast oak butter viscous',
#  'clean citrus grapefruit orange soft tart',
#  'sweet clean crisp citrus apple orange_peel',
#  'light_bodied spritzy crisp apple refreshing bright tangy',
#  'dry sparkling spice berry fruit depth rich oily',
#  'soft cream fruit yeast edgy',
#  'soft herb smooth bright crisp citrus gooseberry',
#  'white fruit crisp refreshing herb edgy lemon grapefruit zingy bright',
#  'dust plum berry clean hard salt snappy plum dry',
#  'yeast toast fruit crisp bright',
#  'butter butter spice vanilla cream smooth',
#  'soft fresh apple apple crisp clean',
#  'minerality tight yeast crisp bright apple fruit',
#  ...]

# %%
## create embedding vectors for each review
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit(mapped_reviews)
dict_of_tfidf_weightings = dict(zip(X.get_feature_names(), X.idf_))

# %%
dict_of_tfidf_weightings
# Out:
# {'abrasive': 8.678601285345636,
#  'acacia': 7.609402881883819,
#  'aggressive': 6.33623822089467,
#  'airy': 7.882269868550459,
#  'allspice': 7.614390423394858,
#  'almond': 4.740825783815074,
#  'alpine_herbs': 9.511510408280738,
#  'american_oak': 7.501061738087855,
#  'angular': 6.792410370991944,
#  'anise': 5.185172679467446,
#  'apple': 3.513070247436332,
#  'apple_sauce': 8.424071420210755,
#  'apricot': 4.425149403656348,
#  'ash': 7.69235196486457,
#  'asian_spice': 6.700101694191376,
#  'asparagus': 7.179366513045149,
#  'asphalt': 7.18260800696932,
#  'assertive': 6.630441043046888,
#  'astringent': 5.233918791743741,
#  'austere': 5.729596088199614,
#  'bacon': 5.610885447804963,
#  'baked': 4.6506649459759535,
#  'baked_bread': 7.9568807323416335,
#  'balsamic': 6.163948242451215,
#  'banana': 5.867802672813524,
#  'barbecue': 6.151135021138839,
#  'bark': 7.837533974709068,
#  'barnyard': 6.923746373053031,
#  'basil': 7.8128413621186965,
#  'bay_leaf': 8.481890991099581,
#  'beef_jerky': 7.432068866600903,
#  'beefy': 7.843803587722663,
#  'beeswax': 7.882269868550459,
#  'beet': 7.69235196486457,
#  'beetroot': 8.678601285345636,
#  'bell_pepper': 6.747289935711475,
#  'bergamot': 8.38010829678964,
#  'berry': 3.2192624868013215,
#  'bite': 5.887169475304374,
#  'bitter': 4.646286316958341,
#  'bitter_almond': 6.946561050819202,
#  'bittersweet': 9.249146143813249,
#  'black_pepper': 12.219560609382949,
#  'blackberry': 3.0725328436185326,
#  'blackcurrant': 7.281496008121529,
#  'bland': 7.202280772568025,
#  'blood_orange': 8.738320520047257,
#  'blossom': 9.416200228476415,
#  'blue': 6.985781763972484,
#  'blue_flower': 6.610088814197989,
#  'blueberry': 4.760509774081108,
#  'bone_dry': 5.827643495990348,
#  'botrytis': 6.716263662148374,
#  'boysenberry': 6.160437413801152,
#  'bramble': 5.598820958309433,
#  'brawny': 7.04341087680912,
#  'bread': 8.249268695830828,
#  'bread_crust': 9.223828335828959,
#  'brick': 8.307537603954803,
#  'bright': 3.6670002741294208,
#  'brilliant': 6.478161271155441,
#  'brine': 6.8724530786654805,
#  'brioche': 7.492172790670609,
#  'brisk': 5.372086261285742,
#  'brown': 7.329211481161195,
#  'brown_butter': 9.199135723238587,
#  'brown_sugar': 6.351677124046322,
#  'bubble_gum': 8.543259937475874,
#  'bubblegum': 8.41289811961263,
#  'bulky': 7.332977963956672,
#  'bullish': 8.664212547893536,
#  'buoyant': 7.411449579398168,
#  'burnt': 5.666339709840433,
#  'butter': 5.184292010101853,
#  'butter_nut': 8.785573404897804,
#  'butter_popcorn': 7.448875984917285,
#  'buttercream': 7.665683717782408,
#  'butterscotch': 5.814332151352108,
#  'buttery_toast': 5.571223937579734,
#  'cake': 7.034972008163256,
#  'campfire': 7.818957589136132,
#  'camphor': 9.54541195995642,
#  'candle_wax': 9.106045300172575,
#  'candy': 4.501097361101722,
#  'caramel': 4.723463264206993,
#  'cardamom': 7.584831621153313,
#  'carob': 6.996505727335459,
#  'cashew': 9.175038171659526,
#  'cassis': 4.185415760733256,
#  'cataloupe': 7.432068866600903,
#  'cedar': 4.63529579099389,
#  'celery': 7.825111454710511,
#  'cement': 8.753824706583224,
#  'chalk': 5.79875168037686,
#  'chamomile': 8.307537603954803,
#  'charcoal': 7.69235196486457,
#  'cheese': 5.751861883278596,
#  'chemical': 7.992726864114769,
#  'cherry': 2.4053688593324094,
#  'chewi': 5.016155088299854,
#  'chocolate': 3.607602841522289,
#  'choppy': 7.249747309806948,
#  'chunky': 5.440207045205336,
#  'cider': 8.41289811961263,
#  'cigar': 7.89542795312797,
#  'cigar_box': 7.2602186096742445,
#  'cinnamon': 4.67655212825977,
#  'citrus': 3.4548825352663437,
#  'citrus_peel': 6.772823237716639,
#  'citrus_pith': 8.1765093415484,
#  'clampy': 8.401848283426045,
#  'classy': 6.724443666860305,
#  'clay': 7.978233856812203,
#  'clean': 3.861597643537269,
#  'closed': 4.409410703718768,
#  'clove': 5.097904360453535,
#  'cloying': 6.738921686040958,
#  'coarse': 8.007433011504464,
#  'cocoa': 5.219682041525006,
#  'coconut': 5.9523600608415865,
#  'coffee': 3.797227698990672,
#  'cola': 4.039659990971828,
#  'complex': 3.578734857521437,
#  'complicated': 7.2602186096742445,
#  'compost': 7.391246872080648,
#  'compote': 7.363631705047675,
#  'concentrated': 3.8880947678954993,
#  'concrete': 9.616870923938565,
#  'cooked': 6.495975507430568,
#  'cookie': 7.708701102866099,
#  'corn': 7.432068866600903,
#  'cotton_candy': 7.831303424958431,
#  'cracker': 7.708701102866099,
#  'cranberry': 5.276438186563521,
#  'cream': 3.872918519161751,
#  'crisp': 3.276772938563382,
#  'crunchy': 7.7365580573690655,
#  'cucumber': 8.20317758863056,
#  'cured_meat': 6.297982189739134,
#  'currant': 3.691229673556256,
#  'custard': 7.570373537978083,
#  'cut_grass': 7.317996410341055,
#  'dainty': 8.401848283426045,
#  'dark': 3.5766162126611514,
#  'dense': 4.010932701334917,
#  'depth': 4.243652249217411,
#  'diesel': 8.25874743978537,
#  'dill': 7.001911145902367,
#  'diluted': 7.107572821026406,
#  'dr_pepper': 10.514812517144524,
#  'dry': 2.656558334958495,
#  'dull': 6.743097057451439,
#  'dust': 4.6977013571813195,
#  'earth': 3.8732743699454124,
#  'earthy': 7.501061738087855,
#  'easy': 8.14202316547723,
#  'edgy': 4.31504121437678,
#  'effervescent': 7.281496008121529,
#  'elderberry': 8.481890991099581,
#  'elderflower': 9.416200228476415,
#  'elegant': 3.7187000725876094,
#  'espresso': 7.686961116229694,
#  'eucalyptus': 6.8442822016987845,
#  'expansive': 7.800720001586352,
#  'extracted': 5.244614080860489,
#  'exuberant': 6.608258987520913,
#  'fat': 6.267616820437251,
#  'feminine': 6.901440615538733,
#  'fennel': 7.09559662997969,
#  'feral': 8.401848283426045,
#  'fig': 5.467290233241207,
#  'finessed': 6.207068695082891,
#  'firm': 3.7267625748014335,
#  'fizz': 8.905374604710424,
#  'flabby': 7.166504599402741,
#  'flashy': 6.743097057451439,
#  'flat': 6.108093269880271,
#  'fleshy': 5.890731366870734,
#  'flint': 6.81238883792283,
#  'flower': 3.83054175669022,
#  'foamy': 7.263733551781688,
#  'forest_floor': 6.214439735827481,
#  'foxy': 8.100523434570476,
#  'french_oak': 6.553133921270517,
#  'fresh': 2.97660784967929,
#  'frothy': 7.963947899564726,
#  'fruit': 1.805407445882196,
#  'fruity': 8.358830898342354,
#  'fudge': 7.599501810901107,
#  'full_bodied': 4.5093554149504165,
#  'funky': 6.0894216675872075,
#  'game': 6.265019416379565,
#  'ginger': 6.411418119402505,
#  'gingerbread': 8.20317758863056,
#  'gold': 6.158103690454932,
#  'gooseberry': 6.104772846242969,
#  'grabby': 6.512450344634074,
#  'graham_cracker': 7.391246872080648,
#  'grain': 7.771044233440235,
#  'grainy': 7.432068866600903,
#  'granite': 7.676265827112945,
#  'grapefruit': 4.633264302230229,
#  'grapefruit_peel': 8.801833925769582,
#  'grapefruit_pith': 9.041506779035004,
#  'grapey': 6.83506554659386,
#  'graphite': 6.202184680490467,
#  'grass': 5.49512738752835,
#  'gravel': 7.929101168234558,
#  'green': 3.706174656309666,
#  'green_bean': 7.542069761815232,
#  'grilled_meat': 6.428072554307643,
#  'gripping': 6.04890439848994,
#  'grippy': 7.0100744565415285,
#  'gritty': 6.104772846242969,
#  'guava': 6.9287715092557045,
#  'gummy': 8.23987895548099,
#  'ham': 7.519080243590533,
#  'hard': 4.685599555594749,
#  'hay': 6.690131521871526,
#  'hazelnut': 7.1105894145658315,
#  'heady': 6.747289935711475,
#  'hearty': 6.384749872320344,
#  'heavy': 4.716270978707867,
#  'herb': 3.383986416765661,
#  'herbacious': 6.055193727397504,
#  'herbs': 7.419646346602346,
#  'hibiscus': 8.708015170551928,
#  'hickory': 7.753652490728365,
#  'hickory_smoke': 8.470056533452578,
#  'high_alcohol': 5.980259898370386,
#  'hollow': 7.510030408070615,
#  'honey': 4.208371351453489,
#  'honeycomb': 8.43537097546469,
#  'honeydew': 6.747289935711475,
#  'honeysuckle': 5.538705930592735,
#  'horsey': 8.581974449656563,
#  'hot': 4.7651300537411245,
#  'huckleberry': 9.734653959594949,
#  'incense': 8.133584296831366,
#  'indian_spice': 6.901440615538733,
#  'inky': 6.4296004384856955,
#  'iodine': 8.358830898342354,
#  'iron': 7.403319453314917,
#  'jagged': 7.546731774921043,
#  'jam': 4.086854119689685,
#  'jasmine': 6.918746362636325,
#  'jelly': 6.777142898861156,
#  'juicy': 3.7716103207088727,
#  'juniper': 7.8501127569159275,
#  'kirsch': 7.719750939052684,
#  'kiwi': 6.050996449462164,
#  'kumquat': 8.530681155269013,
#  'lactic': 7.6345931307123776,
#  'lanolin': 7.929101168234558,
#  'latex': 8.63604167092684,
#  'lavender': 6.716263662148374,
#  'lavish': 7.218975651140195,
#  'leafy': 5.579031394285211,
#  'lean': 4.940931667062267,
#  'leather': 4.136849475145368,
#  'lees': 6.017025092195027,
#  'lemon': 4.205390229669682,
#  'lemon_curd': 7.9710653673335905,
#  'lemon_custard': 8.221359907713751,
#  'lemon_drop': 7.949863159682987,
#  'lemon_meringue': 8.650027912901578,
#  'lemon_peel': 6.029245203529802,
#  'lemon_pith': 9.329188851486785,
#  'lemon_verbena': 8.835170346037176,
#  'lemongrass': 7.032174803542194,
#  'length': 5.524998550861854,
#  'lengthy': 7.14751668715805,
#  'lettuce': 8.44679967128831,
#  'licorice': 4.2415925162544,
#  'light': 8.000052904206843,
#  'light_bodied': 3.2960360185305895,
#  'lilac': 8.348359598475058,
#  'lime': 4.36537344161467,
#  'lime_peel': 7.270800719004781,
#  'lime_pith': 8.43537097546469,
#  'limestone': 9.0840663934538,
#  'linear': 6.310119897753558,
#  'loamy': 7.432068866600903,
#  'low_alcohol': 7.759416195445116,
#  'low_complexity': 5.904202607860615,
#  'luminous': 6.738921686040958,
#  'lush': 4.670741229711092,
#  'luxurious': 7.225732433603075,
#  'lychee': 6.254696744072146,
#  'mace': 9.777213574013745,
#  'mandarin': 9.58050327976769,
#  'mango': 5.701151056629094,
#  'maple': 8.268316890801522,
#  'maple_syrup': 7.395254893478187,
#  'marjoram': 9.357359728453481,
#  'marmalade': 7.029385401454616,
#  'marshmallow': 7.79471397752614,
#  'masculine': 7.049076614344798,
#  'mass': 7.556121515270882,
#  'matchstick': 8.568902368089212,
#  'mealy': 7.295936692276324,
#  'meat': 5.772254746841736,
#  'meaty': 5.560907920885118,
#  'medicinal': 6.2046237060898255,
#  'meditteranean_herbs': 7.888827269096618,
#  'medium_bodied': 5.962851334942122,
#  'medium_length_finish': 8.493867182146296,
#  'medium_sweet': 7.831303424958431,
#  'mellow': 6.1373416990065035,
#  'melon': 4.467225446080658,
#  'melon_rind': 8.693200084766788,
#  'melted_butter': 8.961464071361467,
#  'menthol': 6.146516075282545,
#  'metal': 7.670960774883253,
#  'milk_chocolate': 5.940101538641141,
#  'minerality': 3.4859665475198947,
#  'mint': 4.724852346247271,
#  'modest': 5.625831378192195,
#  'moist_earth': 7.218975651140195,
#  'molasses': 6.610088814197989,
#  'moss': 7.665683717782408,
#  'mousse': 7.355879728243357,
#  'mulberry': 7.141266666812879,
#  'mulch': 8.317587939808305,
#  'murky': 7.387254850811111,
#  'muscular': 6.549679686402429,
#  'mushroom': 5.769880388781274,
#  'musky': 7.570373537978083,
#  'mustard': 8.852264779396474,
#  'nectar': 8.708015170551928,
#  'nectarine': 5.607519574549857,
#  'nervy': 7.379318301215374,
#  'nettle': 7.594587796098678,
#  'nut': 5.53432407694618,
#  'nutmeg': 6.193694635557635,
#  'oak': 2.877972700797094,
#  'oaked': 8.150533855145138,
#  'ocean': 8.348359598475058,
#  'oil': 6.599159743665799,
#  'oily': 6.271525620202303,
#  'olallieberry': 9.446971887143167,
#  'olive': 5.416610444766938,
#  'opulent': 5.155656647910881,
#  'orange': 4.912358294618211,
#  'orange_blossom': 6.999204784304625,
#  'orange_marmalade': 7.565600259225426,
#  'orange_peel': 5.663492732828505,
#  'oregano': 7.379318301215374,
#  'over': 8.150533855145138,
#  'overripe': 5.996984341311581,
#  'oxidized': 7.119694181558751,
#  'pale': 6.678297064224523,
#  'papaya': 6.274140000776375,
#  'passion_fruit': 8.068520703484303,
#  'pastry': 7.046239733009598,
#  'pea': 8.1942089186478,
#  'peach': 3.6893524808892173,
#  'peach_pit': 8.212227424150479,
#  'peanut': 8.530681155269013,
#  'pear': 3.9476287745345404,
#  'pencil_lead': 7.676265827112945,
#  'pencil_shaving': 8.1765093415484,
#  'pepper': 3.5693236442089473,
#  'perfumed': 5.001383770979542,
#  'persimmon': 7.542069761815232,
#  'petal': 8.835170346037176,
#  'petrol': 6.9038946045003,
#  'phenolic': 8.287734976658623,
#  'pickled': 7.18260800696932,
#  'pie': 5.5475276639218825,
#  'piercing': 7.034972008163256,
#  'pillowy': 9.020887491832267,
#  'pine': 6.792410370991944,
#  'pineapple': 4.118337510720023,
#  'pink': 7.107572821026406,
#  'pink_color': 8.297587273101636,
#  'pith': 6.312837290730058,
#  'plastic': 8.052895385581223,
#  'plum': 3.321263310771483,
#  'plump': 5.405017712122991,
#  'plush': 5.599487402852593,
#  'polished': 4.861685581752216,
#  'pollen': 9.000684784514748,
#  'pomegranate': 5.856532505842484,
#  'pop': 7.1045652999624505,
#  'popcorn': 7.542069761815232,
#  'potpourri': 7.942894490366894,
#  'powdery': 8.327740311272322,
#  'powerful': 4.073431099357544,
#  'prickly': 7.046239733009598,
#  'prune': 5.28127612536599,
#  'puckery': 8.317587939808305,
#  'pulpy': 7.5751697102415765,
#  'punchy': 7.818957589136132,
#  'pungent': 6.333456577932793,
#  'purple': 6.425023771458284,
#  'purple_flower': 8.167775661579643,
#  'pyrazines': 8.785573404897804,
#  'quaffer': 7.6345931307123776,
#  'quince': 6.956870420478063,
#  'racy': 5.645182362114722,
#  'raisin': 4.983581302636095,
#  'raspberry': 3.51754898097417,
#  'raspy': 8.568902368089212,
#  'red_berry': 6.692117619843155,
#  'red_currant': 9.868185352219472,
#  'red_fruit': 11.814095501274785,
#  'reductive': 7.992726864114769,
#  'reedy': 8.36941300767289,
#  'refined': 5.748761105600347,
#  'refreshing': 4.824760235300225,
#  'residual_sugar': 6.070024507704472,
#  'resin': 5.989079161804467,
#  'restrained': 6.002954508298084,
#  'rhubarb': 6.221865512524332,
#  'rich': 2.7281097103380247,
#  'rind': 8.15911759883653,
#  'ripe': 2.675824155874305,
#  'roast_beef': 8.769573063551363,
#  'roasted_meat': 7.2089253152866934,
#  'robust': 6.140772234103292,
#  'rocks': 7.015553922306154,
#  'rocky': 8.543259937475874,
#  'root': 6.9038946045003,
#  'rose': 5.3951869393398635,
#  'rosemary': 7.074977342776955,
#  'rosewater': 9.199135723238587,
#  'rough': 5.858258131809954,
#  'round': 4.10883302640846,
#  'rubber': 5.588877223740577,
#  'ruby_color': 7.292306924225745,
#  'rum_cake': 7.619402965218402,
#  'rustic': 5.118296584216293,
#  'rusty': 8.505988542678642,
#  'saddle_leather': 8.708015170551928,
#  'saffron': 8.348359598475058,
#  'sage': 6.062581623797394,
#  'saline': 6.766378532273997,
#  'salt': 6.399477679030587,
#  'sandalwood': 5.561549563512201,
#  'sanguine': 8.568902368089212,
#  'sappy': 7.092624859590533,
#  'sassafras': 6.167471440458533,
#  'satiny': 8.185319971230554,
#  'savory': 4.7841225895683985,
#  'sawdust': 7.875755187529266,
#  'scorched_earth': 8.007433011504464,
#  'scratchy': 7.153806016065614,
#  'semisweet': 9.386347265326734,
#  'sharp': 4.748197521195852,
#  'shimmer': 9.128518156024633,
#  'shine': 6.83736175885421,
#  'shoe_polish': 8.125216047160848,
#  'silky': 4.520624409569502,
#  'simple': 7.523636060126393,
#  'sinewy': 8.493867182146296,
#  'sizzling': 8.36941300767289,
#  'slate': 6.807914557527909,
#  'sleek': 6.975171584860468,
#  'slick': 8.297587273101636,
#  'smoke': 3.7286087291719388,
#  'smoked_bacon': 7.60444009254169,
#  'smoked_meat': 6.586558316787795,
#  'smooth': 3.7760139581350103,
#  'snappy': 5.778614068750029,
#  'soapy': 7.665683717782408,
#  'soft': 3.0495735917559825,
#  'soil': 7.156965576355982,
#  'sorbet': 8.505988542678642,
#  'sour': 5.108456406414782,
#  'soy': 7.708701102866099,
#  'soy_sauce': 8.358830898342354,
#  'sparkling': 5.2783705543145745,
#  'spearmint': 7.837533974709068,
#  'spice': 2.523897054053199,
#  'spiky': 8.63604167092684,
#  'spring_flower': 7.44043711627142,
#  'spritzy': 7.029385401454616,
#  'stalky': 6.287315421934939,
#  'star_anise': 7.650017601038009,
#  'steak': 6.012984682658022,
#  'steel': 5.421620196408019,
#  'stemmy': 6.220624047436266,
#  'stewed_prune': 8.801833925769582,
#  'sticky': 6.437275073238805,
#  'stone': 4.65817890800315,
#  'stone_fruit': 8.769573063551363,
#  'stout': 8.133584296831366,
#  'straw': 8.212227424150479,
#  'strawberry': 4.600572682294482,
#  'struck_flint': 8.801833925769582,
#  'sturdy': 6.426547000998806,
#  'succulent': 5.809385727416783,
#  'sugar': 5.319333596821604,
#  'sulfur': 7.407376254010532,
#  'super_rich': 7.89542795312797,
#  'super_ripe': 6.421984255440387,
#  'supple': 5.135334187285033,
#  'sweat': 7.086707682562444,
#  'sweet': 2.832078740654354,
#  'syrupy': 5.776224581352647,
#  'tangerine': 5.396818704727769,
#  'tangerine_peel': 8.317587939808305,
#  'tangy': 4.797784815738302,
#  'tannin': 3.9374570402993223,
#  'tar': 5.707072613532531,
#  'tarragon': 7.843803587722663,
#  'tart': 4.033792413366411,
#  'tea': 5.422178387882183,
#  'thick': 4.706397064148874,
#  'thyme': 6.5688273558165635,
#  'tight': 4.161233302801992,
#  'tingling': 6.647406577205185,
#  'tingly': 8.23987895548099,
#  'tire_rubber': 7.156965576355982,
#  'toast': 3.616740331999275,
#  'toasted_hazelnut': 8.221359907713751,
#  'toasted_nut': 6.500889522232997,
#  'tobacco': 4.228306679542751,
#  'toffee': 6.8844292697121965,
#  'tomato': 6.706131863217967,
#  'tree_bark': 7.6977720323339085,
#  'tropical_fruit': 4.595185793655725,
#  'truffle': 6.688149360667535,
#  'umami': 8.230576562818674,
#  'undergrowth': 7.054774635459435,
#  'underripe': 7.176135492463703,
#  'unoaked': 7.501061738087855,
#  'unripe': 6.69610168885803,
#  'vanilla': 3.4687192340074167,
#  'vegetal': 5.938228878917849,
#  'velvety': 5.127818494287796,
#  'vibrant': 5.101544404917616,
#  'vinegar': 8.568902368089212,
#  'violet': 5.297902425231821,
#  'viscous': 6.9491284463244485,
#  'voluptuous': 6.999204784304625,
#  'walnut': 7.542069761815232,
#  'warm': 4.761951319667343,
#  'watermelon': 7.375373522924358,
#  'watery': 6.686171120655429,
#  'wax': 6.736840519837133,
#  'weed': 7.411449579398168,
#  'weight': 4.744221372816213,
#  'wet_clay': 9.199135723238587,
#  'wet_earth': 7.092624859590533,
#  'wet_rocks': 6.626709695434029,
#  'white': 3.6799212291368817,
#  'white_flower': 6.075374975257303,
#  'wild_berry': 5.341234141091625,
#  'wildflower': 7.141266666812879,
#  'wood': 4.0144788043416675,
#  'wood_spice': 7.806762316042314,
#  'woody_berry': 8.622248348794503,
#  'yeast': 5.836898925964507,
#  'yellow': 5.242279267752202,
#  'yellow_flower': 7.79471397752614,
#  'zest': 6.387678132099432,
#  'zesty': 5.0830774007927015,
#  'zingy': 6.985781763972484,
#  'zippy': 6.975171584860468}

# %%
review_vectors = []
for review in mapped_reviews:
    numwords = 0
    words = review.split(' ')
    tfidf_mapped_review = []
    for word in words:
        if word in dict_of_tfidf_weightings.keys():
            tfidf = dict_of_tfidf_weightings[word]
            vec = tfidf * model.wv.get_vector(word).reshape(1, 300)
            tfidf_mapped_review.append(vec)
            numwords = numwords + 1
    if len(tfidf_mapped_review) > 0:
        weight_rev_vec = sum(tfidf_mapped_review)/len(tfidf_mapped_review)
    else:
        weight_rev_vec = []
    review_vectors.append(weight_rev_vec)

# %%
print(model.wv)
# Out:
# <gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fe675d8f520>

# %%
query = ['peach']

# %%
import numpy as np
vectors_list = []
for vec in review_vectors:
    if len(vec) == 1:
        vectors_list.append(np.float32(vec[0]))
    else:
        vectors_list.append(np.float32(np.zeros(300)))

# %%
from sklearn.neighbors import NearestNeighbors
knn = NearestNeighbors(n_neighbors=10, algorithm= 'brute', metric='cosine')
modelknn = knn.fit(vectors_list)

# %%
weightedqueryterms = []
for term in query:
    if term in dict_of_tfidf_weightings:
        tfidfweight = dict_of_tfidf_weightings[term]
        word_vector = tfidfweight * model.wv.get_vector(term).reshape(1,300)
        weightedqueryterms.append(word_vector)
    else:
        try:
            print(term)
            word_vector = model.wv.get_vector(term)
            word_vector.shape(1,300)
            print(word_vector)
            weightedqueryterms.append(word_vector)
        except:
            print("???")
query_vec = sum(weightedqueryterms)
distance, indice = modelknn.kneighbors(query_vec, n_neighbors = 5)

# %%
distance_list = distance[0].tolist()[1:]
indice_list = indice[0].tolist()[1:]

# %%
distance_list
# Out:
# [0.0, 0.0, 0.0, 0.040747876738546185]

# %%
indice_list
# Out:
# [135946, 41537, 7739, 16315]

# %%
for i in indice_list:
    print(i)
    review = mapped_reviews[i]
    location = data['province'][i]
    wine = data['variety'][i]
    print(location)
    print(wine)
    print(review)
    print()
# Out:
# 135946
# Mosel-Saar-Ruwer
# Riesling
# peach
#
# 41537
# Mosel-Saar-Ruwer
# Riesling
# peach
#
# 7739
# Virginia
# Viognier
# peach
#
# 16315
# South Australia
# Chenin Blanc
# peach concentrated peach peach fruit

# %%
#new word embedding tfidf matrix of reviews
np.array(vectors_list).shape
# Out:
# (149149, 300)

# %%
#cleaned and mapped reviews (with only wine words)
mapped_reviews
# Out:
# ['oak juicy fruit caramel elegant mint',
#  'ripe fig blackberry cassis sweet oak chocolate vanilla rich chocolate fruit baked spice toast heady',
#  'complex white dark gold toasted_hazelnut pear compote orange_peel succulent residual_sugar',
#  'oak fruit dense toast toast cigar_box blackberry cherry coffee graphite polished dark chocolate coffee',
#  'dense wood rich concentrated',
#  'depth dense dark ripe fruit oak blackberry coffee coffee toast oak spice smooth heady',
#  'gritty sweet pastry prune blackberry coffee chocolate',
#  'lush cedar almond vanilla tannin lush chocolate baked berry cassis hard tannin depth',
#  'minerality chunky fruit citrus graphite concentrated',
#  'bright crunchy cranberry pomegranate orange_peel silky succulent fleshy fruit lush length',
#  'elegant complex white yellow spring_flower herb fruit cream juicy white peach ripe pear citrus white almond savory minerality',
#  'supple coffee cherry vanilla savory',
#  'green cola tobacco orange vanilla tea milk_chocolate ripe blackberry fruit',
#  'ripe fruit dry berry fruit',
#  'minerality tart fruit supple dense strawberry blueberry plum cherry chocolate minerality silky',
#  'succulent minerality rich butterscotch lees',
#  'blueberry pie chocolate smooth silky complex cedar pepper pepper oak dense rich finessed spice',
#  'oak blackberry licorice vanilla smooth coffee blackberry raspberry fruit chocolate velvety',
#  'powerful fruit wood dark rich concentrated elegant restrained',
#  'fresh cherry tangy crisp orange_peel cherry pomegranate baked spice',
#  'strawberry watermelon orange_peel salt spice vibrant flower',
#  'complex powerful grilled_meat berry tea smoke vanilla spice concentrated elegant blackberry molasses coffee chocolate oak',
#  'tar blackberry cheese oak expansive grabby bullish salt earth blackberry baked spice chocolate chocolate hard tannin',
#  'white oak almond white peach sizzling salt lemon brown_butter rich finessed luxurious',
#  'fruit cherry sage eucalyptus ripe plum strawberry fruit juniper pine bay_leaf',
#  'silky hickory_smoke white peach lime_peel',
#  'jelly rose plum complex fruit cola brown_sugar',
#  'dense ripe raspberry oak coffee coffee cedar cinnamon dark chocolate',
#  'cranberry baked rhubarb anise slate raspberry fruit earth loamy fennel oregano juniper round',
#  'stone earth brine olive green olive orange_peel gravel smoked_meat cured_meat',
#  'dry cherry plum fresh pepper eucalyptus soft dry cherry cassis plum',
#  'steel perfumed oak vibrant fresh baked apple lemon_pith grapefruit spice',
#  'undergrowth scorched_earth menthol plum chewi ripe cherry raspberry jam pepper licorice firm velvety warm',
#  'wet_rocks honeysuckle chamomile stone fruit',
#  'forest_floor berry leather ripe fleshy cherry dry herb tobacco gripping',
#  'spice fresh pear melon fruit round flabby warm spice',
#  'forest_floor violet berry dark baked spice cherry raspberry pepper star_anise firm',
#  'rose violet berry juicy ripe cherry mint white pepper star_anise complex savory fresh supple',
#  'bright savory juicy cherry raspberry violet white pepper coffee polished',
#  'earth plum cherry round smooth light_bodied brine earth plum cherry salt',
#  'expansive oily hazelnut toffee plump light_bodied buttery_toast toffee peanut',
#  'scorched_earth plum dry flower green herb dense tart',
#  'rose herb round juicy ripe cherry fleshy raspberry white pepper clove polished smooth velvety',
#  'dark coffee plum fruit soft dust',
#  'violet plum coffee forest_floor firm dry cherry pepper toast clove',
#  'earth ripe berry baked spice menthol juicy cherry pomegranate star_anise coffee tobacco',
#  'juicy cherry cassis pillowy tar fruit',
#  'ripe forest_floor cooked spice leather chewi fleshy cherry cinnamon vanilla tobacco polished',
#  'blue fruit herb spice tight restrained firm grain length',
#  'robust coffee plum cake toast dark spice hearty blackberry jam licorice vanilla coffee firm coffee closed',
#  'complex minerality weight tight tannin',
#  'ripe ripe green fruit lime rich apricot concentrated fruit',
#  'light_bodied smoke fruit fresh',
#  'white hazelnut cream vanilla round oak',
#  'wood spice cherry light_bodied elegant gripping',
#  'minerality citrus green fruit tight round',
#  'exuberant fruit tropical_fruit minerality edgy dry refreshing vibrant light_bodied honey',
#  'cherry herb minerality firm',
#  'savory coffee leather tobacco dark woody_berry chewi juicy plum cassis clove polished',
#  'concentrated ripe blackberry cassis pepper spice cedar oak blackberry hot sizzling',
#  'supple firm cherry mint earthy brown_sugar',
#  'smoke wood berry cassis flower oak plum cassis vanilla',
#  'tight toast tangy',
#  'concentrated fruit wood dense firm plum blackberry dark concentrated',
#  'fresh boysenberry blueberry sorbet mint tarragon dill hot gravel pepper light_bodied tobacco coffee boysenberry',
#  'steel crisp lemon minerality edgy juicy fresh',
#  'tight tobacco tea coconut',
#  'full_bodied dark chewi fruit cedar tobacco thick',
#  'juicy cherry vanilla oak cedar smooth medium_bodied coffee chocolate',
#  'sweet depth chocolate blackberry soft juicy rich dense elegant spice clove cinnamon',
#  'tight light_bodied bright cherry pomegranate rose',
#  'rose wild_berry dark cooked spice baked earth ripe cherry licorice game chocolate velvety warm closed',
#  'fruit fleshy fruit sweet dry dense length',
#  'ripe dark firm dense concentrated juicy berry firm',
#  'elegant sturdy currant fruit baked spice orange',
#  'round toast linear fresh crisp citrus almond',
#  'crisp white lean lemon grapefruit tangerine refreshing white peach',
#  'chocolate graham_cracker vanilla jam thick tobacco',
#  'undergrowth smoke coffee dark fruit ripe dry cherry licorice clove firm velvety',
#  'fruit tart toast coffee fresh',
#  'dark violet cherry lavender rose cherry raspberry herb silky bright cherry',
#  'berry baked spice dry mint vanilla white pepper sage anise orange_peel yellow peach cherry balsamic closed firm refined',
#  'hearty forest_floor leather licorice menthol firm chewi ripe cherry raspberry jam anise tobacco dark',
#  'woody_berry rose mint menthol mint cherry raspberry spice toast assertive bright',
#  'french_oak coconut vanilla spice plum powerful oak warm cherry licorice menthol',
#  'refreshing tight minerality fruit tangy crisp tight toast apple citrus tight',
#  'hot spice cinnamon clove pine depth plum dark cherry clove powerful leather',
#  'light_bodied concentrated ripe rich fruit kirsch cherry raspberry cinnamon lush plush',
#  'blackberry chocolate chalk full_bodied licorice cassis tea',
#  'bright light_bodied oak cherry strawberry fresh fruit',
#  'fruit sparkling bright crisp tangy currant',
#  'white spring_flower fruit citrus ripe yellow peach green apple foamy mousse',
#  'smoke earth smooth',
#  'light_bodied spice wood fruit ripe bright',
#  'smooth soft fruit ripe round edgy rich juicy fruit',
#  'oak crisp ripe pear baked spice soft smooth',
#  'austere modest crisp currant cranberry cedar dry herb',
#  'spice stalky bright berry fruit crisp light_bodied minerality',
#  'light_bodied refreshing bright perfumed herb citrus',
#  'juicy kiwi lime sour apple candy ripe oily honeydew',
#  'bramble herb bright ripe tar toffee rich cola',
#  'undergrowth berry toast low_complexity lean sour cherry green sage pepper astringent',
#  'leather tobacco pepper rustic edgy fruit mellow',
#  'sticky sweet oily candy honeydew kiwi sweet juniper pine gold honey soft oil thick',
#  'ripe lean overripe apple melon orange_peel fruit',
#  'wood smoke grilled_meat assertive oak dry herb medium_bodied soft',
#  'earth flower low_complexity fruit',
#  'dry earth savory fruit walnut almond',
#  'oak medium_bodied overripe honeysuckle lime lemon_peel',
#  'soft ripe light_bodied fruit',
#  'rubber citrus fruit round dry citrus',
#  'tannin oak hard ripe smoke oak currant concentrated powerful',
#  'savory apple pear lemon bramble earth tangerine bright sweet',
#  'tart gooseberry lime flower pith plum currant citrus_peel light_bodied astringent fresh herb saline closed',
#  'prune raisin plum gritty chunky grabby blackberry burnt coffee dark chocolate plump rubber closed',
#  'cherry cassis horsey hot sweet hard cherry cassis baked plum chunky',
#  'pale fruit crisp soft',
#  'soft fruit light fruit earth edgy',
#  'fruit ripe berry fruit soft smooth',
#  'robust oak cherry oak toast reductive smooth concentrated powerful ripe',
#  'full_bodied fruit round spice tart cherry',
#  'elegant sparkling sparkling watermelon dry orange_blossom yeast citrus_peel fresh strawberry tart raspberry yeast melon salt gripping',
#  'citrus elegant honey pear caramel lengthy complex mellow',
#  'tangy nervy refreshing fresh tangy fruit cranberry concentrated',
#  'restrained powerful modest fruit tart fruit lean elegant oak',
#  'vanilla coconut rich milk_chocolate strawberry jam sweet smooth',
#  'thick chocolate leather pepper concentrated smooth round robust blackberry vanilla',
#  'strawberry currant spice fresh grabby fruit baked spice cocoa dry cassis chocolate',
#  'pineapple fruit saline apple peach herb minerality firm',
#  'juicy ripe fruit succulent crisp apple pear nectarine minerality bright',
#  'light_bodied chalk slate minerality pear kiwi honeydew fruit pith grapefruit apple warm yellow pear saline warm',
#  'meaty smoke fruit robust dry firm tannin grilled_meat',
#  'crisp elegant lemon_peel apple pear light_bodied oak',
#  'dark pepper syrupy earth dry',
#  'dark olallieberry blackberry plum concentrated purple_flower licorice earth eucalyptus fresh pomegranate juicy',
#  'sour cherry cranberry sandalwood savory herb oregano dry herb juicy',
#  'heavy fruit concentrated thick velvety concentrated',
#  'cherry plum vanilla oak elegant plum cherry toast oak vanilla toast crisp hard',
#  'fruit currant raspberry strawberry flower lavender rosemary berry peach_pit soft spice closed',
#  'light_bodied ripe strawberry raspberry citrus',
#  'citrus light_bodied complex white refreshing bite oak steel oak shine tropical_fruit',
#  'zesty cherry cola cinnamon spice pepper light_bodied grippy vibrant iron',
#  'steel racy pungent rich juicy fruit apple tangerine oak powerful',
#  'clean sharp zesty fruit ripe green apple fresh tingly sour stone fruit grippy',
#  'strawberry rich fruit warm hard ripe soft',
#  'exuberant fruit spice robust dark berry dust brown_sugar pepper ripe concentrated smooth elegant powerful',
#  'white_flower stone fruit lees juicy elegant citrus pith',
#  'vibrant flower depth blackberry dry fresh baked berry pastry cooked blackberry vanilla juicy strawberry pepper rosemary spice',
#  'white sweet bone_dry sugar citrus orange_blossom peach syrupy brisk honeysuckle pine bitter',
#  'light_bodied tart cherry fruit chocolate bright light_bodied',
#  'orange lemon_peel vanilla white_flower citrus lush tropical_fruit fruit',
#  'dust lees apple vanilla sturdy fresh modest elegant lime apple tarragon dry apple citrus easy',
#  'bright citrus tropical_fruit fruit white fresh elegant',
#  'peach pear lemon white complex fruit soft',
#  'light_bodied herb horsey blueberry plum cardamom ripe hot flabby soft chunky plum blackberry licorice mint chewi syrupy',
#  'fruit dry wood berry fruit juicy fresh',
#  'shine bright spice tart strawberry raspberry cherry american_oak oak gripping',
#  'leather plum compost rubber juicy herb plum currant earth tomato light_bodied leafy',
#  'berry cassis spice jam hollow blackberry blueberry fleshy soft',
#  'dry oregano thyme cherry green pepper blackberry tomato',
#  'fruit dense chunky cherry coffee oak toast elegant',
#  'dense tar asphalt rubber boysenberry flat tannin blackberry prune raisin toast bitter chocolate weight oak ripe',
#  'smoke meaty ripe plum tart blackberry overripe restrained savory tarragon anise',
#  'peach lemon juicy honey minerality apple pear cider ripe light_bodied',
#  'tight spice berry fruit light_bodied oak milk_chocolate smooth',
#  'plum coffee tobacco cedar low_complexity blackberry currant clove licorice',
#  'wild_berry violet spice savory cherry clove pepper',
#  'firm dry fruit fresh currant berry perfumed',
#  'light_bodied yellow green crisp green apple rich pear butter fig rich ripe',
#  'rhubarb cola pencil_shaving earth sassafras dry berry soil minerality dark fruit',
#  'dark lemon graphite licorice blackberry horsey baked chunky heavy fruit resin oak spice salt wood tannin',
#  'leather cherry plum ripe cherry cedar cinnamon soft',
#  'light_bodied fresh fruit cranberry cherry tangy fruit cinnamon firm',
#  'oak meaty savory super_ripe cherry fruit',
#  'cherry raspberry fresh dense wild_berry plum brown_sugar warm heady fruit bright',
#  'sleek toast oak vanilla blue_flower plum round sweet cherry raspberry licorice mint assertive',
#  'robust baked plum coffee menthol spice hearty fruit chocolate licorice dry herb hot closed',
#  'juicy soft blackberry cherry oak weight strawberry dry herb closed',
#  'latex tire_rubber spice cured_meat berry fruit grabby herb muscular plum licorice pepper',
#  'lemon oak refreshing fennel brine powerful',
#  'oak cherry extracted rich depth fruit complex licorice tar',
#  'earth menthol eucalyptus tomato light_bodied powerful weight cherry plum dark savory',
#  'kumquat wet_rocks concentrated light_bodied shine',
#  'dark mint inky blackberry rubber grabby toast berry fruit chocolate oak hot mint coffee',
#  'raspberry cherry herb wood_spice fruit fresh elegant light_bodied chalk',
#  'lush powerful gingerbread cherry thick heavy coffee plum cherry earth complex pencil_lead',
#  'hearty earth nutmeg iron hot stone loamy cherry extracted lush ripe cassis cherry fruit elegant chalk round cocoa',
#  'apple nectarine lees brine round bitter melon peach lees pith grapefruit_peel',
#  'raisin baked overripe heavy berry prune fresh raisin',
#  'crisp minerality oak firm juicy modest blackberry cassis oak coffee closed',
#  'bright fruit minerality fresh fruit firm',
#  'rich weight wood smoke edgy',
#  'smoke toast wood fruit juicy fruit firm',
#  'tannin wood juicy fruit bright smoke fruit dark toast',
#  'smoke burnt toast currant fruit bright fruit',
#  'cream butter bright lemon apple sweet luxurious viscous',
#  'brick dry round cherry watermelon',
#  'zesty minerality unoaked citrus refreshing pear quince crisp',
#  'smoke violet perfumed elegant fresh green apple pear tart concentrated tight',
#  'rocks slate lemon tangerine zippy fresh brisk stone',
#  'fig spice perfumed rustic potpourri dust raisin fig elegant crisp spice',
#  'ripe soft fruit soft rich smooth round',
#  'leather firm fruit',
#  'pear white_flower sweet spice',
#  'plum herb dark blue fruit chalk dry',
#  'dry cherry vanilla dry tobacco blackberry dry cranberry cherry rich tart astringent',
#  'potpourri brisk concentrated light_bodied elegant perfumed',
#  'light_bodied wood herb fruit sweet rich fruit gripping',
#  'smoke toast fresh crisp citrus foamy grapefruit orange pepper caramel foamy pepper bitter',
#  'ripe spice wood powerful fruit dark bitter chocolate cherry rich concentrated',
#  'blue_flower ripe berry baked spice mint elegant juicy cherry raspberry cinnamon licorice minerality firm ripe finessed',
#  'earth dark complex ripe blackberry cherry compote',
#  'raspberry blue_flower graphite firm ripe cherry pepper licorice sage tight',
#  'chalk rich fruit steel minerality perfumed crisp fresh dense complex',
#  'rich fruit minerality tangy apple grapefruit steel tight',
#  'cherry toffee tobacco tar violet full_bodied powerful fruit spice bright',
#  'dry rose leather truffle berry ripe cherry raspberry cinnamon white pepper chewi',
#  'rich ripe elegant tropical_fruit fruit juicy warm round',
#  'ripe fruit tight',
#  'lush wild_berry wet_rocks sweet grain bright berry fruit',
#  'light_bodied heavy leather purple fruit blueberry tobacco licorice pepper game restrained juicy thick',
#  'round rich flower fruit steel',
#  'juicy oak dense cherry plum lavender sage thick rocky minerality',
#  'ripe fresh violet rose perfumed berry spice depth juicy cherry raspberry clove pepper chewi',
#  'ripe oil rich honey fruit dry edgy botrytis orange light_bodied ginger',
#  'white pepper exuberant buoyant fruit wild_berry bramble soft',
#  'high_alcohol oak herb berry grain bramble tart strawberry cherry fruit',
#  'hot blackberry pie cinnamon allspice cola nut cherry dark plum fruit plum candy blackberry syrupy fresh watery',
#  'herb dark berry fruit spice leather powerful complex concentrated',
#  'light_bodied complex coffee vanilla pencil_lead cherry blueberry herb polished plush elegant',
#  'saddle_leather cedar spice cardamom soft juicy tingly weight',
#  'depth tannin ripe fig plum fruit saline iron',
#  'fruit mass cherry cassis smoke oak length dry',
#  'balsamic menthol mint fennel ripe berry leather violet cherry raspberry baked spice licorice fresh',
#  'ripe minerality rich white fruit fresh fruit citrus complex',
#  'flower rich dry ripe perfumed round opulent steel minerality',
#  'chalk minerality ripe tropical_fruit fruit rich dry ripe sweet',
#  'rich dense dark opulent fruit firm silky',
#  'violet spice perfumed berry juicy ripe cherry raspberry fresh pepper coffee anise fresh firm polished',
#  'smoke toast currant fruit fresh firm juicy fruit',
#  'rich crisp fruit tight chalk steel ripe apple grapefruit bright fruit',
#  'tight herbacious crisp minerality fresh fruit juicy bright',
#  'round velvety smooth blackberry fruit fresh rich soft',
#  'crisp fruit bright lime grapefruit fresh juicy',
#  'ripe apple brioche smooth',
#  'toast oak tart raspberry fruit clean oak light_bodied fruit',
#  'pink cinnamon berry bubble_gum sour cherry plum fruit',
#  'bright orange juicy dill herb vanilla apple fresh lime juicy',
#  'white cream tropical_fruit ripe melon pear fruit spice',
#  'plum bright cherry fruit savory tobacco spice sweet pepper caramel',
#  'bright berry fruit light_bodied sage baked spice',
#  'dust oak burnt toast cherry fruit chalk',
#  'brown lean light_bodied strawberry flower oak cardamom spice fig',
#  'spice concentrated sweet tea',
#  'plum oak coffee pepper balsamic barnyard dark cherry oak coffee toast vanilla aggressive wood astringent',
#  'white heady flower jasmine vibrant sweet fresh fruit grapefruit peach nectarine',
#  'iron pepper light_bodied racy boysenberry sanguine',
#  'plum cherry coffee ripe',
#  'brilliant purple tannin syrupy blackberry baked spice clove oak',
#  'dust cherry dark plum ripe plump clean weight berry fruit spice oak smooth fresh',
#  'fresh fruit sparkling crisp apple apricot ripe light_bodied cream mousse fruit tight',
#  'chalk earth pepper clove spice complex cedar tea green pepper',
#  'blackberry pepper meaty boysenberry iron licorice',
#  'low_complexity closed cherry coffee prune oak tire_rubber aggressive dry',
#  'crisp ripe yellow fruit warm rich fruit almond refreshing',
#  'honeydew ripe nectarine lemongrass peach bubblegum flint',
#  'bright rustic fresh raspberry stone tart cherry berry ripe raspberry tart',
#  'light_bodied butterscotch baked pear fresh jasmine apple pear round',
#  'raisin cinnamon spice soft extracted modest baked fruit fig chocolate herb chocolate rich',
#  'fruit dark firm juicy cherry',
#  'fruit rich wood rich fruit complex minerality tight nervy citrus fruit apricot',
#  'ripe orange apricot oak',
#  'rosemary leather rich savory juicy dark plum tobacco coffee',
#  'dry sparkling dry complex lemon orange yeast vanilla cream toast sparkling',
#  'low_alcohol brisk silky raspberry cola butter cinnamon toast',
#  'depth apple fruit flint cream',
#  'rich cream apple bitter orange herb complex',
#  'ripe smooth cream ripe peach vanilla concentrated rich',
#  'rich raspberry cranberry persimmon crisp dry',
#  'depth flower chamomile fruit graphite juicy honeydew white peach ripe pear citrus minerality fresh',
#  'stone fruit tomato fresh cut_grass green melon depth cream white peach ripe cataloupe firm closed flint minerality',
#  'powerful dense fruit dark fruit',
#  'mint wood ripe polished rich fruit blackberry dry',
#  'fruit astringent',
#  'depth rich cherry blueberry complex mushroom toast dry tannin',
#  'cream fruit wood apricot ripe apple melon spice toast rich warm',
#  'tannin dense complex dark fruit licorice bitter',
#  'ripe smooth rich toast apricot fruit tight minerality',
#  'soft clean blueberry fruit',
#  'firm closed tannin fruit dry firm fruit leather dark',
#  'violet truffle ripe fruit rich dark heavy complex',
#  'fruit racy rich pear orange_peel snappy spice',
#  'blackberry jam milk_chocolate cassis toast butter oak sweet dry thick',
#  'ripe rich smoke fruit honey ripe apricot peach',
#  'elegant peach pink dry low_alcohol peach lime vanilla crisp',
#  'savory cataloupe tomato vibrant juicy green melon pineapple citrus minerality fresh clean crisp',
#  'savory weight oak apple pear nutmeg flint cream fresh',
#  'light_bodied silky rich raspberry cherry spice cola smoke oak tart earth',
#  'dense brick tar bramble blackberry fruit powerful smoke meat',
#  'stone earth brine olive green olive orange_peel gravel smoked_meat cured_meat',
#  'white sparkling wax apricot pear crisp minerality stone dry refreshing viscous complex',
#  'complex dry violet plum cooked spice smooth blackberry jam tobacco ripe cherry nutmeg licorice velvety elegant',
#  'fruit white steel crisp white peach brine stone heady honeysuckle ginger vanilla',
#  'plum tangy cranberry pine juniper pencil_shaving mulberry marjoram indian_spice',
#  'silky hickory_smoke white peach lime_peel',
#  'fruit cola clean earth minerality',
#  'ripe fruit spice oak forest_floor opulent baked spice earth cherry fruit complex',
#  'powerful fruit concentrated rose sage strawberry velvety weight',
#  'fruit coffee smoke fruit wood fruit bright raspberry plum cherry light_bodied cola ripe apple sweet spice',
#  'full_bodied orange dark cherry pungent earth savory meaty pepper clove tea',
#  'elegant savory vibrant white yellow stone fruit wet_rocks thyme vibrant yellow peach tangy tangerine lemon_drop pineapple graphite closed elegant depth',
#  'white white_flower yellow stone fruit white peach pear ginger lemon_drop fresh cream minerality',
#  'fruit tropical_fruit edgy coconut firm sage cedar tobacco pepper savory fruit',
#  'currant cherry dry milk_chocolate',
#  'crisp robust raspberry blackberry coffee full_bodied dense licorice clove lengthy',
#  'flower cream crisp length stone green apple rich complex',
#  'chunky cranberry blackberry cherry fruit dense fruit wet_rocks minerality',
#  'full_bodied fruit firm minerality powerful elegant',
#  'pop orange_peel cured_meat olive wet_rocks purple fruit fruit plum savory',
#  'ripe fruit spice warm herb',
#  'spice sweet root saddle_leather earth berry fruit rich dense dark cherry berry fruit herb complex chocolate oak',
#  'rich fruit',
#  'ripe chocolate coffee hard coffee coffee hazelnut ripe berry fruit dense firm toast powerful',
#  'elegant powerful fruit round rich cassis clove pepper',
#  'rich dense concentrated spice dark fruit herb warm',
#  'oak sweet almond prune chocolate tannin depth dense toast cassis blackberry coffee chocolate pepper rough tannin',
#  'light_bodied bright wood spice ripe fruit concentrated rich complex',
#  'soil wood mint rich truffle',
#  'polished potpourri almond apple white pepper yeast oak complex bright bite',
#  'woody_berry rose herb anise balsamic firm robust white pepper licorice sage toast cherry warm closed',
#  'juicy grapefruit apple buoyant fresh steel',
#  'dense rich fruit elegant concentrated vanilla berry soft oak fruit rocky minerality',
#  'light_bodied lees vanilla cookie crisp minerality apple apple pineapple fresh citrus_pith',
#  'tropical_fruit mango pear vanilla cream elegant grapefruit',
#  'powerful concentrated rich dense dark',
#  'ripe white peach caramel pear apple almond restrained grippy pear honey',
#  'lush rose fresh strawberry fruit toast oak satiny hard',
#  'quaffer dry crisp bright refreshing succulent grapefruit tangerine light_bodied light_bodied',
#  'fruit berry spice menthol firm juicy cherry raspberry licorice pepper mint racy',
#  'blue_flower rose wild_berry graphite firm cherry raspberry star_anise pepper bright tight',
#  'bittersweet berry juicy dust chalk rich leather clove',
#  'perfumed berry mint baked spice oak firm cherry raspberry mint sage spice',
#  'sandalwood velvety tea truffle forest_floor sinewy complex savory cinnamon clove',
#  'dense minerality powerful concentrated',
#  'rich dry rich juicy fruit concentrated fresh',
#  'warm vanilla ripe nectarine apple lemon_peel pencil_lead apple lemon sizzling',
#  'lemon light_bodied tropical_fruit white weight elegant hard white peach',
#  'herb green perfumed fruit peach fresh pear herb fresh brisk citrus apple silky supple',
#  'rose wild_berry cinnamon balsamic juicy cherry white pepper anise mint spice polished firm refined',
#  'caramel white peach salt lemon pear apple white_flower orange grapefruit_pith buttery_toast saline herb',
#  'cherry kirsch coffee tobacco fruit tar coffee',
#  'cream mousse dry white citrus fruit tangy tight minerality',
#  'rich currant fresh leather',
#  'light_bodied honeysuckle moist_earth tart raspberry cherry minerality crisp',
#  'restrained plum dark plum mint eucalyptus pepper fruit soft mint bright opulent tart apple crisp',
#  'cream pineapple apple custard lemon iodine lemon salt apple tangy ripe fruit savory saline',
#  'lush strawberry cream fruit closed',
#  'rose berry mint menthol oak linear cherry strawberry white pepper licorice tight bright',
#  'ripe berry earth leather blackberry chocolate raisin prune light_bodied toast dense',
#  'cedar cherry olive wet_earth green olive fresh plum pop ripe cherry tangy green olive tart',
#  'lemon_curd soft apple pear ripe stone fruit tangy bone_dry grippy chalk',
#  'melon white peach citrus',
#  'velvety fresh earth oak leafy fruit depth depth game',
#  'fruit firm raspberry plum perfumed fresh',
#  'fresh cranberry raspberry fruit clean light_bodied',
#  'berry rose clove bright supple smooth juicy cherry strawberry white pepper fresh minerality savory',
#  'plum blackberry ripe rich fruit savory edgy bramble dry herb crisp cranberry fresh',
#  'fresh green pear watery herb edgy fresh green refreshing',
#  'pepper spice lees fresh white asparagus luminous fresh',
#  'pear juicy warm earth tropical_fruit lemon pineapple fresh',
#  'fresh pear fruit crisp clean fresh fruit fresh',
#  'pale elegant restrained velvety finessed rhubarb cinnamon cardamom cocoa',
#  'firm fruit raspberry fruit perfumed fresh',
#  'spring_flower beeswax fruit elegant linear juicy lemon nectarine hazelnut saline firm closed crisp clean',
#  'earth white flower dust fruit dry herb flower dry peach candy nectarine zest',
#  'tart juicy fresh tangy citrus green apple fruit lees wet_rocks refreshing white',
#  'light_bodied yellow stone fruit citrus herb bright cream peach green apple nectarine minerality juicy',
#  'apple pear vibrant fresh sweet simple refreshing steel minerality',
#  'herb mint rich dry tannin cherry wild_berry rosemary rich meat mushroom',
#  'concentrated oak dark cherry ripe dry blackberry dark chocolate full_bodied dark fruit',
#  'blackberry jam oak pepper sturdy',
#  'depth blackberry cedar firm restrained oak smoke pencil_lead lengthy',
#  'plum herb tobacco fresh plum berry cherry',
#  'ripe rich berry ripe blackberry plum fleshy rich soft supple silky tannin',
#  'fruit vanilla tobacco orange_peel earth fresh hollow pepper oak cherry plum toast snappy',
#  'steel american_oak powerful elegant tannin grippy toast oak cherry rich cinnamon chocolate',
#  'grippy leather tobacco gravel concentrated dense currant cassis leather',
#  'depth blackberry boysenberry ripe concentrated',
#  'spice oak velvety smooth ripe cranberry cedar nutmeg',
#  'cream honeysuckle light_bodied butter citrus_peel vanilla apple cinnamon firm clean light_bodied',
#  'juicy blackberry blackcurrant cocoa cola pepper dense depth dark tar pencil_shaving dry blueberry asphalt umami tight',
#  'ripe leather menthol robust concentrated cherry raspberry jam cinnamon licorice warm hot firm ripe',
#  'fresh dill green herb plum',
#  'fruit raspberry blackberry light_bodied tangy mellow dark chocolate',
#  'apple lime minerality fresh round plump peach citrus stone tropical_fruit lychee mango',
#  'perfumed rich ripe fruit smooth dark cherry juicy',
#  'undergrowth earth truffle star_anise menthol ripe dry cherry blackberry jam licorice coffee assertive',
#  'coffee undergrowth leather dark spice fruit oak firm dry cherry coffee vanilla star_anise dust',
#  'lemon_custard pineapple white vanilla lemon_meringue pie',
#  'scorched_earth coffee dry cherry blackberry coffee vanilla game',
#  'herb forest_floor scorched_earth cured_meat menthol ripe juicy cherry fleshy raspberry cinnamon tobacco candy firm',
#  'rose perfumed berry meditteranean_herbs soft bright cherry raspberry tobacco coffee supple',
#  'peach baked orange apple honeysuckle racy sizzling cut_grass lemongrass',
#  'rosemary bay_leaf clove full_bodied dry',
#  'tannin cherry leather',
#  'thick dense dust fruit cedar tar tobacco blackberry currant powerful gripping',
#  'steel refreshing orange lime',
#  'funky brine tropical_fruit oak mellow opulent butter',
#  'tropical_fruit guava mango restrained french_oak vanilla honeysuckle low_complexity lengthy',
#  'pepper dry cherry plum violet plum blackberry tart cherry smooth',
#  'wild_berry thyme dry cherry white pepper sage anise tight',
#  'caramel oak rich round medium_bodied lemon apple',
#  'low_complexity exuberant toast oak gripping cedar sage cassis cherry powerful soft',
#  'french_oak brawny meat leather blackberry tar velvety oak',
#  'light_bodied spice fresh plum medium_bodied',
#  'round ripe baked plum vanilla anise leather juicy cherry blackberry coffee dry sage baked spice licorice polished',
#  'forest_floor plum menthol spice elegant cherry pepper licorice firm',
#  'scorched_earth undergrowth blue_flower woody_berry elegant raspberry cherry brown spice leather tight refined',
#  'dry cherry vanilla dry tobacco blackberry dry cranberry cherry rich tart astringent',
#  'light_bodied cherry pepper spice light_bodied lush ripe berry nutmeg game',
#  'potpourri brisk concentrated light_bodied elegant perfumed',
#  'light_bodied wood herb fruit sweet rich fruit gripping',
#  'smoke toast fresh crisp citrus foamy grapefruit orange pepper caramel foamy pepper bitter',
#  'raspberry currant oak maple crisp plum raspberry',
#  'light_bodied apple herb tropical_fruit fruit medium_bodied lean tart concentrated',
#  'mint rich currant fruit fresh juicy',
#  'butter full_bodied full_bodied ripe fruit toast oak dry rich savory smoke fruit',
#  'heavy oak smoke ripe cherry boysenberry rich full_bodied toast oak firm sweet oak',
#  'hot coffee vanilla herb cherry blackberry sweet viscous dry',
#  'pear peach minerality almond medium_bodied',
#  'earth leather wild_berry funky game robust sage tobacco licorice depth fleshy cherry raspy',
#  'oak vanilla toast dense dark prune coffee anise oak astringent dry',
#  'perfumed toast smoke fruit fruit wood',
#  'round purple fruit fresh soil dust ripe cherry tart plum earth',
#  'apple spice low_complexity',
#  'apricot white_flower orange_peel fresh baked full_bodied dry sweet fruit',
#  'bright crisp white apricot nectarine white peach minerality juicy fruit zesty clean refreshing',
#  'cheese funky complicated brine stone fruit butter oxidized brine apricot',
#  'earth leafy forest_floor dry currant low_complexity juicy blackberry raspberry clove smooth',
#  'lime minerality stone fruit dry residual_sugar phenolic cream',
#  'berry spice oak vanilla cream oak sharp plum boysenberry tart vanilla snappy sharp',
#  'smooth nut vanilla dry orange lemon salt peanut crisp metal angular salt oily',
#  'crisp mint herb berry plum bright tannin blackberry chocolate earth plump',
#  'oak dry coconut coffee vanilla hard',
#  'berry cherry fruit clean tannin plum blackberry crisp firm',
#  'concentrated plum scorched_earth dense prune baked cherry nutmeg clove velvety fruit',
#  'cured_meat fruit toast oak ripe sage vanilla oak spice fleshy plum fruit rich',
#  'oak vanilla plum coffee coconut tight dry fruit coffee clove hot closed',
#  'crisp refreshing currant light_bodied caramel fruit',
#  'resin balsamic overripe dry apricot candy nectarine zest closed',
#  'robust viscous petrol oak tart',
#  'barnyard soy sweet cherry cooked fruit funky',
#  'berry soft fruit smooth',
#  'rose lychee powerful flower fruit soft sweet',
#  'fruit crisp bright fruit tangy citrus ripe cream',
#  'pale brick elegant cherry',
#  'dry cranberry currant cake tannin tart',
#  'spice reedy dry herb fruit tight baked plum berry fruit cocoa',
#  'soft green apple orange_peel underripe banana zippy prickly pith citrus zest bitter',
#  'american_oak round pencil_shaving cherry leather tobacco firm',
#  'concentrated orange_blossom bubblegum minerality sweet dry syrupy apple pear lemon_curd',
#  'green wood herb cherry ripe chalk fruit astringent bitter',
#  'fruit grippy hearty full_bodied cherry plum',
#  'crisp fruit bright lemon fruit minerality',
#  'jam blueberry oak dense flat baked berry herb plum sweet green syrupy',
#  'ripe tropical_fruit honeydew banana nectarine sweet apple bubblegum',
#  'modest lemon white lemon pith yeast citrus tangy',
#  'lime concrete green apple rind lime tangy ripe apple pear stone',
#  'fruit bright soft fruit',
#  'smoke brawny pepper cherry ripe grippy powerful coffee dust',
#  'spice wood firm tight granite blackberry fruit',
#  'low_complexity dry fruit medium_bodied cherry blackberry',
#  'funky sour blackberry charcoal dry meat blueberry sour plum savory meat',
#  'grass herb apricot spice fruit',
#  'dull rustic earth anise soft cherry fruit light_bodied',
#  'bright fruit juicy plum',
#  'pale light_bodied bright fruit zesty orange_peel crisp strawberry',
#  'light_bodied fresh fruit cranberry cherry tangy fruit cinnamon firm',
#  'leather cherry plum ripe cherry cedar cinnamon soft',
#  'cherry raspberry full_bodied tannin',
#  'blue_flower undergrowth coffee concentrated pepper clove tight fruit rich',
#  'spice juicy fruit sweet berry ripe',
#  'sweet honey rich apricot fruit fresh fruit minerality fruit',
#  'apple pear dust pollen saffron savory spice dry concentrated tangerine lime dust earth',
#  'sparkling honeysuckle candy citrus firm ripe yellow apple nectarine zest candy ginger toast walnut crisp',
#  'full_bodied apple pear pineapple fruit',
#  'dry cherry purple_flower vanilla blackberry jam purple_flower sour cherry coffee sanguine grippy',
#  'toast coffee currant cedar dry cherry coffee sage leather astringent',
#  'firm plum fruit cherry',
#  'oak cherry coffee anise smooth sandalwood butterscotch',
#  'firm light_bodied raspberry citrus stone',
#  'warm pie pepper green bell_pepper plum cherry strawberry wood bitter',
#  'perfumed dark chocolate dense powerful dark',
#  'boysenberry dry violet pepper fresh rich purple fruit licorice tobacco',
#  'blackberry ripe plum blue_flower anise pepper fleshy cherry assertive polished',
#  'blue fruit allspice earth game spice blueberry blackberry pepper licorice tobacco',
#  'earth berry licorice light_bodied oak fresh juicy plum raspberry loamy earth heavy',
#  'cherry leather silky cocoa',
#  'dry strawberry wild_berry clove cinnamon cocoa powerful fruit dry cherry dry herb dark chocolate hot',
#  'blackberry cassis herb spice ripe berry cassis chocolate oak chocolate cream oak full_bodied',
#  'spice crisp blue plum licorice dark chocolate light_bodied game cured_meat leafy',
#  'cinnamon cherry potpourri gingerbread raspberry juicy dark chocolate purple_flower pepper cardamom gripping',
#  'fruit herb tart cranberry tight bitter pineapple elegant aggressive herbacious fruit',
#  'blue light_bodied fresh watery flower fresh herb lees stone fruit crisp citrus orange peach nectarine lemon minerality',
#  'fruit toast oak coffee licorice blackberry extracted anise clove tobacco dust',
#  'dry light_bodied oak plum berry bright juicy fresh racy cherry plum clean',
#  'minerality citrus dust round gripping nectarine lime green banana',
#  'bite apple anise powerful finessed depth complex',
#  'concentrated minerality perfumed melon orange fruit',
#  'powerful dark fruit rich juicy dry concentrated dense wood ripe fruit',
#  'spice plum berry fruit fresh cinnamon clove complex tea savory toast oak',
#  'plum dust clove blackberry chocolate vanilla',
#  'plum cedar coffee supple concentrated dark roasted_meat savory pie',
#  'pea wood cigar_box camphor fruit cedar blueberry cherry milk_chocolate',
#  'complex wet_rocks orange_peel herb dry tart stone fruit',
#  'cider nectarine yellow fruit flower yeast grapefruit',
#  'firm berry fruit juicy dark fresh powerful dense minerality',
#  'voluptuous rich toast lemon crisp yellow apple brilliant minerality vanilla firm round',
#  'rich herb mint fruit powerful ripe',
#  'length elegant pungent grass tight lime apple fruit mustard green white pepper',
#  'effervescent cherry mint licorice slate blackberry pepper powerful',
#  'warm depth rich fruit apple peach lees light_bodied oak cream',
#  'rich ripe yellow fruit pepper concentrated light_bodied toast',
#  'soft toast refreshing herb',
#  'dry orange_peel mango honey stone savory herb tight lemon yellow_flower yeast toast racy round',
#  'honeysuckle jasmine linear vanilla caramel lemon_custard lush rich minerality butter',
#  'straw lemon_curd apricot fresh apricot pear spice crisp clean spice',
#  'rose violet baked spice juicy cherry vanilla licorice cinnamon firm',
#  'plush vanilla honeysuckle apricot viscous',
#  'berry blue lilac baked spice meditteranean_herbs white pepper sage tobacco bright cherry aggressive bright',
#  'ripe rich smoke fruit oak ripe fruit rich dense spice toast fruit',
#  'firm depth fruit weight concentrated plum juicy currant dry complex',
#  'minerality fruit complex fruit steel',
#  'zesty fresh rich oak smoke caramel pear vanilla oak apple white peach nectarine lime_peel',
#  'depth cassis berry racy tight full_bodied berry pepper baked spice chocolate toast pepper juicy',
#  'concentrated concrete oak flower light_bodied toast length',
#  'oil ripe caramel toast depth gold crisp green apple melon complex minerality supple',
#  'complex herb cherry fresh fruit mint clove anise vibrant full_bodied',
#  'herb plump fruit dill sage cherry blueberry sleek',
#  'sweet firm stone soft angular peach',
#  'closed edgy soft ripe ripe fruit',
#  'wood rich dark fruit wood fruit firm complex',
#  'cinnamon cherry ripe cranberry light_bodied tobacco leather rustic soft cranberry cherry spice thyme bay_leaf cinnamon',
#  'hazelnut truffle juicy round concentrated',
#  'white peach apricot steel minerality elegant light_bodied sweet bramble herbacious',
#  'wild_berry sage cherry raspberry fruit concentrated',
#  'heady honeysuckle white stone fruit dill hay vegetal tomato tangy juicy grapefruit white peach honeydew saline depth',
#  'wood wood toast spice yellow fruit ripe rich',
#  'soft stone melon fresh clean soft stone dry fresh apple',
#  'rich smoke wood perfumed fruit wood',
#  'ripe apple soft pepper spice rich lemon fresh soft cheese',
#  'white ripe green pear fresh bright lemon',
#  'tart yellow fruit cucumber green lemon steel oak minerality rich gripping',
#  'fruit cake spice concentrated ripe cherry raspberry nutmeg carob depth',
#  'complex rich cherry berry dry herb lavender',
#  'dry heady jasmine citrus yellow stone fruit vibrant apricot tangerine_peel herb fresh',
#  'crisp elegant white white peach grapefruit',
#  'cherry light_bodied coffee tobacco',
#  'oak restrained steel oak rich apple pear compote rich lemon fresh',
#  'rose baked spice juicy fleshy cherry raspberry pepper bright supple',
#  'spice oak velvety smooth ripe cranberry cedar nutmeg',
#  'baked root sandalwood spice berry fruit grabby oak herb plum raspberry dry firm',
#  'berry cinnamon light_bodied wood spice tannin oak plum berry fruit savory dry snappy',
#  'depth ripe fruit light_bodied spice firm bite rosemary fruit concentrated oak',
#  'apple pear vibrant fresh sweet simple refreshing steel minerality',
#  'herb mint rich dry tannin cherry wild_berry rosemary rich meat mushroom',
#  'concentrated oak dark cherry ripe dry blackberry dark chocolate full_bodied dark fruit',
#  'cherry pie spice buoyant robust fruit oak white pepper',
#  'fruit strawberry cherry citrus tea elegant feminine sturdy',
#  'full_bodied rich fruit dense dust tannin',
#  'robust currant dark cherry chocolate dust sage cedar luxurious smooth complex',
#  'bright oak lemon_custard flower citrus green apple lemongrass ginger rich',
#  'nervy light_bodied clean crisp pear nectarine mandarin pith tight sharp citrus round',
#  'white flower almond fruit almond herbs elegant peach apricot almond tangerine',
#  'ripe fruit rich dry fruit',
#  'iron cranberry cola cherry pepper vibrant',
#  'complex chocolate cherry cherry plum fruit oak spice lemon',
#  'dark concentrated fruit smooth rich round opulent',
#  'pungent earth fruit strawberry orange_peel tea savory rich smoke vanilla',
#  'pepper cinnamon blueberry plum tart cherry fruit spice fresh restrained fresh rich',
#  'cranberry herb licorice dry cherry tight firm',
#  'shine plum raspberry blackberry soft dark chocolate clove',
#  'baked cherry vanilla pastry loamy dry mint forest_floor tannin raspberry fruit round thyme oregano pepper saline',
#  'depth dark berry vanilla gritty spice tobacco hard blackberry cassis oak spice molasses savory oak chocolate blackberry fruit',
#  'juicy cherry fruit tar elderberry edgy licorice fruit fresh vibrant elegant refreshing',
#  'earth elderberry dry oak leafy smooth elegant powerful shine depth',
#  'rich cherry candy strawberry spice lavish purple fruit flower pepper spice vanilla warm tar',
#  'crisp peach apricot white gravel steel gripping gritty velvety smooth',
#  'fruit bright spice cherry concentrated length light green herb round',
#  'bright firm berry savory rich steak ripe fruit firm grippy',
#  'nut cashew honey walnut vanilla oak smoke',
#  'minerality rocky powerful spice plum cola clove pepper',
#  'oak leafy tart strawberry supple vanilla smooth mellow depth fresh',
#  'robust rich dark cherry currant oak full_bodied',
#  'complex raspberry sage spice raspberry syrupy dark chocolate blackberry light_bodied grippy plush fruit',
#  'high_alcohol warm burnt earth cherry rubber herb chewi boysenberry cassis herb spice smooth',
#  'fruit spice dense licorice wood complex',
#  'high_alcohol dry tannin ripe blackberry dark chocolate pepper',
#  'bright fruit spice fruit crisp ripe',
#  'rich brisk currant cassis minerality oak elegant',
#  'ripe concentrated depth fruit rich peach pear spice wood',
#  'jasmine honeysuckle fruit round juicy green apple citrus yellow peach minerality',
#  'fresh raspberry cherry jam fruit complex mushroom',
#  'spice honeycomb lanolin minerality dry concentrated complex spice stone fruit tangerine',
#  'dainty stone fruit flower tea minerality juicy orange mango peach',
#  'lavish ripe peach honeysuckle juicy nectar lime',
#  'zesty lime peach plum cherry medium_sweet juicy stone fruit refreshing',
#  'smoke brisk flower lush ripe peach nectarine',
#  'smooth rich concentrated fruit apricot smoke minerality gold apple hazelnut honey crisp crisp complex',
#  'thick spice pear butter mint complex rich',
#  'fruit dust smooth complex juicy fruit dense minerality',
#  'rich lees french_oak oak fruit ripe racy tropical_fruit peach pear depth',
#  'dense spice wood smoke bacon weight berry fruit',
#  'dry lean angular lemon lime wet_rocks tropical_fruit fruit',
#  'rich currant thick soft cherry violet grilled_meat pepper meaty dry',
#  'dark dense tannin earth spice dry cherry rhubarb pomegranate fruit',
#  'ripe juicy peach nectarine semisweet soft sweet minerality',
#  'fresh herbacious elegant rich round sweet peach zingy citrus spice',
#  'semisweet ripe yellow cherry quince crisp tart tangerine bright elegant fresh herb',
#  'smoke stone fruit apple racy powerful sweet yellow cherry quince minerality brisk citrus',
#  'smoke candle_wax savory ripe stone fruit lemon concentrated ripe juicy tangerine sweet lime zest',
#  'complex concentrated ripe peach nectarine smoke spice zippy bright tart tangerine minerality',
#  'sweet honey apricot pear lemon vanilla rich crisp',
#  'concentrated cataloupe yellow peach elderberry tomato fruit juicy fresh minerality crisp depth',
#  'ripe fruit fruit dark fruit',
#  'complex fruit concentrated spice leather rich dense dust',
#  'white toast juicy citrus pear apple spice',
#  'rich blackberry chocolate chalk juicy cigar medium_bodied round soft cherry pomegranate',
#  'fruit beet cherry purple rich velvety',
#  'stewed_prune coconut coffee herb firm dark cherry coffee anise tobacco bright',
#  'wood powerful dense fruit concentrated wood fruit',
#  'closed firm ripe sour cherry dark cooked spice tobacco herbs fresh austere refined',
#  'vanilla berry dark chocolate jam mint',
#  'pungent wood earth orange_blossom pear crisp light_bodied honey lemon complex',
#  'berry undergrowth herb spice dry cherry anise coffee toast herb assertive brisk',
#  'berry sage cinnamon menthol juicy sour cherry raspberry licorice tobacco low_complexity ripe fresh',
#  'woody_berry herb oak firm dry cherry baked spice coffee firm closed star_anise fruit rich',
#  'firm plum undergrowth baked earth vanilla spice chewi ripe cherry raspberry jam vanilla coffee white pepper mint polished',
#  'tropical_fruit fruit lees dust minerality lemon tangy lemon lime gooseberry fresh clean stone citrus',
#  'clove graphite iron cherry complex iron raspberry minerality',
#  'juicy blackberry ripe plum dry fruit full_bodied light_bodied smoke perfumed',
#  'fresh fruit white hot dry yellow green fruit refreshing',
#  'residual_sugar lush fruit sweet dry peach pear light_bodied spice fruit',
#  'flower dry fresh apricot cream light_bodied fresh',
#  'rich spice toast dense perfumed',
#  'toast spice ripe yellow fruit zingy lemon_peel minerality',
#  'tangerine lime green herb grapefruit lemon crisp clean',
#  'soft dense currant cherry powerful juicy exuberant fruit oak smoke',
#  'fruit scorched_earth spice blue_flower vibrant savory juicy cherry plum pepper anise racy soft polished',
#  'ripe tannin chewi firm blue plum cherry tobacco toast compost earth',
#  'dark french_oak coffee clove blackberry extracted licorice vanilla sweet baked spice baked plum',
#  'bright raspberry fruit toast oak fresh',
#  'fruit chewi ripe full_bodied powerful citrus',
#  'full_bodied peach banana pineapple fresh',
#  'baked plum earth truffle leather game cured_meat ripe dense fleshy cherry anise coffee mint velvety candy',
#  'violet rose dark berry cured_meat firm extracted rich cherry chocolate tobacco sweet spice grippy',
#  'french_oak coconut coffee menthol dense extracted raspberry jam vanilla toast oak kirsch warm leather wood concentrated',
#  'crisp elegant cherry rose silky scorched_earth dry complex flower',
#  'light_bodied fruit citrus rich chalk soil fresh crisp fruit',
#  'cherry plum earth gritty weight berry cherry bitter chocolate coffee',
#  'herbacious green herb tight citrus gooseberry light_bodied fresh',
#  'lean savory tea herb juicy bramble berry grippy',
#  'complex fruit spice savory plum fresh plum fruit tart bacon',
#  'fruit bright wood firm currant fruit',
#  'coconut cream pie fig honey vanilla cream baked fruit lush',
#  'crisp apple citrus minerality bright grapefruit',
#  'plum spice incense cherry white pepper leather licorice coffee balsamic astringent',
#  'flashy sweet oak ripe fruit rich ripe raspberry cherry firm vanilla',
#  'pungent lychee grapefruit pepper ginger clove dry rich herb spice fresh',
#  'fresh citrus green apple crisp steel',
#  'sparkling sandalwood licorice currant tart cranberry bitter herb',
#  'pungent juicy grapefruit chocolate strawberry fruit light_bodied light_bodied',
#  'light_bodied orange juicy passion_fruit sugar grapefruit_peel pear cider complex',
#  'white heady dry fruit fresh peach buttery_toast fresh stone fruit fig astringent',
#  'coconut oak extracted coffee coffee mint spice fruit rich oak dry wood',
#  'light_bodied bright refreshing pear lime_peel guava citrus_peel light_bodied papaya apple juicy rich crisp',
#  'round spice light_bodied fruit',
#  'rich toast apricot peach fruit round',
#  'crisp ripe fruit fresh herbacious fruit',
#  'closed rich fruit bitter_almond fruit',
#  'oak plum fruit tobacco cedar clove pepper steak',
#  'white currant fresh apricot fruit bright toast rich',
#  'cherry fruit steel stone firm tannin tart crisp fruit',
#  'flower peach lemon dust clove light_bodied oak bright',
#  'silky cherry strawberry dense refined oak violet rose rich powerful finessed',
#  'fruit dry edgy fruit',
# ...
#  'weight fruit ripe berry fruit fresh powerful dry dense',
#  'brine bell_pepper vegetal round celery bell_pepper lime tangerine grass brine',
#  'rich pineapple apple',
#  'toast weed undergrowth tobacco plum anise coffee fruit rich astringent',
#  'violet rose wild_berry bright lean berry pepper saline dry sage astringent',
#  'oak vanilla cocoa wood_spice cranberry herb raspberry elegant herb cherry tart',
#  'warm robust undergrowth spice plum sage leather balsamic tight dry berry fig menthol licorice hot coffee closed',
#  'tire_rubber leather dry fruit mushroom silky tart fruit',
#  'fresh juicy bright smoke fresh currant',
#  'fruit crisp herbacious rich wood light_bodied fruit',
#  'ripe exuberant fruit',
#  'dry juicy fruit sweet plum ripe',
#  'ripe rich opulent round dark rich dry',
#  'perfumed lavender juicy cassis rough chewi',
#  'blackberry dry cherry pepper coffee anise assertive astringent dry fruit hot',
#  'cherry boysenberry full_bodied rich ripe fruit firm',
#  'fruit rich sweet cherry berry plum fresh full_bodied',
#  'coffee chocolate herb plum oak soft elegant',
#  'dark fruit wood burnt toast chocolate dry fresh fruit',
#  'blueberry vanilla herb full_bodied',
#  'grass gooseberry crisp bright vibrant fresh mellow lush',
#  'oak fresh plum cherry velvety ripe firm soft',
#  'oak steel peach pear minerality round light_bodied oily',
#  'chewi coconut smoke game dense concentrated coffee',
#  'raspberry cherry flower pepper dark coffee light_bodied fruit oak',
#  'oak dill vanilla plum green herb fruit plump vibrant oak',
#  'bright fresh green apple lime lemon melon tangy refreshing medium_bodied crisp refreshing',
#  'low_complexity cherry dry rose anise complex dark fruit pepper spice',
#  'tobacco juicy plum oak vanilla dry ripe',
#  'yellow plum pear brawny full_bodied rich butter ripe citrus apple',
#  'concentrated tangerine peach smoke spice',
#  'chewi robust tar leather cranberry herb oak restrained',
#  'light_bodied depth dry bright berry currant fruit',
#  'dry heady jasmine citrus yellow stone fruit vibrant apricot tangerine_peel herb fresh',
#  'crisp elegant white white peach grapefruit',
#  'cherry light_bodied coffee tobacco',
#  'oak restrained steel oak rich apple pear compote rich lemon fresh',
#  'rose baked spice juicy fleshy cherry raspberry pepper bright supple',
#  'wood wood toast spice yellow fruit ripe rich',
#  'soft stone melon fresh clean soft stone dry fresh apple',
#  'rich smoke wood perfumed fruit wood',
#  'ripe apple soft pepper spice rich lemon fresh soft cheese',
#  'white ripe green pear fresh bright lemon',
#  'heady honeysuckle white stone fruit dill hay vegetal tomato tangy juicy grapefruit white peach honeydew saline depth',
#  'tart yellow fruit cucumber green lemon steel oak minerality rich gripping',
#  'sanguine jam rich plush fruit beef_jerky cedar cranberry crisp edgy leather pepper',
#  'residual_sugar peach pear lemon voluptuous spice flower jasmine dry',
#  'cherry rocks meditteranean_herbs vibrant tangy succulent nectarine cherry strawberry minerality',
#  'firm chewi dark earth umami roasted_meat asphalt mushroom length ripe tannin',
#  'chocolate blackberry hearty oak cigar coffee brawny',
#  'earth complex juicy blackberry bitter tea concentrated oak',
#  'opulent blackberry jam grapey dry fruit concentrated tart tannin rich mellow',
#  'dense depth wood smoke blackberry berry clove dark chocolate full_bodied gripping rich',
#  'spice fruit hard dry',
#  'pepper clove leather cigar succulent fruit smoke',
#  'fruit spice chewi cherry ripe cinnamon cardamom light_bodied astringent',
#  'spice herb plum cassis olive fresh dense leafy berry plum olive herb spice',
#  'smoke oak savory plum berry abrasive lemon_peel toast cassis chocolate toast',
#  'dry purple_flower dark cardamom spice blackberry roast_beef soy pepper chewi dark pencil_lead blueberry asphalt',
#  'gravel asphalt complex bright cherry strawberry fruit rocky minerality spice pepper',
#  'tannin fresh berry cherry firm',
#  'dust slate saffron zesty lime honey light_bodied concentrated marmalade',
#  'mint dry cherry oak bright ripe fruit dense fresh complex',
#  'smoke oak tight gripping fruit leather chocolate tobacco lengthy powerful',
#  'lees burnt banana toast lime dry apple elegant',
#  'fresh strawberry complex mushroom yeast sparkling mousse heavy',
#  'oak spice rich concentrated complex velvety',
#  'funky foamy nectarine yeast bread',
#  'crisp thyme blackberry tar medium_bodied juicy cassis',
#  'dry cherry strawberry anise lush velvety ripe berry cherry concentrated pomegranate bramble',
#  'brilliant fresh tight zingy citrus apple toast bright tangy',
#  'honey crisp fruit concentrated light_bodied ripe light_bodied',
#  'ripe clean perfumed zesty rich green fruit apple green plum refreshing',
#  'spice earth lengthy concentrated cardamom pine fruit dark bramble crisp spice',
#  'smooth licorice coffee tobacco dry herb fruit leather violet',
#  'cherry raspberry dry violet graphite full_bodied blueberry cherry espresso soft round elegant',
#  'fruit dry tannin concentrated firm',
#  'ripe fruit fresh crisp minerality steel fresh lemon lime',
#  'sage dark cranberry butter cherry fresh marjoram wet_rocks thyme bay_leaf anise rich cranberry fruit tannin gripping dark fruit depth',
#  'forest_floor herb leather berry ripe chewi cherry sage licorice toasted_nut tight',
#  'pale pink_color lime_peel wet_rocks bright citrus',
#  'dust apple minerality crisp round stone apple quince',
#  'tight wood brine citrus dry stone fruit racy dry apricot tart nectarine almond',
#  'scorched_earth game truffle plum ripe dry blackberry cherry anise almond firm',
#  'chocolate spice powerful',
#  'cherry rose spice round savory juicy fleshy cherry raspberry star_anise coffee polished',
#  'rose violet berry menthol cooked spice linear cherry orange_peel clove white pepper licorice tobacco firm',
#  'fruit herb firm savory soy_sauce plum ripe cherry warm earth plum berry',
#  'dry dry plum clove scorched_earth balsamic concentrated dry cherry raisin licorice pepper firm',
#  'luminous fresh berry violet herbs baked spice vibrant linear cherry strawberry white pepper star_anise racy polished',
#  'violet perfumed berry baked spice sleek savory ripe cherry raspberry cinnamon clove star_anise firm polished',
#  'berry herbs blue_flower menthol elegant juicy ripe cherry raspberry licorice vanilla round',
#  'dark tobacco violet soy pepper plum wood pepper dry violet lavender thyme rosemary elderberry',
#  'concentrated concrete oak flower light_bodied toast length',
#  'oil ripe caramel toast depth gold crisp green apple melon complex minerality supple',
#  'zesty fresh rich oak smoke caramel pear vanilla oak apple white peach nectarine lime_peel',
#  'depth cassis berry racy tight full_bodied berry pepper baked spice chocolate toast pepper juicy',
#  'rose blue_flower incense truffle pepper coffee licorice depth bright fruit polished smooth silky fresh',
#  'fruit tangy rich juicy light_bodied spice green fruit zesty bitter orange fruit',
#  'sweet oak vanilla plum violet coffee oak ripe cherry leather baked spice tight closed',
#  'undergrowth tobacco leather truffle blackberry toast fig cherry carob bitter cocoa white pepper dry',
#  'smooth cherry allspice elegant fruit',
#  'butter toast nut minerality apple butter cinnamon vanilla',
#  'elegant sparkling rose berry yeast fresh baked depth tart apple strawberry sage marjoram brisk elegant mousse',
#  'fresh refined fruit wild_berry forest_floor pine rose bright strawberry cherry vanilla cinnamon smooth supple bright',
#  'light_bodied austere plum blackberry weight fruit',
#  'dark dense powerful concentrated firm fruit',
#  'crisp grapefruit tight tangy steel fruit austere',
#  'sugar juicy sweet rich fruit ripe grapefruit peach apricot length',
#  'grilled_meat pepper jam blackberry coffee bitter powerful',
#  'light_bodied toast tobacco blueberry pie cedar fresh blueberry cigar',
#  'oak tight dense cherry chocolate licorice baked spice silky full_bodied',
#  'heavy coffee dark cherry coffee',
#  'berry cherry minerality',
#  'mint hot gravel fruit light_bodied complex herb spice blackberry fruit',
#  'reedy berry eucalyptus tight tannin dry leafy herb fruit licorice coffee dry snappy earth spice olive mint',
#  'vibrant slate peach apricot citrus dry depth rich fruit',
#  'strawberry cake dry purple_flower cigar_box elegant purple fruit leather pepper tart',
#  'ripe lush complex plum cassis gripping snappy',
#  'elegant pear ginger lemon herb',
#  'flint smoke nectarine citrus ginger white pepper balsamic depth complex',
#  'plum asphalt oak toast spice forest_floor cherry coffee licorice minerality',
#  'ripe spice rich fruit depth minerality',
#  'plush oak depth berry cassis chocolate coffee wood spice rich berry fruit oak',
#  'flower perfumed lavender pepper white pepper thyme tart plum savory dry purple_flower thyme rosemary pepper medium_bodied dense',
#  'baked pear fruit honeysuckle apple fresh',
#  'ripe fruit brilliant fruit dense',
#  'fruit asphalt pepper rosemary lavender plum light_bodied tar juicy purple fruit',
#  'feral game rosemary dry fennel rose forest_floor blackberry light_bodied firm rosemary lavender game',
#  'light_bodied gold bright jasmine succulent steel minerality powerful',
#  'wood rich spice fruit ripe raspberry fruit lemon',
#  'light_bodied crisp tight elegant fruit spice tangy minerality fruit',
#  'rich dark fruit tannin',
#  'dry ripe fruit berry lemon juicy full_bodied rich',
#  'perfumed ripe yellow fruit currant citrus',
#  'rich oil lavish opulent plump blueberry soft spice cherry dark chocolate caramel powerful',
#  'oak viscous green apple melon peach honeysuckle grapefruit_peel voluptuous weight ripe',
#  'oak perfumed tart boysenberry rich caramel oak cola plum gravel bay_leaf meaty depth',
#  'fresh herb lemon olive citrus fresh apple fruit',
#  'earth dust loamy rich grippy chewi oak dark chocolate clove tobacco blueberry blackberry',
#  'meaty smoke pepper dense blue fruit powerful coffee chocolate',
#  'rich pastry raspberry tart tangy gripping length',
#  'powerful toffee weight nut salt caramel dry apricot buttery_toast umami racy',
#  'cola cocoa graphite tobacco blackberry fruit light_bodied elegant',
#  'rich almond peach apple pear fruit light_bodied bright wet_rocks gravel',
#  'stone',
#  'shine violet blueberry light_bodied pepper elegant clove',
#  'ripe fruit raisin tire_rubber toast french_oak dark tight gripping oak cassis blackberry firm closed',
#  'edgy cherry plum mulberry pepper spice sage rich full_bodied tangy plum eucalyptus fresh',
#  'butter rich smoke honeysuckle almond apple cream marshmallow pear citrus',
#  'grapefruit green tea cola sleek berry',
#  'ocean feral robust fruit tart cranberry orange_peel',
#  'hearty spice cherry cardamom spice sanguine meaty dry cherry indian_spice olive gripping',
#  'undergrowth fruit toast coffee oak coffee coconut vanilla coffee dry cherry prune clove raspy fruit rich dry',
#  'ripe fruit heavy toast fruit weight dark juicy',
#  'herb earth fruit dense dust ripe sweet plum wood rich spice',
#  'weight fruit ripe berry fruit fresh powerful dry dense',
#  'ripe smooth rich raspberry fresh fruit juicy',
#  'depth blueberry prune dry purple bacon purple fruit juicy sharp licorice edgy',
#  'brine bell_pepper vegetal round celery bell_pepper lime tangerine grass brine',
#  'rich pineapple apple',
#  'tropical_fruit citrus bell_pepper zesty lemon tangerine brine citrus juicy crisp',
#  'minerality white oak vanilla brioche viscous vibrant fruit ripe apple apricot',
#  'cherry plum rubber raisin depth light_bodied herb flower plum cherry oak resin elegant',
#  'fresh fruit polished raspberry plum chocolate blackberry rich firm fruit',
#  'wildflower lemon_peel dry citrus white grapefruit bitter_almond white fresh',
#  'dense earth meaty light_bodied tannin forest_floor plum baked',
#  'vibrant elegant cherry raspberry alpine_herbs supple bright',
#  'foamy sparkling sparkling apple ripe pear low_complexity apple white flower guava tropical_fruit',
#  'ripe fruit spice undergrowth dry herb dry cherry plum clove sage',
#  'spice tight pear fruit white pepper watery cracker',
#  'dense earth berry fruit latex crisp fresh hot light_bodied herb leather currant wild_berry oak',
#  'coffee tobacco cedar fruit elegant currant dry cherry clove anise silky',
#  'concentrated berry fruit soft fresh fruit',
#  'sawdust oak spice currant toast oak coffee menthol pepper dry cherry grippy astringent',
#  'fresh strawberry fruit spice tart lemon',
#  'crisp dry tannin cranberry ripe cherry dry currant savory dry herb clove',
#  'dense concentrated prune tobacco leather syrupy blackberry extracted fig sweet spice velvety complex',
#  'firm spice plum violet spice juicy ripe cherry licorice clove tight refined',
#  'fruit cherry hard candy light_bodied herb stemmy fruit',
#  'concentrated fruit powerful juicy fruit',
#  'dark raspberry fruit graphite dark earth rocks earth juniper sour',
#  'white citrus flower soft lemon_curd orange white fruit rich high_alcohol',
#  'berry undergrowth leather fennel herb firm vibrant ripe cherry raspberry licorice coffee balsamic',
#  'smooth smoke edgy purple plum berry fruit silky length',
#  'fruit ripe currant berry spice wood fresh juicy',
#  'ripe fruit spice tannin cherry raspberry sweet chocolate',
#  'resin oak stalky berry cherry raspberry grabby clampy oak berry baked plum oak raisin licorice',
#  'fruit blue_flower round dry cherry blackberry jam licorice tobacco chewi',
#  'dark blackberry pepper juniper berry smooth plum blackberry white peach elderberry violet eucalyptus fresh cherry juicy',
#  'strawberry dense powerful tight oak spice',
#  'fresh apple pear fresh herb citrus_peel honey steel',
#  'raisin white pepper ripe fruit flower spice anise full_bodied hearty complex firm',
#  'dark strawberry plum caramel smoked_meat blackberry blueberry smoked_meat vanilla coffee vanilla silky orange_peel',
#  'blue_flower plum licorice clove coffee menthol brawny warm full_bodied juicy cherry coffee pepper anise hot',
#  'concentrated wood light oak ripe yellow fruit crisp tangy spice bright',
#  'rich concentrated almond hazelnut light_bodied lengthy lemon_peel apple',
#  'flower cherry pomegranate fresh pepper pomegranate strawberry mace anise smooth bright',
#  'soft ripe nectarine citrus edgy pith orange bitter dry apple',
#  'fruit minerality fruit gripping powerful dense herb',
#  'dark cherry flower cherry matchstick petrol cherry pomegranate bell_pepper light_bodied flower chewi orange_peel cranberry',
#  'dark berry coffee toast cooked spice cherry coffee dry herb',
#  'vanilla soft spice fruit mellow sweet',
#  'rose bright berry anise sour cherry tobacco clove herbs brisk',
#  'brawny plum coffee menthol dense chewi cherry licorice coffee warm',
#  'rose berry coffee herb toast crunchy cherry raspberry star_anise white pepper tight assertive closed coffee',
#  'earth leather game earth berry dry cherry coffee coffee licorice tobacco fresh',
#  'dark berry blue_flower spice firm ripe cherry white pepper cocoa star_anise balsamic',
#  'cherry plum butter oak leather firm ripe loamy berry cassis light_bodied raisin round',
#  'wild_berry dark spice menthol low_complexity dark cherry licorice dry herb firm ripe',
#  'oak toast brown_sugar coffee fruit dark berry cola clove cinnamon cream lush weight dry fruit vanilla coffee',
#  'fresh toast light_bodied cranberry cherry fruit tart oak',
#  'clean crisp bright steel wood fresh fruit apple melon ginger racy',
#  'yellow apple chamomile flower ripe acacia bitter_almond',
#  'smoke toast oak butter viscous',
#  'clean citrus grapefruit orange soft tart',
#  'sweet clean crisp citrus apple orange_peel',
#  'light_bodied spritzy crisp apple refreshing bright tangy',
#  'dry sparkling spice berry fruit depth rich oily',
#  'soft cream fruit yeast edgy',
#  'soft herb smooth bright crisp citrus gooseberry',
#  'white fruit crisp refreshing herb edgy lemon grapefruit zingy bright',
#  'dust plum berry clean hard salt snappy plum dry',
#  'yeast toast fruit crisp bright',
#  'butter butter spice vanilla cream smooth',
#  'soft fresh apple apple crisp clean',
#  'minerality tight yeast crisp bright apple fruit',
#  ...]

# %%
data['description'] = mapped_reviews
data.drop(columns = 'index')
wine_dict = data.to_dict(orient='index')

# %%
wine_dict
# Out:
# {0: {'index': 0,
#   'country': 'US',
#   'description': 'oak juicy fruit caramel elegant mint',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Heitz'},
#  1: {'index': 1,
#   'country': 'Spain',
#   'description': 'ripe fig blackberry cassis sweet oak chocolate vanilla rich chocolate fruit baked spice toast heady',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  2: {'index': 2,
#   'country': 'US',
#   'description': 'complex white dark gold toasted_hazelnut pear compote orange_peel succulent residual_sugar',
#   'province': 'California',
#   'region_1': 'Knights Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Macauley'},
#  3: {'index': 3,
#   'country': 'US',
#   'description': 'oak fruit dense toast toast cigar_box blackberry cherry coffee graphite polished dark chocolate coffee',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  4: {'index': 4,
#   'country': 'France',
#   'description': 'dense wood rich concentrated',
#   'province': 'Provence',
#   'region_1': 'Bandol',
#   'variety': 'Provence red blend',
#   'winery': 'Domaine de la Bégude'},
#  5: {'index': 5,
#   'country': 'Spain',
#   'description': 'depth dense dark ripe fruit oak blackberry coffee coffee toast oak spice smooth heady',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  6: {'index': 6,
#   'country': 'Spain',
#   'description': 'gritty sweet pastry prune blackberry coffee chocolate',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Maurodos'},
#  7: {'index': 7,
#   'country': 'Spain',
#   'description': 'lush cedar almond vanilla tannin lush chocolate baked berry cassis hard tannin depth',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Bodega Carmen Rodríguez'},
#  8: {'index': 8,
#   'country': 'US',
#   'description': 'minerality chunky fruit citrus graphite concentrated',
#   'province': 'Oregon',
#   'region_1': 'Chehalem Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  9: {'index': 9,
#   'country': 'US',
#   'description': 'bright crunchy cranberry pomegranate orange_peel silky succulent fleshy fruit lush length',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Blue Farm'},
#  10: {'index': 10,
#   'country': 'Italy',
#   'description': 'elegant complex white yellow spring_flower herb fruit cream juicy white peach ripe pear citrus white almond savory minerality',
#   'province': 'Northeastern Italy',
#   'region_1': 'Collio',
#   'variety': 'Friulano',
#   'winery': 'Borgo del Tiglio'},
#  11: {'index': 11,
#   'country': 'US',
#   'description': 'supple coffee cherry vanilla savory',
#   'province': 'Oregon',
#   'region_1': 'Ribbon Ridge',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  12: {'index': 12,
#   'country': 'US',
#   'description': 'green cola tobacco orange vanilla tea milk_chocolate ripe blackberry fruit',
#   'province': 'Oregon',
#   'region_1': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Patricia Green Cellars'},
#  13: {'index': 13,
#   'country': 'France',
#   'description': 'ripe fruit dry berry fruit',
#   'province': 'Southwest France',
#   'region_1': 'Madiran',
#   'variety': 'Tannat',
#   'winery': 'Vignobles Brumont'},
#  14: {'index': 14,
#   'country': 'US',
#   'description': 'minerality tart fruit supple dense strawberry blueberry plum cherry chocolate minerality silky',
#   'province': 'Oregon',
#   'region_1': 'Dundee Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Domaine Serene'},
#  15: {'index': 15,
#   'country': 'US',
#   'description': 'succulent minerality rich butterscotch lees',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Bergström'},
#  16: {'index': 16,
#   'country': 'US',
#   'description': 'blueberry pie chocolate smooth silky complex cedar pepper pepper oak dense rich finessed spice',
#   'province': 'California',
#   'region_1': 'Diamond Mountain District',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hall'},
#  17: {'index': 17,
#   'country': 'Spain',
#   'description': 'oak blackberry licorice vanilla smooth coffee blackberry raspberry fruit chocolate velvety',
#   'province': 'Northern Spain',
#   'region_1': 'Ribera del Duero',
#   'variety': 'Tempranillo',
#   'winery': 'Valduero'},
#  18: {'index': 18,
#   'country': 'France',
#   'description': 'powerful fruit wood dark rich concentrated elegant restrained',
#   'province': 'Southwest France',
#   'region_1': 'Cahors',
#   'variety': 'Malbec',
#   'winery': 'Château Lagrézette'},
#  19: {'index': 19,
#   'country': 'US',
#   'description': 'fresh cherry tangy crisp orange_peel cherry pomegranate baked spice',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Gary Farrell'},
#  20: {'index': 20,
#   'country': 'US',
#   'description': 'strawberry watermelon orange_peel salt spice vibrant flower',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Rosé',
#   'winery': 'Heitz'},
#  21: {'index': 21,
#   'country': 'Spain',
#   'description': 'complex powerful grilled_meat berry tea smoke vanilla spice concentrated elegant blackberry molasses coffee chocolate oak',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Muga'},
#  22: {'index': 22,
#   'country': 'Spain',
#   'description': 'tar blackberry cheese oak expansive grabby bullish salt earth blackberry baked spice chocolate chocolate hard tannin',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Numanthia'},
#  23: {'index': 23,
#   'country': 'US',
#   'description': 'white oak almond white peach sizzling salt lemon brown_butter rich finessed luxurious',
#   'province': 'California',
#   'region_1': 'Edna Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Center of Effort'},
#  24: {'index': 24,
#   'country': 'US',
#   'description': 'fruit cherry sage eucalyptus ripe plum strawberry fruit juniper pine bay_leaf',
#   'province': 'California',
#   'region_1': 'Santa Cruz Mountains',
#   'variety': 'Pinot Noir',
#   'winery': 'Comartin'},
#  25: {'index': 25,
#   'country': 'New Zealand',
#   'description': 'silky hickory_smoke white peach lime_peel',
#   'province': 'Kumeu',
#   'region_1': nan,
#   'variety': 'Chardonnay',
#   'winery': 'Kumeu River'},
#  26: {'index': 26,
#   'country': 'US',
#   'description': 'jelly rose plum complex fruit cola brown_sugar',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Bergström'},
#  27: {'index': 27,
#   'country': 'US',
#   'description': 'dense ripe raspberry oak coffee coffee cedar cinnamon dark chocolate',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Ponzi'},
#  28: {'index': 28,
#   'country': 'US',
#   'description': 'cranberry baked rhubarb anise slate raspberry fruit earth loamy fennel oregano juniper round',
#   'province': 'California',
#   'region_1': 'Santa Lucia Highlands',
#   'variety': 'Pinot Noir',
#   'winery': 'Roar'},
#  29: {'index': 29,
#   'country': 'US',
#   'description': 'stone earth brine olive green olive orange_peel gravel smoked_meat cured_meat',
#   'province': 'Washington',
#   'region_1': 'Walla Walla Valley (WA)',
#   'variety': 'Syrah',
#   'winery': 'Saviah'},
#  30: {'index': 30,
#   'country': 'Bulgaria',
#   'description': 'dry cherry plum fresh pepper eucalyptus soft dry cherry cassis plum',
#   'province': 'Bulgaria',
#   'region_1': nan,
#   'variety': 'Mavrud',
#   'winery': 'Villa Melnik'},
#  31: {'index': 31,
#   'country': 'US',
#   'description': 'steel perfumed oak vibrant fresh baked apple lemon_pith grapefruit spice',
#   'province': 'California',
#   'region_1': 'Russian River Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Zepaltas'},
#  32: {'index': 32,
#   'country': 'Italy',
#   'description': 'undergrowth scorched_earth menthol plum chewi ripe cherry raspberry jam pepper licorice firm velvety warm',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Abbadia Ardenga'},
#  33: {'index': 34,
#   'country': 'US',
#   'description': 'wet_rocks honeysuckle chamomile stone fruit',
#   'province': 'Washington',
#   'region_1': 'Columbia Valley (WA)',
#   'variety': 'Chardonnay',
#   'winery': 'Buty'},
#  34: {'index': 35,
#   'country': 'Italy',
#   'description': 'forest_floor berry leather ripe fleshy cherry dry herb tobacco gripping',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Carillon'},
#  35: {'index': 36,
#   'country': 'France',
#   'description': 'spice fresh pear melon fruit round flabby warm spice',
#   'province': 'Rhône Valley',
#   'region_1': 'Châteauneuf-du-Pape',
#   'variety': 'Rhône-style White Blend',
#   'winery': "Clos de L'Oratoire des Papes"},
#  36: {'index': 37,
#   'country': 'Italy',
#   'description': 'forest_floor violet berry dark baked spice cherry raspberry pepper star_anise firm',
#   'province': 'Tuscany',
#   'region_1': 'Vino Nobile di Montepulciano',
#   'variety': 'Sangiovese',
#   'winery': 'Avignonesi'},
#  37: {'index': 38,
#   'country': 'Italy',
#   'description': 'rose violet berry juicy ripe cherry mint white pepper star_anise complex savory fresh supple',
#   'province': 'Tuscany',
#   'region_1': 'Chianti Classico',
#   'variety': 'Sangiovese',
#   'winery': 'Casina di Cornia'},
#  38: {'index': 39,
#   'country': 'Italy',
#   'description': 'bright savory juicy cherry raspberry violet white pepper coffee polished',
#   'province': 'Tuscany',
#   'region_1': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Castello di Monterinaldi'},
#  39: {'index': 40,
#   'country': 'Spain',
#   'description': 'earth plum cherry round smooth light_bodied brine earth plum cherry salt',
#   'province': 'Galicia',
#   'region_1': 'Ribeira Sacra',
#   'variety': 'Mencía',
#   'winery': 'Don Bernardino'},
#  40: {'index': 41,
#   'country': 'Spain',
#   'description': 'expansive oily hazelnut toffee plump light_bodied buttery_toast toffee peanut',
#   'province': 'Andalucia',
#   'region_1': 'Jerez',
#   'variety': 'Palomino',
#   'winery': 'González Byass'},
#  41: {'index': 42,
#   'country': 'US',
#   'description': 'scorched_earth plum dry flower green herb dense tart',
#   'province': 'Idaho',
#   'region_1': nan,
#   'variety': 'Petite Sirah',
#   'winery': 'Huston'},
#  42: {'index': 43,
#   'country': 'Italy',
#   'description': 'rose herb round juicy ripe cherry fleshy raspberry white pepper clove polished smooth velvety',
#   'province': 'Tuscany',
#   'region_1': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Rignana'},
#  43: {'index': 44,
#   'country': 'France',
#   'description': 'dark coffee plum fruit soft dust',
#   'province': 'Rhône Valley',
#   'region_1': 'Cornas',
#   'variety': 'Syrah',
#   'winery': 'Tardieu-Laurent'},
#  44: {'index': 45,
#   'country': 'Italy',
#   'description': 'violet plum coffee forest_floor firm dry cherry pepper toast clove',
#   'province': 'Tuscany',
#   'region_1': 'Chianti Classico',
#   'variety': 'Red Blend',
#   'winery': 'Vignavecchia'},
#  45: {'index': 46,
#   'country': 'Italy',
#   'description': 'earth ripe berry baked spice menthol juicy cherry pomegranate star_anise coffee tobacco',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Banfi'},
#  46: {'index': 47,
#   'country': 'US',
#   'description': 'juicy cherry cassis pillowy tar fruit',
#   'province': 'California',
#   'region_1': 'Mount Veeder',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Brandlin'},
#  47: {'index': 48,
#   'country': 'Italy',
#   'description': 'ripe forest_floor cooked spice leather chewi fleshy cherry cinnamon vanilla tobacco polished',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Brunelli Martoccia'},
#  48: {'index': 49,
#   'country': 'US',
#   'description': 'blue fruit herb spice tight restrained firm grain length',
#   'province': 'Washington',
#   'region_1': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Canvasback'},
#  49: {'index': 50,
#   'country': 'Italy',
#   'description': 'robust coffee plum cake toast dark spice hearty blackberry jam licorice vanilla coffee firm coffee closed',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Capanne Ricci'},
#  50: {'index': 51,
#   'country': 'France',
#   'description': 'complex minerality weight tight tannin',
#   'province': 'Burgundy',
#   'region_1': 'Chassagne-Montrachet',
#   'variety': 'Chardonnay',
#   'winery': 'Chartron et Trébuchet'},
#  51: {'index': 52,
#   'country': 'France',
#   'description': 'ripe ripe green fruit lime rich apricot concentrated fruit',
#   'province': 'Loire Valley',
#   'region_1': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Cherrier Frères'},
#  52: {'index': 53,
#   'country': 'France',
#   'description': 'light_bodied smoke fruit fresh',
#   'province': 'Loire Valley',
#   'region_1': 'Coteaux du Giennois',
#   'variety': 'Pinot Noir',
#   'winery': 'Clement et Florian Berthier'},
#  53: {'index': 54,
#   'country': 'US',
#   'description': 'white hazelnut cream vanilla round oak',
#   'province': 'California',
#   'region_1': 'Russian River Valley',
#   'variety': 'Chardonnay',
#   'winery': 'De Loach'},
#  54: {'index': 55,
#   'country': 'US',
#   'description': 'wood spice cherry light_bodied elegant gripping',
#   'province': 'Washington',
#   'region_1': 'Red Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'DeLille'},
#  55: {'index': 56,
#   'country': 'France',
#   'description': 'minerality citrus green fruit tight round',
#   'province': 'Loire Valley',
#   'region_1': 'Sancerre',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Domaine Vacheron'},
#  56: {'index': 57,
#   'country': 'US',
#   'description': 'exuberant fruit tropical_fruit minerality edgy dry refreshing vibrant light_bodied honey',
#   'province': 'New York',
#   'region_1': 'Finger Lakes',
#   'variety': 'Riesling',
#   'winery': 'Dr. Konstantin Frank'},
#  57: {'index': 58,
#   'country': 'US',
#   'description': 'cherry herb minerality firm',
#   'province': 'Washington',
#   'region_1': 'Columbia Valley (WA)',
#   'variety': 'Cabernet Sauvignon-Syrah',
#   'winery': 'Efeste'},
#  58: {'index': 59,
#   'country': 'Italy',
#   'description': 'savory coffee leather tobacco dark woody_berry chewi juicy plum cassis clove polished',
#   'province': 'Tuscany',
#   'region_1': 'Maremma Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Fattoria di Magliano'},
#  59: {'index': 60,
#   'country': 'Argentina',
#   'description': 'concentrated ripe blackberry cassis pepper spice cedar oak blackberry hot sizzling',
#   'province': 'Mendoza Province',
#   'region_1': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Matias Riccitelli'},
#  60: {'index': 61,
#   'country': 'Australia',
#   'description': 'supple firm cherry mint earthy brown_sugar',
#   'province': 'Victoria',
#   'region_1': 'Mornington Peninsula',
#   'variety': 'Pinot Noir',
#   'winery': 'Moorooduc'},
#  61: {'index': 62,
#   'country': 'Argentina',
#   'description': 'smoke wood berry cassis flower oak plum cassis vanilla',
#   'province': 'Mendoza Province',
#   'region_1': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Navarro Correas'},
#  62: {'index': 63,
#   'country': 'France',
#   'description': 'tight toast tangy',
#   'province': 'Burgundy',
#   'region_1': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Chenevières'},
#  63: {'index': 64,
#   'country': 'Portugal',
#   'description': 'concentrated fruit wood dense firm plum blackberry dark concentrated',
#   'province': 'Alentejano',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Herdade do Rocim'},
#  64: {'index': 65,
#   'country': 'US',
#   'description': 'fresh boysenberry blueberry sorbet mint tarragon dill hot gravel pepper light_bodied tobacco coffee boysenberry',
#   'province': 'California',
#   'region_1': 'Santa Clara Valley',
#   'variety': 'Syrah',
#   'winery': 'Jason-Stephens'},
#  65: {'index': 66,
#   'country': 'France',
#   'description': 'steel crisp lemon minerality edgy juicy fresh',
#   'province': 'Burgundy',
#   'region_1': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Louis Max'},
#  66: {'index': 67,
#   'country': 'US',
#   'description': 'tight tobacco tea coconut',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Michael Mondavi Family Estate'},
#  67: {'index': 68,
#   'country': 'US',
#   'description': 'full_bodied dark chewi fruit cedar tobacco thick',
#   'province': 'Oregon',
#   'region_1': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Panther Creek'},
#  68: {'index': 69,
#   'country': 'US',
#   'description': 'juicy cherry vanilla oak cedar smooth medium_bodied coffee chocolate',
#   'province': 'California',
#   'region_1': 'Rutherford',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Provenance Vineyards'},
#  69: {'index': 70,
#   'country': 'US',
#   'description': 'sweet depth chocolate blackberry soft juicy rich dense elegant spice clove cinnamon',
#   'province': 'California',
#   'region_1': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Raymond'},
#  70: {'index': 71,
#   'country': 'US',
#   'description': 'tight light_bodied bright cherry pomegranate rose',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Red Car'},
#  71: {'index': 72,
#   'country': 'Italy',
#   'description': 'rose wild_berry dark cooked spice baked earth ripe cherry licorice game chocolate velvety warm closed',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Silvano Bolmida'},
#  72: {'index': 73,
#   'country': 'US',
#   'description': 'fruit fleshy fruit sweet dry dense length',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Gris',
#   'winery': 'Trinity Vineyards'},
#  73: {'index': 74,
#   'country': 'Portugal',
#   'description': 'ripe dark firm dense concentrated juicy berry firm',
#   'province': 'Alentejo',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Adega Cooperativa de Borba'},
#  74: {'index': 75,
#   'country': 'US',
#   'description': 'elegant sturdy currant fruit baked spice orange',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Archery Summit'},
#  75: {'index': 76,
#   'country': 'France',
#   'description': 'round toast linear fresh crisp citrus almond',
#   'province': 'Champagne',
#   'region_1': 'Champagne',
#   'variety': 'Chardonnay',
#   'winery': 'Aubry'},
#  76: {'index': 77,
#   'country': 'US',
#   'description': 'crisp white lean lemon grapefruit tangerine refreshing white peach',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'B Cellars'},
#  77: {'index': 78,
#   'country': 'US',
#   'description': 'chocolate graham_cracker vanilla jam thick tobacco',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'B Side'},
#  78: {'index': 79,
#   'country': 'Italy',
#   'description': 'undergrowth smoke coffee dark fruit ripe dry cherry licorice clove firm velvety',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Bel Colle'},
#  79: {'index': 80,
#   'country': 'US',
#   'description': 'fruit tart toast coffee fresh',
#   'province': 'Oregon',
#   'region_1': 'Eola-Amity Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Bethel Heights'},
#  80: {'index': 81,
#   'country': 'Israel',
#   'description': 'dark violet cherry lavender rose cherry raspberry herb silky bright cherry',
#   'province': 'Upper Galilee',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Binyamina'},
#  81: {'index': 82,
#   'country': 'Italy',
#   'description': 'berry baked spice dry mint vanilla white pepper sage anise orange_peel yellow peach cherry balsamic closed firm refined',
#   'province': 'Piedmont',
#   'region_1': 'Roero',
#   'variety': 'Nebbiolo',
#   'winery': 'Ceste'},
#  82: {'index': 83,
#   'country': 'Italy',
#   'description': 'hearty forest_floor leather licorice menthol firm chewi ripe cherry raspberry jam anise tobacco dark',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina Cucco'},
#  83: {'index': 84,
#   'country': 'Italy',
#   'description': 'woody_berry rose mint menthol mint cherry raspberry spice toast assertive bright',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina del Monastero'},
#  84: {'index': 85,
#   'country': 'Italy',
#   'description': 'french_oak coconut vanilla spice plum powerful oak warm cherry licorice menthol',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cordero di Montezemolo'},
#  85: {'index': 86,
#   'country': 'France',
#   'description': 'refreshing tight minerality fruit tangy crisp tight toast apple citrus tight',
#   'province': 'Burgundy',
#   'region_1': 'Chablis',
#   'variety': 'Chardonnay',
#   'winery': 'Domaine Gérard Duplessis'},
#  86: {'index': 87,
#   'country': 'US',
#   'description': 'hot spice cinnamon clove pine depth plum dark cherry clove powerful leather',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Eagle Glen'},
#  87: {'index': 88,
#   'country': 'US',
#   'description': 'light_bodied concentrated ripe rich fruit kirsch cherry raspberry cinnamon lush plush',
#   'province': 'California',
#   'region_1': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Eleven Eleven'},
#  88: {'index': 89,
#   'country': 'US',
#   'description': 'blackberry chocolate chalk full_bodied licorice cassis tea',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Meritage',
#   'winery': 'Franciscan'},
#  89: {'index': 90,
#   'country': 'US',
#   'description': 'bright light_bodied oak cherry strawberry fresh fruit',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Belle Ambiance'},
#  90: {'index': 91,
#   'country': 'Portugal',
#   'description': 'fruit sparkling bright crisp tangy currant',
#   'province': 'Beira Atlantico',
#   'region_1': nan,
#   'variety': 'Baga',
#   'winery': 'Adega de Cantanhede'},
#  91: {'index': 92,
#   'country': 'Italy',
#   'description': 'white spring_flower fruit citrus ripe yellow peach green apple foamy mousse',
#   'province': 'Veneto',
#   'region_1': 'Prosecco',
#   'variety': 'Glera',
#   'winery': 'De Stefani'},
#  92: {'index': 93,
#   'country': 'US',
#   'description': 'smoke earth smooth',
#   'province': 'California',
#   'region_1': 'Mendocino County',
#   'variety': 'Chardonnay',
#   'winery': 'Parducci'},
#  93: {'index': 94,
#   'country': 'Portugal',
#   'description': 'light_bodied spice wood fruit ripe bright',
#   'province': 'Douro',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Quinta do Portal'},
#  94: {'index': 95,
#   'country': 'France',
#   'description': 'smooth soft fruit ripe round edgy rich juicy fruit',
#   'province': 'Southwest France',
#   'region_1': 'Cahors',
#   'variety': 'Malbec-Merlot',
#   'winery': 'Rigal'},
#  95: {'index': 96,
#   'country': 'US',
#   'description': 'oak crisp ripe pear baked spice soft smooth',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Chardonnay',
#   'winery': 'The Naked Grape'},
#  96: {'index': 97,
#   'country': 'US',
#   'description': 'austere modest crisp currant cranberry cedar dry herb',
#   'province': 'California',
#   'region_1': 'Sonoma Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Tin Barn'},
#  97: {'index': 98,
#   'country': 'France',
#   'description': 'spice stalky bright berry fruit crisp light_bodied minerality',
#   'province': 'Southwest France',
#   'region_1': 'Buzet',
#   'variety': 'Merlot-Malbec',
#   'winery': 'Georges Vigouroux'},
#  98: {'index': 99,
#   'country': 'France',
#   'description': 'light_bodied refreshing bright perfumed herb citrus',
#   'province': 'Southwest France',
#   'region_1': 'Côtes de Gascogne',
#   'variety': 'Ugni Blanc-Colombard',
#   'winery': 'Georges Vigouroux'},
#  99: {'index': 100,
#   'country': 'US',
#   'description': 'juicy kiwi lime sour apple candy ripe oily honeydew',
#   'province': 'California',
#   'region_1': 'South Coast',
#   'variety': 'Viognier',
#   'winery': 'Hawk Watch Winery'},
#  100: {'index': 101,
#   'country': 'US',
#   'description': 'bramble herb bright ripe tar toffee rich cola',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Hestan'},
#  101: {'index': 102,
#   'country': 'Italy',
#   'description': 'undergrowth berry toast low_complexity lean sour cherry green sage pepper astringent',
#   'province': 'Tuscany',
#   'region_1': 'Brunello di Montalcino',
#   'variety': 'Sangiovese',
#   'winery': 'Il Grappolo'},
#  102: {'index': 103,
#   'country': 'US',
#   'description': 'leather tobacco pepper rustic edgy fruit mellow',
#   'province': 'California',
#   'region_1': 'Knights Valley',
#   'variety': 'Cabernet Sauvignon-Cabernet Franc',
#   'winery': 'Ehret'},
#  103: {'index': 104,
#   'country': 'US',
#   'description': 'sticky sweet oily candy honeydew kiwi sweet juniper pine gold honey soft oil thick',
#   'province': 'California',
#   'region_1': 'Paso Robles',
#   'variety': 'Moscato',
#   'winery': 'EOS'},
#  104: {'index': 105,
#   'country': 'US',
#   'description': 'ripe lean overripe apple melon orange_peel fruit',
#   'province': 'Washington',
#   'region_1': 'Yakima Valley',
#   'variety': 'Pinot Grigio',
#   'winery': 'Martinez & Martinez'},
#  105: {'index': 106,
#   'country': 'US',
#   'description': 'wood smoke grilled_meat assertive oak dry herb medium_bodied soft',
#   'province': 'California',
#   'region_1': 'Lodi',
#   'variety': 'Cabernet Franc',
#   'winery': 'Ironstone'},
#  106: {'index': 107,
#   'country': 'US',
#   'description': 'earth flower low_complexity fruit',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Chardonnay',
#   'winery': 'Leaping Horse'},
#  107: {'index': 108,
#   'country': 'US',
#   'description': 'dry earth savory fruit walnut almond',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'White Blend',
#   'winery': 'Kitchen Sink'},
#  108: {'index': 109,
#   'country': 'US',
#   'description': 'oak medium_bodied overripe honeysuckle lime lemon_peel',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Kuleto Estate'},
#  109: {'index': 110,
#   'country': 'Portugal',
#   'description': 'soft ripe light_bodied fruit',
#   'province': 'Tejo',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Wines & Winemakers'},
#  110: {'index': 111,
#   'country': 'Argentina',
#   'description': 'rubber citrus fruit round dry citrus',
#   'province': 'Mendoza Province',
#   'region_1': 'Tupungato',
#   'variety': 'Rosé',
#   'winery': 'Zorzal'},
#  111: {'index': 112,
#   'country': 'US',
#   'description': 'tannin oak hard ripe smoke oak currant concentrated powerful',
#   'province': 'California',
#   'region_1': 'Howell Mountain',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Charles Krug'},
#  112: {'index': 113,
#   'country': 'US',
#   'description': 'savory apple pear lemon bramble earth tangerine bright sweet',
#   'province': 'New York',
#   'region_1': 'Hudson River Region',
#   'variety': 'Riesling',
#   'winery': 'Millbrook'},
#  113: {'index': 114,
#   'country': 'South Africa',
#   'description': 'tart gooseberry lime flower pith plum currant citrus_peel light_bodied astringent fresh herb saline closed',
#   'province': 'Stellenbosch',
#   'region_1': nan,
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Waterkloof'},
#  114: {'index': 115,
#   'country': 'Argentina',
#   'description': 'prune raisin plum gritty chunky grabby blackberry burnt coffee dark chocolate plump rubber closed',
#   'province': 'Mendoza Province',
#   'region_1': 'Valle de Uco',
#   'variety': 'Malbec',
#   'winery': 'Viñalba'},
#  115: {'index': 116,
#   'country': 'Spain',
#   'description': 'cherry cassis horsey hot sweet hard cherry cassis baked plum chunky',
#   'province': 'Levante',
#   'region_1': 'Jumilla',
#   'variety': 'Monastrell',
#   'winery': 'Casa de la Ermita'},
#  116: {'index': 117,
#   'country': 'France',
#   'description': 'pale fruit crisp soft',
#   'province': 'Southwest France',
#   'region_1': 'Gaillac',
#   'variety': 'Rosé',
#   'winery': 'Château Clément Termes'},
#  117: {'index': 118,
#   'country': 'France',
#   'description': 'soft fruit light fruit earth edgy',
#   'province': 'Southwest France',
#   'region_1': nan,
#   'variety': 'Gamay',
#   'winery': 'Château Coutinel'},
#  118: {'index': 119,
#   'country': 'Portugal',
#   'description': 'fruit ripe berry fruit soft smooth',
#   'province': 'Alentejano',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Adega Cooperativa de Borba'},
#  119: {'index': 120,
#   'country': 'US',
#   'description': 'robust oak cherry oak toast reductive smooth concentrated powerful ripe',
#   'province': 'California',
#   'region_1': 'Russian River Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'MacPhail'},
#  120: {'index': 121,
#   'country': 'US',
#   'description': 'full_bodied fruit round spice tart cherry',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  121: {'index': 122,
#   'country': 'US',
#   'description': 'elegant sparkling sparkling watermelon dry orange_blossom yeast citrus_peel fresh strawberry tart raspberry yeast melon salt gripping',
#   'province': 'California',
#   'region_1': 'Santa Maria Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Goat Bubbles'},
#  122: {'index': 123,
#   'country': 'US',
#   'description': 'citrus elegant honey pear caramel lengthy complex mellow',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Grgich Hills'},
#  123: {'index': 124,
#   'country': 'US',
#   'description': 'tangy nervy refreshing fresh tangy fruit cranberry concentrated',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Navarro'},
#  124: {'index': 125,
#   'country': 'US',
#   'description': 'restrained powerful modest fruit tart fruit lean elegant oak',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Navarro'},
#  125: {'index': 126,
#   'country': 'US',
#   'description': 'vanilla coconut rich milk_chocolate strawberry jam sweet smooth',
#   'province': 'California',
#   'region_1': 'Amador County',
#   'variety': 'Zinfandel',
#   'winery': 'Renwood'},
#  126: {'index': 127,
#   'country': 'US',
#   'description': 'thick chocolate leather pepper concentrated smooth round robust blackberry vanilla',
#   'province': 'California',
#   'region_1': 'St. Helena',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Trinchero'},
#  127: {'index': 128,
#   'country': 'Spain',
#   'description': 'strawberry currant spice fresh grabby fruit baked spice cocoa dry cassis chocolate',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Pagos del Rey'},
#  128: {'index': 129,
#   'country': 'Italy',
#   'description': 'pineapple fruit saline apple peach herb minerality firm',
#   'province': 'Sicily & Sardinia',
#   'region_1': 'Etna',
#   'variety': 'White Blend',
#   'winery': 'Biondi'},
#  129: {'index': 130,
#   'country': 'Italy',
#   'description': 'juicy ripe fruit succulent crisp apple pear nectarine minerality bright',
#   'province': 'Southern Italy',
#   'region_1': 'Greco di Tufo',
#   'variety': 'Greco',
#   'winery': 'Cantine di Marzo'},
#  130: {'index': 131,
#   'country': 'US',
#   'description': 'light_bodied chalk slate minerality pear kiwi honeydew fruit pith grapefruit apple warm yellow pear saline warm',
#   'province': 'California',
#   'region_1': 'Santa Lucia Highlands',
#   'variety': 'Chardonnay',
#   'winery': 'Alexander-Smith'},
#  131: {'index': 132,
#   'country': 'US',
#   'description': 'meaty smoke fruit robust dry firm tannin grilled_meat',
#   'province': 'California',
#   'region_1': 'Amador County',
#   'variety': 'Barbera',
#   'winery': 'Andis'},
#  132: {'index': 133,
#   'country': 'US',
#   'description': 'crisp elegant lemon_peel apple pear light_bodied oak',
#   'province': 'California',
#   'region_1': 'Sonoma County',
#   'variety': 'Chardonnay',
#   'winery': 'Benziger'},
#  133: {'index': 134,
#   'country': 'US',
#   'description': 'dark pepper syrupy earth dry',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Beaucanon'},
#  134: {'index': 135,
#   'country': 'US',
#   'description': 'dark olallieberry blackberry plum concentrated purple_flower licorice earth eucalyptus fresh pomegranate juicy',
#   'province': 'California',
#   'region_1': 'Adelaida District',
#   'variety': 'Grenache',
#   'winery': 'Brecon Estate'},
#  135: {'index': 136,
#   'country': 'US',
#   'description': 'sour cherry cranberry sandalwood savory herb oregano dry herb juicy',
#   'province': 'California',
#   'region_1': 'Adelaida District',
#   'variety': 'Zinfandel',
#   'winery': 'Peachy Canyon'},
#  136: {'index': 137,
#   'country': 'US',
#   'description': 'heavy fruit concentrated thick velvety concentrated',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Three'},
#  137: {'index': 138,
#   'country': 'Spain',
#   'description': 'cherry plum vanilla oak elegant plum cherry toast oak vanilla toast crisp hard',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'Valdelacierva'},
#  138: {'index': 139,
#   'country': 'France',
#   'description': 'fruit currant raspberry strawberry flower lavender rosemary berry peach_pit soft spice closed',
#   'province': 'Languedoc-Roussillon',
#   'region_1': 'Coteaux du Languedoc Pic Saint Loup',
#   'variety': 'Rosé',
#   'winery': 'Château de Lancyre'},
#  139: {'index': 140,
#   'country': 'France',
#   'description': 'light_bodied ripe strawberry raspberry citrus',
#   'province': 'Bordeaux',
#   'region_1': 'Bordeaux Rosé',
#   'variety': 'Rosé',
#   'winery': 'Château Suau'},
#  140: {'index': 141,
#   'country': 'US',
#   'description': 'citrus light_bodied complex white refreshing bite oak steel oak shine tropical_fruit',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Clif Family'},
#  141: {'index': 142,
#   'country': 'US',
#   'description': 'zesty cherry cola cinnamon spice pepper light_bodied grippy vibrant iron',
#   'province': 'California',
#   'region_1': 'Santa Lucia Highlands',
#   'variety': 'Grenache',
#   'winery': 'Santa Cruz Mountain Vineyard'},
#  142: {'index': 143,
#   'country': 'US',
#   'description': 'steel racy pungent rich juicy fruit apple tangerine oak powerful',
#   'province': 'Oregon',
#   'region_1': 'Applegate Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Schmidt'},
#  143: {'index': 144,
#   'country': 'US',
#   'description': 'clean sharp zesty fruit ripe green apple fresh tingly sour stone fruit grippy',
#   'province': 'California',
#   'region_1': 'Edna Valley',
#   'variety': 'Albariño',
#   'winery': 'Stephen Ross'},
#  144: {'index': 145,
#   'country': 'US',
#   'description': 'strawberry rich fruit warm hard ripe soft',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Goldeneye'},
#  145: {'index': 146,
#   'country': 'US',
#   'description': 'exuberant fruit spice robust dark berry dust brown_sugar pepper ripe concentrated smooth elegant powerful',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Zinfandel',
#   'winery': 'Grgich Hills'},
#  146: {'index': 147,
#   'country': 'Spain',
#   'description': 'white_flower stone fruit lees juicy elegant citrus pith',
#   'province': 'Galicia',
#   'region_1': 'Rías Baixas',
#   'variety': 'Albariño',
#   'winery': 'Mar de Viñas'},
#  147: {'index': 148,
#   'country': 'US',
#   'description': 'vibrant flower depth blackberry dry fresh baked berry pastry cooked blackberry vanilla juicy strawberry pepper rosemary spice',
#   'province': 'California',
#   'region_1': 'Sta. Rita Hills',
#   'variety': 'Syrah',
#   'winery': 'Kessler-Haak'},
#  148: {'index': 149,
#   'country': 'US',
#   'description': 'white sweet bone_dry sugar citrus orange_blossom peach syrupy brisk honeysuckle pine bitter',
#   'province': 'California',
#   'region_1': 'Ballard Canyon',
#   'variety': 'Malvasia Bianca',
#   'winery': 'Larner'},
#  149: {'index': 150,
#   'country': 'US',
#   'description': 'light_bodied tart cherry fruit chocolate bright light_bodied',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Bomb'},
#  150: {'index': 151,
#   'country': 'Greece',
#   'description': 'orange lemon_peel vanilla white_flower citrus lush tropical_fruit fruit',
#   'province': 'Atalanti Valley',
#   'region_1': nan,
#   'variety': 'White Blend',
#   'winery': 'Hatzimichalis'},
#  151: {'index': 152,
#   'country': 'Spain',
#   'description': 'dust lees apple vanilla sturdy fresh modest elegant lime apple tarragon dry apple citrus easy',
#   'province': 'Catalonia',
#   'region_1': 'Cava',
#   'variety': 'Sparkling Blend',
#   'winery': 'Bohigas'},
#  152: {'index': 153,
#   'country': 'Greece',
#   'description': 'bright citrus tropical_fruit fruit white fresh elegant',
#   'province': 'Santorini',
#   'region_1': nan,
#   'variety': 'Assyrtiko',
#   'winery': 'Boutari'},
#  153: {'index': 154,
#   'country': 'Greece',
#   'description': 'peach pear lemon white complex fruit soft',
#   'province': 'Florina',
#   'region_1': nan,
#   'variety': 'Malagouzia',
#   'winery': 'Alpha Estate'},
#  154: {'index': 155,
#   'country': 'Chile',
#   'description': 'light_bodied herb horsey blueberry plum cardamom ripe hot flabby soft chunky plum blackberry licorice mint chewi syrupy',
#   'province': 'Marchigue',
#   'region_1': nan,
#   'variety': 'Carmenère',
#   'winery': 'Viña Bisquertt'},
#  155: {'index': 156,
#   'country': 'France',
#   'description': 'fruit dry wood berry fruit juicy fresh',
#   'province': 'Southwest France',
#   'region_1': 'Cahors',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Chateau Quattre'},
#  156: {'index': 157,
#   'country': 'US',
#   'description': 'shine bright spice tart strawberry raspberry cherry american_oak oak gripping',
#   'province': 'Oregon',
#   'region_1': 'Rogue Valley',
#   'variety': 'Sangiovese',
#   'winery': 'Ledger David'},
#  157: {'index': 158,
#   'country': 'Spain',
#   'description': 'leather plum compost rubber juicy herb plum currant earth tomato light_bodied leafy',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo',
#   'winery': 'CVNE'},
#  158: {'index': 159,
#   'country': 'Chile',
#   'description': 'berry cassis spice jam hollow blackberry blueberry fleshy soft',
#   'province': 'Colchagua Valley',
#   'region_1': nan,
#   'variety': 'Red Blend',
#   'winery': 'Estampa'},
#  159: {'index': 160,
#   'country': 'US',
#   'description': 'dry oregano thyme cherry green pepper blackberry tomato',
#   'province': 'California',
#   'region_1': 'Happy Canyon of Santa Barbara',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Foxen 7200'},
#  160: {'index': 161,
#   'country': 'US',
#   'description': 'fruit dense chunky cherry coffee oak toast elegant',
#   'province': 'Oregon',
#   'region_1': 'Oregon',
#   'variety': 'Pinot Noir',
#   'winery': 'Irvine Family Vineyards'},
#  161: {'index': 162,
#   'country': 'Spain',
#   'description': 'dense tar asphalt rubber boysenberry flat tannin blackberry prune raisin toast bitter chocolate weight oak ripe',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Marqués de Cáceres'},
#  162: {'index': 163,
#   'country': 'US',
#   'description': 'smoke meaty ripe plum tart blackberry overripe restrained savory tarragon anise',
#   'province': 'California',
#   'region_1': 'Dunnigan Hills',
#   'variety': 'Syrah',
#   'winery': 'Matchbook'},
#  163: {'index': 164,
#   'country': 'US',
#   'description': 'peach lemon juicy honey minerality apple pear cider ripe light_bodied',
#   'province': 'California',
#   'region_1': 'Paso Robles',
#   'variety': 'Viognier',
#   'winery': 'Eberle'},
#  164: {'index': 165,
#   'country': 'US',
#   'description': 'tight spice berry fruit light_bodied oak milk_chocolate smooth',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Silvan Ridge'},
#  165: {'index': 166,
#   'country': 'Italy',
#   'description': 'plum coffee tobacco cedar low_complexity blackberry currant clove licorice',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Tenuta degli Dei'},
#  166: {'index': 167,
#   'country': 'Italy',
#   'description': 'wild_berry violet spice savory cherry clove pepper',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Poggio Mandorlo'},
#  167: {'index': 168,
#   'country': 'Portugal',
#   'description': 'firm dry fruit fresh currant berry perfumed',
#   'province': 'Douro',
#   'region_1': nan,
#   'variety': 'Touriga Nacional',
#   'winery': 'Quinta das Carvalhas'},
#  168: {'index': 169,
#   'country': 'US',
#   'description': 'light_bodied yellow green crisp green apple rich pear butter fig rich ripe',
#   'province': 'California',
#   'region_1': 'Livermore Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Occasio'},
#  169: {'index': 170,
#   'country': 'US',
#   'description': 'rhubarb cola pencil_shaving earth sassafras dry berry soil minerality dark fruit',
#   'province': 'California',
#   'region_1': 'Sta. Rita Hills',
#   'variety': 'Pinot Noir',
#   'winery': 'Sanford'},
#  170: {'index': 171,
#   'country': 'Chile',
#   'description': 'dark lemon graphite licorice blackberry horsey baked chunky heavy fruit resin oak spice salt wood tannin',
#   'province': 'Curicó Valley',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon-Cabernet Franc',
#   'winery': 'Santa Alba'},
#  171: {'index': 172,
#   'country': 'Greece',
#   'description': 'leather cherry plum ripe cherry cedar cinnamon soft',
#   'province': 'Nemea',
#   'region_1': nan,
#   'variety': 'Agiorgitiko',
#   'winery': 'Boutari'},
#  172: {'index': 173,
#   'country': 'US',
#   'description': 'light_bodied fresh fruit cranberry cherry tangy fruit cinnamon firm',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Foursight'},
#  173: {'index': 174,
#   'country': 'France',
#   'description': 'oak meaty savory super_ripe cherry fruit',
#   'province': 'Rhône Valley',
#   'region_1': 'Côtes du Rhône',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Ogier'},
#  174: {'index': 175,
#   'country': 'Spain',
#   'description': 'cherry raspberry fresh dense wild_berry plum brown_sugar warm heady fruit bright',
#   'province': 'Northern Spain',
#   'region_1': 'Toro',
#   'variety': 'Tinta de Toro',
#   'winery': 'Pagos del Rey'},
#  175: {'index': 176,
#   'country': 'Italy',
#   'description': 'sleek toast oak vanilla blue_flower plum round sweet cherry raspberry licorice mint assertive',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Sangiovese',
#   'winery': 'Altesino'},
#  176: {'index': 177,
#   'country': 'Italy',
#   'description': 'robust baked plum coffee menthol spice hearty fruit chocolate licorice dry herb hot closed',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Cabreo'},
#  177: {'index': 178,
#   'country': 'US',
#   'description': 'juicy soft blackberry cherry oak weight strawberry dry herb closed',
#   'province': 'California',
#   'region_1': 'Napa Valley',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Cameron Hughes'},
#  178: {'index': 179,
#   'country': 'Chile',
#   'description': 'latex tire_rubber spice cured_meat berry fruit grabby herb muscular plum licorice pepper',
#   'province': 'Maule Valley',
#   'region_1': nan,
#   'variety': 'Red Blend',
#   'winery': 'Casa Donoso'},
#  179: {'index': 180,
#   'country': 'US',
#   'description': 'lemon oak refreshing fennel brine powerful',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Chardonnay',
#   'winery': 'Rodney Strong'},
#  180: {'index': 181,
#   'country': 'US',
#   'description': 'oak cherry extracted rich depth fruit complex licorice tar',
#   'province': 'California',
#   'region_1': 'Paso Robles',
#   'variety': 'Syrah',
#   'winery': 'San Simeon'},
#  181: {'index': 182,
#   'country': 'US',
#   'description': 'earth menthol eucalyptus tomato light_bodied powerful weight cherry plum dark savory',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Siduri'},
#  182: {'index': 183,
#   'country': 'US',
#   'description': 'kumquat wet_rocks concentrated light_bodied shine',
#   'province': 'Washington',
#   'region_1': 'Yakima Valley',
#   'variety': 'Picpoul',
#   'winery': 'Syncline'},
#  183: {'index': 184,
#   'country': 'Argentina',
#   'description': 'dark mint inky blackberry rubber grabby toast berry fruit chocolate oak hot mint coffee',
#   'province': 'Mendoza Province',
#   'region_1': 'Luján de Cuyo',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Piattelli'},
#  184: {'index': 185,
#   'country': 'US',
#   'description': 'raspberry cherry herb wood_spice fruit fresh elegant light_bodied chalk',
#   'province': 'Washington',
#   'region_1': 'Columbia Valley (WA)',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Pondera'},
#  185: {'index': 186,
#   'country': 'US',
#   'description': 'lush powerful gingerbread cherry thick heavy coffee plum cherry earth complex pencil_lead',
#   'province': 'California',
#   'region_1': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  186: {'index': 187,
#   'country': 'US',
#   'description': 'hearty earth nutmeg iron hot stone loamy cherry extracted lush ripe cassis cherry fruit elegant chalk round cocoa',
#   'province': 'California',
#   'region_1': 'Paso Robles',
#   'variety': 'Zinfandel',
#   'winery': 'Tobin James'},
#  187: {'index': 188,
#   'country': 'Spain',
#   'description': 'apple nectarine lees brine round bitter melon peach lees pith grapefruit_peel',
#   'province': 'Northern Spain',
#   'region_1': 'Valdeorras',
#   'variety': 'Godello',
#   'winery': 'Valdesil'},
#  188: {'index': 189,
#   'country': 'Spain',
#   'description': 'raisin baked overripe heavy berry prune fresh raisin',
#   'province': 'Catalonia',
#   'region_1': 'Montsant',
#   'variety': 'Red Blend',
#   'winery': 'Jaspi'},
#  189: {'index': 190,
#   'country': 'Argentina',
#   'description': 'crisp minerality oak firm juicy modest blackberry cassis oak coffee closed',
#   'province': 'Mendoza Province',
#   'region_1': 'Tupungato',
#   'variety': 'Malbec',
#   'winery': 'Tupun'},
#  190: {'index': 191,
#   'country': 'France',
#   'description': 'bright fruit minerality fresh fruit firm',
#   'province': 'Bordeaux',
#   'region_1': 'Graves',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Beauregard Lagupeau'},
#  191: {'index': 192,
#   'country': 'France',
#   'description': 'rich weight wood smoke edgy',
#   'province': 'Bordeaux',
#   'region_1': 'Haut-Médoc',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château du Taillan'},
#  192: {'index': 193,
#   'country': 'France',
#   'description': 'smoke toast wood fruit juicy fruit firm',
#   'province': 'Bordeaux',
#   'region_1': 'Saint-Estèphe',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château la Haye'},
#  193: {'index': 194,
#   'country': 'France',
#   'description': 'tannin wood juicy fruit bright smoke fruit dark toast',
#   'province': 'Bordeaux',
#   'region_1': 'Fronsac',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Lalande Mausse'},
#  194: {'index': 195,
#   'country': 'France',
#   'description': 'smoke burnt toast currant fruit bright fruit',
#   'province': 'Bordeaux',
#   'region_1': 'Haut-Médoc',
#   'variety': 'Bordeaux-style Red Blend',
#   'winery': 'Château Magnol'},
#  195: {'index': 196,
#   'country': 'US',
#   'description': 'cream butter bright lemon apple sweet luxurious viscous',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Chardonnay',
#   'winery': 'Grand Pacific'},
#  196: {'index': 197,
#   'country': 'US',
#   'description': 'brick dry round cherry watermelon',
#   'province': 'Washington',
#   'region_1': 'Columbia Valley (WA)',
#   'variety': 'Malbec',
#   'winery': 'Hamilton'},
#  197: {'index': 198,
#   'country': 'US',
#   'description': 'zesty minerality unoaked citrus refreshing pear quince crisp',
#   'province': 'New York',
# ...
#   'region_1': 'Côtes du Lot',
#   'variety': 'White Blend',
#   'winery': 'Clos Troteligotte'},
#  934: {'index': 938,
#   'country': 'Chile',
#   'description': 'tropical_fruit citrus bell_pepper zesty lemon tangerine brine citrus juicy crisp',
#   'province': 'Leyda Valley',
#   'region_1': nan,
#   'variety': 'Sauvignon Blanc',
#   'winery': 'Concha y Toro'},
#  935: {'index': 939,
#   'country': 'US',
#   'description': 'minerality white oak vanilla brioche viscous vibrant fruit ripe apple apricot',
#   'province': 'California',
#   'region_1': 'Carneros',
#   'variety': 'Chardonnay',
#   'winery': 'Conn Creek'},
#  936: {'index': 940,
#   'country': 'Spain',
#   'description': 'cherry plum rubber raisin depth light_bodied herb flower plum cherry oak resin elegant',
#   'province': 'Catalonia',
#   'region_1': 'Penedès',
#   'variety': 'Garnacha',
#   'winery': 'Parés Baltà'},
#  937: {'index': 941,
#   'country': 'US',
#   'description': 'fresh fruit polished raspberry plum chocolate blackberry rich firm fruit',
#   'province': 'California',
#   'region_1': 'Livermore Valley',
#   'variety': 'Rhône-style Red Blend',
#   'winery': 'Fenestra'},
#  938: {'index': 942,
#   'country': 'Germany',
#   'description': 'wildflower lemon_peel dry citrus white grapefruit bitter_almond white fresh',
#   'province': 'Baden',
#   'region_1': nan,
#   'variety': 'Pinot Gris',
#   'winery': 'Franz Keller'},
#  939: {'index': 943,
#   'country': 'Chile',
#   'description': 'dense earth meaty light_bodied tannin forest_floor plum baked',
#   'province': 'Limarí Valley',
#   'region_1': nan,
#   'variety': 'Red Blend',
#   'winery': 'Maray'},
#  940: {'index': 944,
#   'country': 'Italy',
#   'description': 'vibrant elegant cherry raspberry alpine_herbs supple bright',
#   'province': 'Lombardy',
#   'region_1': 'Valtellina Superiore',
#   'variety': 'Red Blend',
#   'winery': 'Nino Negri'},
#  941: {'index': 945,
#   'country': 'US',
#   'description': 'foamy sparkling sparkling apple ripe pear low_complexity apple white flower guava tropical_fruit',
#   'province': 'California',
#   'region_1': 'Arroyo Grande Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Laetitia'},
#  942: {'index': 946,
#   'country': 'Italy',
#   'description': 'ripe fruit spice undergrowth dry herb dry cherry plum clove sage',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Leopoldo I di Toscana'},
#  943: {'index': 947,
#   'country': 'US',
#   'description': 'spice tight pear fruit white pepper watery cracker',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Gris',
#   'winery': 'Lumos'},
#  944: {'index': 948,
#   'country': 'Chile',
#   'description': 'dense earth berry fruit latex crisp fresh hot light_bodied herb leather currant wild_berry oak',
#   'province': 'Colchagua Valley',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Maquis'},
#  945: {'index': 949,
#   'country': 'Italy',
#   'description': 'coffee tobacco cedar fruit elegant currant dry cherry clove anise silky',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Petra'},
#  946: {'index': 950,
#   'country': 'Portugal',
#   'description': 'concentrated berry fruit soft fresh fruit',
#   'province': 'Douro',
#   'region_1': nan,
#   'variety': 'Tinta Francisca',
#   'winery': 'Quinta das Carvalhas'},
#  947: {'index': 951,
#   'country': 'Italy',
#   'description': 'sawdust oak spice currant toast oak coffee menthol pepper dry cherry grippy astringent',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Rocca delle Macìe'},
#  948: {'index': 952,
#   'country': 'US',
#   'description': 'fresh strawberry fruit spice tart lemon',
#   'province': 'Oregon',
#   'region_1': 'Dundee Hills',
#   'variety': 'Rosé',
#   'winery': 'Stoller'},
#  949: {'index': 953,
#   'country': 'US',
#   'description': 'crisp dry tannin cranberry ripe cherry dry currant savory dry herb clove',
#   'province': 'California',
#   'region_1': 'Oakville',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Tamber Bey'},
#  950: {'index': 954,
#   'country': 'Italy',
#   'description': 'dense concentrated prune tobacco leather syrupy blackberry extracted fig sweet spice velvety complex',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Tenuta di Trinoro'},
#  951: {'index': 955,
#   'country': 'Italy',
#   'description': 'firm spice plum violet spice juicy ripe cherry licorice clove tight refined',
#   'province': 'Tuscany',
#   'region_1': 'Toscana',
#   'variety': 'Red Blend',
#   'winery': 'Tenuta Sette Ponti'},
#  952: {'index': 956,
#   'country': 'US',
#   'description': 'fruit cherry hard candy light_bodied herb stemmy fruit',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Walnut City WineWorks'},
#  953: {'index': 957,
#   'country': 'Portugal',
#   'description': 'concentrated fruit powerful juicy fruit',
#   'province': 'Douro',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Wines & Winemakers'},
#  954: {'index': 958,
#   'country': 'US',
#   'description': 'dark raspberry fruit graphite dark earth rocks earth juniper sour',
#   'province': 'California',
#   'region_1': 'Santa Barbara County',
#   'variety': 'Pinot Noir',
#   'winery': 'YNOT'},
#  955: {'index': 959,
#   'country': 'Greece',
#   'description': 'white citrus flower soft lemon_curd orange white fruit rich high_alcohol',
#   'province': 'Peloponnese',
#   'region_1': nan,
#   'variety': 'White Blend',
#   'winery': 'Zacharias'},
#  956: {'index': 960,
#   'country': 'Italy',
#   'description': 'berry undergrowth leather fennel herb firm vibrant ripe cherry raspberry licorice coffee balsamic',
#   'province': 'Piedmont',
#   'region_1': 'Roero',
#   'variety': 'Nebbiolo',
#   'winery': 'Negro Angelo e Figli'},
#  957: {'index': 961,
#   'country': 'US',
#   'description': 'smooth smoke edgy purple plum berry fruit silky length',
#   'province': 'Oregon',
#   'region_1': 'Oregon',
#   'variety': 'Tempranillo',
#   'winery': 'Obsidian'},
#  958: {'index': 962,
#   'country': 'Portugal',
#   'description': 'fruit ripe currant berry spice wood fresh juicy',
#   'province': 'Douro',
#   'region_1': nan,
#   'variety': 'Portuguese Red',
#   'winery': 'Poças'},
#  959: {'index': 963,
#   'country': 'US',
#   'description': 'ripe fruit spice tannin cherry raspberry sweet chocolate',
#   'province': 'California',
#   'region_1': 'Mendocino',
#   'variety': 'Red Blend',
#   'winery': "Ray's Station Vineyards"},
#  960: {'index': 964,
#   'country': 'Spain',
#   'description': 'resin oak stalky berry cherry raspberry grabby clampy oak berry baked plum oak raisin licorice',
#   'province': 'Northern Spain',
#   'region_1': 'Rioja',
#   'variety': 'Tempranillo Blend',
#   'winery': 'Rioja Vega'},
#  961: {'index': 965,
#   'country': 'Italy',
#   'description': 'fruit blue_flower round dry cherry blackberry jam licorice tobacco chewi',
#   'province': 'Piedmont',
#   'region_1': "Barbera d'Alba",
#   'variety': 'Barbera',
#   'winery': 'Rivetto'},
#  962: {'index': 966,
#   'country': 'Israel',
#   'description': 'dark blackberry pepper juniper berry smooth plum blackberry white peach elderberry violet eucalyptus fresh cherry juicy',
#   'province': 'Galilee',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon',
#   'winery': "Segal's"},
#  963: {'index': 967,
#   'country': 'US',
#   'description': 'strawberry dense powerful tight oak spice',
#   'province': 'California',
#   'region_1': 'Sonoma Coast',
#   'variety': 'Pinot Noir',
#   'winery': 'Small Vines'},
#  964: {'index': 968,
#   'country': 'Germany',
#   'description': 'fresh apple pear fresh herb citrus_peel honey steel',
#   'province': 'Mosel',
#   'region_1': nan,
#   'variety': 'Riesling',
#   'winery': 'St. Urbans-Hof'},
#  965: {'index': 969,
#   'country': 'US',
#   'description': 'raisin white pepper ripe fruit flower spice anise full_bodied hearty complex firm',
#   'province': 'California',
#   'region_1': 'Anderson Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Stemmler'},
#  966: {'index': 970,
#   'country': 'Israel',
#   'description': 'dark strawberry plum caramel smoked_meat blackberry blueberry smoked_meat vanilla coffee vanilla silky orange_peel',
#   'province': 'Galilee',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Tabor'},
#  967: {'index': 971,
#   'country': 'Italy',
#   'description': 'blue_flower plum licorice clove coffee menthol brawny warm full_bodied juicy cherry coffee pepper anise hot',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Tenuta Duecorti'},
#  968: {'index': 972,
#   'country': 'Portugal',
#   'description': 'concentrated wood light oak ripe yellow fruit crisp tangy spice bright',
#   'province': 'Alentejano',
#   'region_1': nan,
#   'variety': 'Portuguese White',
#   'winery': 'Terras de Alter'},
#  969: {'index': 973,
#   'country': 'US',
#   'description': 'rich concentrated almond hazelnut light_bodied lengthy lemon_peel apple',
#   'province': 'California',
#   'region_1': 'Russian River Valley',
#   'variety': 'Chardonnay',
#   'winery': 'Thomas George'},
#  970: {'index': 974,
#   'country': 'Israel',
#   'description': 'flower cherry pomegranate fresh pepper pomegranate strawberry mace anise smooth bright',
#   'province': 'Galilee',
#   'region_1': nan,
#   'variety': 'Red Blend',
#   'winery': 'Tulip Winery'},
#  971: {'index': 975,
#   'country': 'US',
#   'description': 'soft ripe nectarine citrus edgy pith orange bitter dry apple',
#   'province': 'California',
#   'region_1': 'Sta. Rita Hills',
#   'variety': 'Chardonnay',
#   'winery': 'Wedell Cellars'},
#  972: {'index': 976,
#   'country': 'US',
#   'description': 'fruit minerality fruit gripping powerful dense herb',
#   'province': 'Oregon',
#   'region_1': 'McMinnville',
#   'variety': 'Pinot Noir',
#   'winery': 'Winderlea'},
#  973: {'index': 977,
#   'country': 'Israel',
#   'description': 'dark cherry flower cherry matchstick petrol cherry pomegranate bell_pepper light_bodied flower chewi orange_peel cranberry',
#   'province': 'Judean Hills',
#   'region_1': nan,
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Yatir'},
#  974: {'index': 978,
#   'country': 'Italy',
#   'description': 'dark berry coffee toast cooked spice cherry coffee dry herb',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Cascina Luisin'},
#  975: {'index': 979,
#   'country': 'US',
#   'description': 'vanilla soft spice fruit mellow sweet',
#   'province': 'California',
#   'region_1': 'Rutherford',
#   'variety': 'Cabernet Sauvignon',
#   'winery': 'Azari'},
#  976: {'index': 980,
#   'country': 'Italy',
#   'description': 'rose bright berry anise sour cherry tobacco clove herbs brisk',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Borgogno Giacomo e Figli'},
#  977: {'index': 981,
#   'country': 'Italy',
#   'description': 'brawny plum coffee menthol dense chewi cherry licorice coffee warm',
#   'province': 'Piedmont',
#   'region_1': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': "Ca'Romè"},
#  978: {'index': 982,
#   'country': 'Italy',
#   'description': 'rose berry coffee herb toast crunchy cherry raspberry star_anise white pepper tight assertive closed coffee',
#   'province': 'Piedmont',
#   'region_1': 'Barbaresco',
#   'variety': 'Nebbiolo',
#   'winery': 'Ceretto'},
#  979: {'index': 983,
#   'country': 'Italy',
#   'description': 'earth leather game earth berry dry cherry coffee coffee licorice tobacco fresh',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Luigi Pira'},
#  980: {'index': 984,
#   'country': 'Italy',
#   'description': 'dark berry blue_flower spice firm ripe cherry white pepper cocoa star_anise balsamic',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Reverdito'},
#  981: {'index': 985,
#   'country': 'Spain',
#   'description': 'cherry plum butter oak leather firm ripe loamy berry cassis light_bodied raisin round',
#   'province': 'Northern Spain',
#   'region_1': 'Ribera del Duero',
#   'variety': 'Tempranillo',
#   'winery': 'Valdubón'},
#  982: {'index': 986,
#   'country': 'Italy',
#   'description': 'wild_berry dark spice menthol low_complexity dark cherry licorice dry herb firm ripe',
#   'province': 'Piedmont',
#   'region_1': 'Barolo',
#   'variety': 'Nebbiolo',
#   'winery': 'Vietti'},
#  983: {'index': 987,
#   'country': 'Australia',
#   'description': 'oak toast brown_sugar coffee fruit dark berry cola clove cinnamon cream lush weight dry fruit vanilla coffee',
#   'province': 'Tasmania',
#   'region_1': 'Tasmania',
#   'variety': 'Pinot Noir',
#   'winery': 'Dalrymple'},
#  984: {'index': 988,
#   'country': 'US',
#   'description': 'fresh toast light_bodied cranberry cherry fruit tart oak',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Pinot Noir',
#   'winery': 'Antiquum Farm'},
#  985: {'index': 989,
#   'country': 'US',
#   'description': 'clean crisp bright steel wood fresh fruit apple melon ginger racy',
#   'province': 'Oregon',
#   'region_1': 'Willamette Valley',
#   'variety': 'Sparkling Blend',
#   'winery': 'Argyle'},
#  986: {'index': 990,
#   'country': 'Italy',
#   'description': 'yellow apple chamomile flower ripe acacia bitter_almond',
#   'province': 'Veneto',
#   'region_1': 'Soave',
#   'variety': 'Garganega',
#   'winery': 'Marcello Turra'},
#  987: {'index': 991,
#   'country': 'US',
#   'description': 'smoke toast oak butter viscous',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Chardonnay',
#   'winery': 'Auspicion'},
#  988: {'index': 992,
#   'country': 'Israel',
#   'description': 'clean citrus grapefruit orange soft tart',
#   'province': 'Galilee',
#   'region_1': nan,
#   'variety': 'Chardonnay',
#   'winery': 'Carmel'},
#  989: {'index': 993,
#   'country': 'Portugal',
#   'description': 'sweet clean crisp citrus apple orange_peel',
#   'province': 'Vinho Verde',
#   'region_1': nan,
#   'variety': 'Portuguese White',
#   'winery': 'Caves Campelo'},
#  990: {'index': 994,
#   'country': 'Portugal',
#   'description': 'light_bodied spritzy crisp apple refreshing bright tangy',
#   'province': 'Vinho Verde',
#   'region_1': nan,
#   'variety': 'Portuguese White',
#   'winery': 'Caves Campelo'},
#  991: {'index': 995,
#   'country': 'Portugal',
#   'description': 'dry sparkling spice berry fruit depth rich oily',
#   'province': 'Tejo',
#   'region_1': nan,
#   'variety': 'Alicante Bouschet',
#   'winery': 'Adega Cooperativa do Cartaxo'},
#  992: {'index': 996,
#   'country': 'Portugal',
#   'description': 'soft cream fruit yeast edgy',
#   'province': 'Beira Atlantico',
#   'region_1': nan,
#   'variety': 'Portuguese Sparkling',
#   'winery': 'Adega de Cantanhede'},
#  993: {'index': 997,
#   'country': 'France',
#   'description': 'soft herb smooth bright crisp citrus gooseberry',
#   'province': 'Southwest France',
#   'region_1': 'Côtes de Gascogne',
#   'variety': 'Sauvignon Blanc',
#   'winery': "Domaine de l'Herré"},
#  994: {'index': 998,
#   'country': 'France',
#   'description': 'white fruit crisp refreshing herb edgy lemon grapefruit zingy bright',
#   'province': 'Southwest France',
#   'region_1': 'Côtes de Gascogne',
#   'variety': 'White Blend',
#   'winery': 'Domaine du Touja'},
#  995: {'index': 999,
#   'country': 'Argentina',
#   'description': 'dust plum berry clean hard salt snappy plum dry',
#   'province': 'Mendoza Province',
#   'region_1': 'Mendoza',
#   'variety': 'Malbec',
#   'winery': 'Proemio'},
#  996: {'index': 1000,
#   'country': 'Portugal',
#   'description': 'yeast toast fruit crisp bright',
#   'province': 'Tejo',
#   'region_1': nan,
#   'variety': 'Portuguese Sparkling',
#   'winery': 'Quinta da Lapa'},
#  997: {'index': 1001,
#   'country': 'US',
#   'description': 'butter butter spice vanilla cream smooth',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Chardonnay',
#   'winery': 'Vin Vault'},
#  998: {'index': 1002,
#   'country': 'US',
#   'description': 'soft fresh apple apple crisp clean',
#   'province': 'California',
#   'region_1': 'California',
#   'variety': 'Pinot Grigio',
#   'winery': 'The Naked Grape'},
#  999: {'index': 1003,
#   'country': 'Portugal',
#   'description': 'minerality tight yeast crisp bright apple fruit',
#   'province': 'Dão',
#   'region_1': nan,
#   'variety': 'Portuguese Sparkling',
#   'winery': 'Global Wines'},
#  ...}

# %%
model.wv

# %%
import pickle

# %%
# with open('word2vecmodel.pickle', 'wb') as handle:
#     pickle.dump(model.wv, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('mapped_reviews.pickle', 'wb') as handle:
#     pickle.dump(mapped_reviews, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('tfidf_weight_dict.pickle', 'wb') as handle:
    pickle.dump(dict_of_tfidf_weightings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('review_vectors_list.pickle', 'wb') as handle:
#     pickle.dump(vectors_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# with open('knnmodel.pickle', 'wb') as handle:
#     pickle.dump(modelknn, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
print(model)
# Out:
# Word2Vec(vocab=39919, size=300, alpha=0.025)

# %%
matrix_word2vec = []
words_word2vec_dict = {}
for i, key in enumerate(list(model.wv.vocab.keys())):
    words_word2vec_dict[key] = i
    embedding = model.wv.get_vector(key)
    matrix_word2vec.append(embedding)
matrix_word2vec = np.array(matrix_word2vec)
matrix_word2vec.shape
# Out:
# (39919, 300)

# %%
from scipy import sparse

# %%
matrix_word2vec = sparse.csr_matrix(matrix_word2vec)

# %%
vectors_list = np.array(vectors_list)
vectors_list_sparse = sparse.csr_matrix(vectors_list)

# %%
with open('matrix_word2vec.pickle', 'wb') as handle:
    pickle.dump(matrix_word2vec, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('words_word2vec.pickle', 'wb') as handle:
    pickle.dump(words_word2vec_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#vectors_list = np.float32(vectors_list)
with open('review_tfidf_embeddings.pickle', 'wb') as handle:
    pickle.dump(vectors_list_sparse, handle, protocol=pickle.HIGHEST_PROTOCOL)#

# %%
country_to_idx = {}
for idx in wine_dict:
    c = wine_dict[idx]['country']
    if c not in country_to_idx:
        country_to_idx[c] = []
    country_to_idx[c].append(idx)

with open('country_to_idx.pickle', 'wb') as handle:
    pickle.dump(country_to_idx, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('wine_dict.pickle', 'wb') as handle:
    pickle.dump(wine_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('tfidf_weight_dict.pickle', 'wb') as handle:
    pickle.dump(dict_of_tfidf_weightings, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
type(vectors_list)
# Out:
# numpy.ndarray

# %%
type(vectors_list_sparse)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
import os
os.path.getsize('C:\\Python27\\Lib\\genericpath.py')

# %%
vectors_list
# Out:
# 178978800

# %%
vectors_list_sparse.data.nbytes
# Out:
# 178908000

# %%
with open('review_tfidf_embeddings.pickle', 'wb') as handle:
    pickle.dump(vectors_list, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
matrix_word2vec.data.nbytes
# Out:
# 47902800
